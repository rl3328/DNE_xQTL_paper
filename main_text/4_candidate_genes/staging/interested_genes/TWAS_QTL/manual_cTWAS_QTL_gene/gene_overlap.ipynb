# %%
library(tidyverse)
library(data.table)

# %% [markdown]
# # Gene annotation

# %% [markdown]
# # MR

# %%
AD_sig_mr = fread("~/project/image_QTL/twas/AD_mr.sig_gene.tsv.gz")
# AD_sig_mr = unique(AD_sig_mr)
AD_sig_mr = AD_sig_mr |> rename(gene_id = gene_name)
AD_sig_mr_raw = AD_sig_mr |> select(gene_id, everything())
fwrite(AD_sig_mr_raw, "~/AD_mr_gene_list.txt", sep = '\t')

# %%
sos run xqtl-protocol/code/data_preprocessing/phenotype/gene_annotation.ipynb annotate_coord \
    --cwd ./ \
    --phenoFile ./AD_mr_gene_list.txt \
    --phenotype-id-column gene_id \
    --molecular-trait-type gene \
    --coordinate-annotation data/resource/references/Homo_sapiens.GRCh38.103.chr.reformatted.collapse_only.gene.ERCC.gtf

# %%
annotate_AD_mr = fread('~/AD_mr_gene_list.gene_list.tsv')

# %%
head(annotate_AD_mr)
dim(annotate_AD_mr)
# Out:
#   #chr start   end     gene_id         strand gene_name
# 1 chr1  944202  959308 ENSG00000188976 -      NOC2L
# 2 chr1  975203  982092 ENSG00000187642 -      PERM1
# 3 chr1  998961 1000171 ENSG00000188290 -      HES4
# 4 chr1 1020119 1056117 ENSG00000188157 +      AGRN
# 5 chr1 1081817 1116360 ENSG00000131591 -      C1orf159
# 6 chr1 1203507 1206591 ENSG00000186891 -      TNFRSF18
# [1] 6058    6

# %%
TL1_sig_mr = fread("~/project/image_QTL/twas/TL1_mr.sig_gene.tsv.gz")
# TL1_sig_mr = unique(TL1_sig_mr)
TL1_sig_mr = TL1_sig_mr |> rename(gene_id = gene_name)
TL1_sig_mr_raw = TL1_sig_mr |> select(gene_id, everything())
fwrite(TL1_sig_mr_raw, "~/TL1_mr_gene_list.txt", sep = '\t')

# %%
sos run xqtl-protocol/code/data_preprocessing/phenotype/gene_annotation.ipynb annotate_coord \
    --cwd ./ \
    --phenoFile ./TL1_mr_gene_list.txt \
    --phenotype-id-column gene_id \
    --molecular-trait-type gene \
    --coordinate-annotation data/resource/references/Homo_sapiens.GRCh38.103.chr.reformatted.collapse_only.gene.ERCC.gtf

# %%
annotate_TL1_mr = fread('~/TL1_mr_gene_list.gene_list.tsv')

# %%
head(annotate_TL1_mr)
dim(annotate_TL1_mr)
# Out:
#   #chr start   end     gene_id         strand gene_name
# 1 chr1 1020119 1056117 ENSG00000188157 +      AGRN
# 2 chr1 1081817 1116360 ENSG00000131591 -      C1orf159
# 3 chr1 1418419 1421768 ENSG00000235098 -      ANKRD65
# 4 chr1 3454664 3481112 ENSG00000130762 +      ARHGEF16
# 5 chr1 3487950 3611507 ENSG00000162591 -      MEGF6
# 6 chr1 3889124 3900277 ENSG00000198912 -      C1orf174
# [1] 2667    6

# %% [markdown]
# # TWAS

# %%
annotated_all = fread("~/xqtl-analysis/production/image_QTL/interested_genes/TWAS_QTL/TWAS_QTL_gene_list.tsv")
TL1_annotated = annotated_all |> filter(event_id == "TL1")

# %%
AD1 = fread("~/xqtl-analysis/production/image_QTL/interested_genes/TWAS_QTL/manual_cTWAS_QTL_gene/image_AD1_gene_list.tsv")
AD1_gene = AD1$gene_id
AD1 = AD1 |> mutate(source = ifelse(gene_name == "" | is.na(gene_name), "TWAS", "QTL")) |> select(-gene_name)
AD1_raw = AD1 |> select(gene_id, source)
fwrite(AD1_raw, "~/image_AD1_gene_list.txt", sep = '\t')

# %%
sos run xqtl-protocol/code/data_preprocessing/phenotype/gene_annotation.ipynb annotate_coord \
    --cwd ./ \
    --phenoFile ./image_AD1_gene_list.txt \
    --phenotype-id-column gene_id \
    --molecular-trait-type gene \
    --coordinate-annotation data/resource/references/Homo_sapiens.GRCh38.103.chr.reformatted.collapse_only.gene.ERCC.gtf

# %%
annotate_AD1 = fread('~/image_AD1_gene_list.gene_list.tsv') |> select(gene_id, gene_name)
AD1_annotated = AD1 |> inner_join(annotate_AD1, by="gene_id")

# %%
head(AD1_annotated)
dim(AD1_annotated)
# Out:
#   #chr  start     end       gene_id         source gene_name
# 1 chr10 101503971 103680000 ENSG00000107882 TWAS   SUFU
# 2 chr10 102877569 104918184 ENSG00000107960 TWAS   STN1
# 3 chr10 101461881 103680000 ENSG00000138107 TWAS   ACTR1A
# 4 chr10 101461394 103680000 ENSG00000138111 TWAS   MFSD13A
# 5 chr10 101673731 103714397 ENSG00000138175 TWAS   ARL3
# 6 chr10 101644478 103680000 ENSG00000171206 TWAS   TRIM8
# [1] 104   6

# %%
AD2 = fread("~/xqtl-analysis/production/image_QTL/interested_genes/TWAS_QTL/manual_cTWAS_QTL_gene/image_AD2_gene_list.tsv")
AD2_gene = AD2$gene_id
AD2 = AD2 |> mutate(source = ifelse(gene_name == "" | is.na(gene_name), "TWAS", "QTL")) |> select(-gene_name)
AD2_raw = AD2 |> select(gene_id, source)
fwrite(AD2_raw, "~/image_AD2_gene_list.txt", sep = '\t')

# %%
sos run xqtl-protocol/code/data_preprocessing/phenotype/gene_annotation.ipynb annotate_coord \
    --cwd ./ \
    --phenoFile ./image_AD2_gene_list.txt \
    --phenotype-id-column gene_id \
    --molecular-trait-type gene \
    --coordinate-annotation data/resource/references/Homo_sapiens.GRCh38.103.chr.reformatted.collapse_only.gene.ERCC.gtf

# %%
annotate_AD2 = fread('~/image_AD2_gene_list.gene_list.tsv') |> select(gene_id, gene_name)
AD2_annotated = AD2 |> inner_join(annotate_AD2, by="gene_id")

# %%
head(AD2_annotated)
dim(AD2_annotated)
# Out:
#   #chr  start     end       gene_id         source gene_name
# 1 chr11  45380755  48440000 ENSG00000110492 TWAS   MDK
# 2 chr11  45800000  48440000 ENSG00000149179 TWAS   C11orf49
# 3 chr11  45800000  48440000 ENSG00000165912 TWAS   PACSIN3
# 4 chr11  57280000  61923443 ENSG00000110108 TWAS   TMEM109
# 5 chr12 115920000 118120000 ENSG00000088992 TWAS   TESC
# 6 chr12 116208142 118452170 ENSG00000089250 TWAS   NOS1
# [1] 134   6

# %%
Aging1 = fread("~/xqtl-analysis/production/image_QTL/interested_genes/TWAS_QTL/manual_cTWAS_QTL_gene/image_Aging1_gene_list.tsv")
Aging1_gene = Aging1$gene_id
Aging1 = Aging1 |> mutate(source = ifelse(gene_name == "" | is.na(gene_name), "TWAS", "QTL")) |> select(-gene_name)
Aging1_raw = Aging1 |> select(gene_id, source)
fwrite(Aging1_raw, "~/image_Aging1_gene_list.txt", sep = '\t')

# %%
sos run xqtl-protocol/code/data_preprocessing/phenotype/gene_annotation.ipynb annotate_coord \
    --cwd ./ \
    --phenoFile ./image_Aging1_gene_list.txt \
    --phenotype-id-column gene_id \
    --molecular-trait-type gene \
    --coordinate-annotation data/resource/references/Homo_sapiens.GRCh38.103.chr.reformatted.collapse_only.gene.ERCC.gtf

# %%
annotate_Aging1 = fread('~/image_Aging1_gene_list.gene_list.tsv') |> select(gene_id, gene_name)
Aging1_annotated = Aging1 |> inner_join(annotate_Aging1, by="gene_id")

# %%
head(Aging1_annotated)
dim(Aging1_annotated)
# Out:
#   #chr  start     end       gene_id         source gene_name
# 1 chr11  13643803  17560000 ENSG00000152270 TWAS   PDE3B
# 2 chr12 101073103 103120120 ENSG00000075188 TWAS   NUP37
# 3 chr12 100696946 102960000 ENSG00000111666 TWAS   CHPT1
# 4 chr14  54559071  56701526 ENSG00000126777 TWAS   KTN1
# 5 chr14  54840000  57301524 ENSG00000139946 TWAS   PELI2
# 6 chr14  54271343  56640000 ENSG00000178974 TWAS   FBXO34
# [1] 162   6

# %%
Aging2 = fread("~/xqtl-analysis/production/image_QTL/interested_genes/TWAS_QTL/manual_cTWAS_QTL_gene/image_Aging2_gene_list.tsv")
Aging2_gene = Aging2$gene_id
Aging2 = Aging2 |> mutate(source = ifelse(gene_name == "" | is.na(gene_name), "TWAS", "QTL")) |> select(-gene_name)
Aging2_raw = Aging2 |> select(gene_id, source)
fwrite(Aging2_raw, "~/image_Aging2_gene_list.txt", sep = '\t')

# %%
sos run xqtl-protocol/code/data_preprocessing/phenotype/gene_annotation.ipynb annotate_coord \
    --cwd ./ \
    --phenoFile ./image_Aging2_gene_list.txt \
    --phenotype-id-column gene_id \
    --molecular-trait-type gene \
    --coordinate-annotation data/resource/references/Homo_sapiens.GRCh38.103.chr.reformatted.collapse_only.gene.ERCC.gtf

# %%
annotate_Aging2 = fread('~/image_Aging2_gene_list.gene_list.tsv') |> select(gene_id, gene_name)
Aging2_annotated = Aging2 |> inner_join(annotate_Aging2, by="gene_id")

# %%
head(Aging2_annotated)
dim(Aging2_annotated)
# Out:
#   #chr  start     end       gene_id         source gene_name
# 1 chr10 123942122 125988189 ENSG00000019995 TWAS   ZRANB1
# 2 chr10 122600000 125840000 ENSG00000107902 TWAS   LHPP
# 3 chr10 123748149 125840000 ENSG00000203791 TWAS   EEF1AKMT2
# 4 chr10  26880000  30640000 ENSG00000095787 TWAS   WAC
# 5 chr11  45380755  48440000 ENSG00000110492 TWAS   MDK
# 6 chr12 115920000 118120000 ENSG00000088992 TWAS   TESC
# [1] 124   6

# %%
Aging3 = fread("~/xqtl-analysis/production/image_QTL/interested_genes/TWAS_QTL/manual_cTWAS_QTL_gene/image_Aging3_gene_list.tsv")
Aging3_gene = Aging3$gene_id
Aging3 = Aging3 |> mutate(source = ifelse(gene_name == "" | is.na(gene_name), "TWAS", "QTL")) |> select(-gene_name)
Aging3_raw = Aging3 |> select(gene_id, source)
fwrite(Aging3_raw, "~/image_Aging3_gene_list.txt", sep = '\t')

# %%
sos run xqtl-protocol/code/data_preprocessing/phenotype/gene_annotation.ipynb annotate_coord \
    --cwd ./ \
    --phenoFile ./image_Aging3_gene_list.txt \
    --phenotype-id-column gene_id \
    --molecular-trait-type gene \
    --coordinate-annotation data/resource/references/Homo_sapiens.GRCh38.103.chr.reformatted.collapse_only.gene.ERCC.gtf

# %%
annotate_Aging3 = fread('~/image_Aging3_gene_list.gene_list.tsv') |> select(gene_id, gene_name)
Aging3_annotated = Aging3 |> inner_join(annotate_Aging3, by="gene_id")

# %%
head(Aging3_annotated)
dim(Aging3_annotated)
# Out:
#   #chr  start     end       gene_id         source gene_name
# 1 chr10 115881477 118126586 ENSG00000187164 TWAS   SHTN1
# 2 chr10 117200000 122280000 ENSG00000183605 TWAS   SFXN4
# 3 chr12  64050626  66160000 ENSG00000156076 TWAS   WIF1
# 4 chr14  56480000  60600000 ENSG00000131966 TWAS   ACTR10
# 5 chr14  56480000  60600000 ENSG00000139971 TWAS   ARMH4
# 6 chr14  58080000  60600000 ENSG00000151838 TWAS   CCDC175
# [1] 90  6

# %%
Aging4 = fread("~/xqtl-analysis/production/image_QTL/interested_genes/TWAS_QTL/manual_cTWAS_QTL_gene/image_Aging4_gene_list.tsv")
Aging4_gene = Aging4$gene_id
Aging4 = Aging4 |> mutate(source = ifelse(gene_name == "" | is.na(gene_name), "TWAS", "QTL")) |> select(-gene_name)
Aging4_raw = Aging4 |> select(gene_id, source)
fwrite(Aging4_raw, "~/image_Aging4_gene_list.txt", sep = '\t')

# %%
sos run xqtl-protocol/code/data_preprocessing/phenotype/gene_annotation.ipynb annotate_coord \
    --cwd ./ \
    --phenoFile ./image_Aging4_gene_list.txt \
    --phenotype-id-column gene_id \
    --molecular-trait-type gene \
    --coordinate-annotation data/resource/references/Homo_sapiens.GRCh38.103.chr.reformatted.collapse_only.gene.ERCC.gtf

# %%
annotate_Aging4 = fread('~/image_Aging4_gene_list.gene_list.tsv') |> select(gene_id, gene_name)
Aging4_annotated = Aging4 |> inner_join(annotate_Aging4, by="gene_id")

# %%
head(Aging4_annotated)
dim(Aging4_annotated)
# Out:
#   #chr  start     end       gene_id         source gene_name
# 1 chr10 102877569 104918184 ENSG00000107960 TWAS   STN1
# 2 chr16  85040000  90338345 ENSG00000141002 TWAS   TCF25
# 3 chr16  85040000  90338345 ENSG00000185324 TWAS   CDK10
# 4 chr16  85040000  90338345 ENSG00000258839 TWAS   MC1R
# 5 chr17  28360000  32440000 ENSG00000141298 TWAS   SSH2
# 6 chr17  42560000  46680000 ENSG00000136448 TWAS   NMT1
# [1] 77  6

# %%
Aging5 = fread("~/xqtl-analysis/production/image_QTL/interested_genes/TWAS_QTL/manual_cTWAS_QTL_gene/image_Aging5_gene_list.tsv")
Aging5_gene = Aging5$gene_id
Aging5 = Aging5 |> mutate(source = ifelse(gene_name == "" | is.na(gene_name), "TWAS", "QTL")) |> select(-gene_name)
Aging5_raw = Aging5 |> select(gene_id, source)
fwrite(Aging5_raw, "~/image_Aging5_gene_list.txt", sep = '\t')

# %%
sos run xqtl-protocol/code/data_preprocessing/phenotype/gene_annotation.ipynb annotate_coord \
    --cwd ./ \
    --phenoFile ./image_Aging5_gene_list.txt \
    --phenotype-id-column gene_id \
    --molecular-trait-type gene \
    --coordinate-annotation data/resource/references/Homo_sapiens.GRCh38.103.chr.reformatted.collapse_only.gene.ERCC.gtf

# %%
annotate_Aging5 = fread('~/image_Aging5_gene_list.gene_list.tsv') |> select(gene_id, gene_name)
Aging5_annotated = Aging5 |> inner_join(annotate_Aging5, by="gene_id")

# %%
head(Aging5_annotated)
dim(Aging5_annotated)
# Out:
#   #chr  start     end       gene_id         source gene_name
# 1 chr10 102040000 104855543 ENSG00000107957 TWAS   SH3PXD2A
# 2 chr10 101673731 103714397 ENSG00000138175 TWAS   ARL3
# 3 chr10 101918293 104090222 ENSG00000148842 TWAS   CNNM2
# 4 chr10 101743947 103834516 ENSG00000166272 TWAS   WBP1L
# 5 chr10 101854258 103864961 ENSG00000166275 TWAS   BORCS7
# 6 chr10 101644478 103680000 ENSG00000171206 TWAS   TRIM8
# [1] 188   6

# %%
combined_df <- bind_rows(
  image_AD1 = AD1_annotated,
  image_AD2 = AD2_annotated,
  image_Aging1 = Aging1_annotated,
  image_Aging2 = Aging2_annotated,
  image_Aging3 = Aging3_annotated,
  image_Aging4 = Aging4_annotated,
  image_Aging5 = Aging5_annotated,
    TL1 = TL1_annotated,
  .id = "event_id"
)

# %%
fwrite(combined_df, "~/xqtl-analysis/production/image_QTL/interested_genes/TWAS_QTL/manual_cTWAS_QTL_gene/TWAS_QTL_gene_list.tsv", sep = '\t')

# %%
combined_df |> count(gene_name) |> filter(n>1) |> arrange(desc(n))
# Out:
#     gene_name  n
# 1   CENPW      6
# 2   AMZ1       5
# 3   GNA12      5
# 4   MAPK3      5
# 5   ARMH4      4
# 6   BCL2L1     4
# 7   BTN2A1     4
# 8   C4A        4
# 9   C4B        4
# 10  CYP21A2    4
# 11  GDF5       4
# 12  GDPD3      4
# 13  HLA-A      4
# 14  NPIPB7     4
# 15  PSMA3      4
# 16  SEZ6L2     4
# 17  SSH2       4
# 18  STAG3      4
# 19  STN1       4
# 20  SULT1A1    4
# 21  TMEM170B   4
# 22  TNIP1      4
# 23  TRIM26     4
# 24  TUFM       4
# 25  UQCC1      4
# 26  ZKSCAN4    4
# 27  ZKSCAN8    4
# 28  AL021997.2 3
# 29  ARL17A     3
# 30  ARL17B     3
# ⋮   ⋮          ⋮
# 336 TRMT11     2
# 337 TRMT61B    2
# 338 TSPYL6     2
# 339 TUT7       2
# 340 TYMP       2
# 341 TYMS       2
# 342 UBE2Z      2
# 343 UBXN6      2
# 344 UGT2B7     2
# 345 UPK1A      2
# 346 UPK3B      2
# 347 VAC14      2
# 348 VAT1       2
# 349 VIRMA      2
# 350 WAC        2
# 351 WASHC3     2
# 352 WBP1L      2
# 353 WDR12      2
# 354 WIF1       2
# 355 WWP2       2
# 356 XPOT       2
# 357 ZIC1       2
# 358 ZIC4       2
# 359 ZIM2       2
# 360 ZNF311     2
# 361 ZNF398     2
# 362 ZNF596     2
# 363 ZNF676     2
# 364 ZNF786     2
# 365 ZP3        2

# %% [markdown]
# # gene_overlap

# %%
all = fread("~/xqtl-analysis/production/image_QTL/interested_genes/TWAS_QTL/manual_cTWAS_QTL_gene/TWAS_QTL_gene_list.tsv")
AD1 = all |> filter(str_detect(event_id,"image_AD1"))
AD2 = all |> filter(str_detect(event_id,"image_AD2"))
Aging1 = all |> filter(str_detect(event_id,"image_Aging1"))
Aging2 = all |> filter(str_detect(event_id,"image_Aging2"))
Aging3 = all |> filter(str_detect(event_id,"image_Aging3"))
Aging4 = all |> filter(str_detect(event_id,"image_Aging4"))
Aging5 = all |> filter(str_detect(event_id,"image_Aging5"))
TL1 = fread("~/xqtl-analysis/production/image_QTL/interested_genes/TWAS_QTL/TL1_mr_gene_list.gene_list.tsv")
AD = fread("~/xqtl-analysis/production/image_QTL/interested_genes/TWAS_QTL/AD_mr_gene_list.gene_list.tsv")

# %%
all |> filter(gene_name == 'TRIM26')
# Out:
#   #chr start    end      gene_id         source gene_name event_id
# 1 chr6 25960000 33560000 ENSG00000234127 TWAS   TRIM26    image_AD2
# 2 chr6 25960000 33560000 ENSG00000234127 TWAS   TRIM26    image_Aging3
# 3 chr6 25960000 33560000 ENSG00000234127 TWAS   TRIM26    image_Aging5
# 4 chr6 25960000 33560000 ENSG00000234127 TWAS   TRIM26    TL1

# %%
Aging1_gene = Aging1$gene_name |> unique()

Aging2_gene = Aging2$gene_name|> unique()

Aging3_gene = Aging3$gene_name|> unique()

Aging4_gene = Aging4$gene_name|> unique()

Aging5_gene = Aging5$gene_name|> unique()

TL1_gene = TL1$gene_name|> unique()
AD_gene = AD$gene_name|> unique()
AD1_gene = AD1$gene_name|> unique()
AD2_gene = AD2$gene_name|> unique()

# %%
AD1_gene
# Out:
#  [1] "SUFU"     "STN1"     "ACTR1A"   "MFSD13A"  "ARL3"     "TRIM8"
#  [7] "ACTR10"   "ARMH4"    "JKAMP"    "DAAM1"    "CCDC175"  "EML1"
# [13] "YY1"      "PDE8A"    "SSH2"     "MAPT"     "AGBL4"    "NINL"
# [19] "UQCC1"    "GDF5"     "MMP24"    "SNAP29"   "PI4KA"    "LGALS1"
# [25] "GCC2"     "CDC42EP3" "SCAP"     "NBEAL2"   "SETD2"    "RBM5"
# [31] "CDC25A"   "PLXNB1"   "XKR6"     "RP1L1"    "FDFT1"    "FAM86B2"
# [37] "FAM167A"  "CTSB"     "FAM86B1"  "DEPTOR"   "MFHAS1"   "TNKS"
# [43] "PDCD11"   "RNF34"    "CBX5"     "ARHGAP9"  "ARID4A"   "AP5M1"
# [49] "PSMA3"    "RTN1"     "TMED6"    "KLHL18"   "CCDC12"   "PTPN23"
# [55] "ELP6"     "MAP4"     "RHOA"     "DHX30"    "SMARCC1"  "KLHDC8B"
# [61] "QRICH1"   "MON1A"    "LSMEM2"   "ENPP2"    "CCN3"     "ANK1"
# [67] "KIAA0586" "SOX7"     "CLDN23"   "ERI1"     "MSRA"     "ARL4C"
# [73] "CSPG5"    "UGT2B7"   "KIF13A"   "AMZ1"     "GNA12"    "EGFR"
# [79] "SBSPON"   "THNSL1"   "KDM2B"    "EEF2"     "PIAS4"    "SERPIND1"
# [85] "ADORA2A"

# %%
AD2_gene
# Out:
#   [1] "MDK"            "C11orf49"       "PACSIN3"        "TMEM109"
#   [5] "TESC"           "NOS1"           "TBC1D30"        "LEMD3"
#   [9] "XPOT"           "AC078815.1"     "AC078927.1"     "CCDC169-SOHLH2"
#  [13] "MAPK3"          "CCDC57"         "MAEL"           "ASAP3"
#  [17] "TCEA3"          "FAF1"           "UQCC1"          "GDF5"
#  [21] "MMP24"          "ERGIC3"         "CEP250"         "CARF"
#  [25] "SPEG"           "PLCD4"          "ZNF142"         "TTLL4"
#  [29] "CNOT9"          "ECEL1"          "SPTBN1"         "FILIP1L"
#  [33] "CYFIP2"         "MAST4"          "TRMT11"         "H2AC4"
#  [37] "BTN3A3"         "BTN2A1"         "ZNF322"         "ZKSCAN3"
#  [41] "ZKSCAN8"        "ZSCAN31"        "AL021997.2"     "ZSCAN23"
#  [45] "ZNF311"         "FLOT1"          "VARS2"          "TRIM26"
#  [49] "ATF6B"          "C4B"            "C4A"            "TES"
#  [53] "SEMA4D"         "FBXW8"          "NAB2"           "MSRB3"
#  [57] "GDPD3"          "TUBG2"          "TUBG1"          "CNTD1"
#  [61] "BRCA1"          "DHX8"           "VAT1"           "MPP2"
#  [65] "CCDC200"        "AARSD1"         "ITGA2B"         "RUNDC3A"
#  [69] "HDAC5"          "G6PC3"          "FAM171A2"       "C1QL1"
#  [73] "GFAP"           "NMT1"           "PLCD3"          "HEXIM1"
#  [77] "KANSL1"         "ARL17A"         "ARL17B"         "ATAD3A"
#  [81] "PHF20"          "NFS1"           "TANK"           "PRKAG3"
#  [85] "USP37"          "MANBA"          "UBE2D3"         "TNIP1"
#  [89] "TMEM170B"       "IER3"           "NKAPD1"         "ZKSCAN4"
#  [93] "PINX1"          "ERO1B"          "DIS3L2"         "AP3B1"
#  [97] "VCAN"           "CYSTM1"         "H2AC11"         "H4C13"
# [101] "FILIP1"         "CCM2"           "TBRG4"          "DGKZ"
# [105] "ATG13"          "CKAP5"          "LRP4"           "NR1H3"
# [109] "ZDHHC5"         "AP001931.2"     "TMX2"           "CTNND1"
# [113] "DPCD"           "NABP2"          "ANKRD52"        "COQ10A"
# [117] "CS"             "CNPY2"          "PAN2"           "IL23A"
# [121] "STAT2"          "SOHLH2"         "CCDC169"        "SPART"

# %%
Aging1_gene
# Out:
#   [1] "PDE3B"      "NUP37"      "CHPT1"      "KTN1"       "PELI2"
#   [6] "FBXO34"     "WDHD1"      "DNAL1"      "CCDC88C"    "PDXDC1"
#  [11] "TNRC6A"     "SLC5A11"    "IL21R"      "SGF29"      "TUFM"
#  [16] "EIF3C"      "CLN3"       "SULT1A1"    "SULT1A2"    "LAT"
#  [21] "NPIPB7"     "RUSF1"      "COG4"       "NOB1"       "SF3B3"
#  [26] "WWP2"       "SRR"        "NOL11"      "KPNA2"      "PRKCZ"
#  [31] "PROX1"      "AGBL4"      "PYGB"       "ABHD12"     "NINL"
#  [36] "BCL2L1"     "C20orf194"  "ITPA"       "NLRC4"      "ZIC4"
#  [41] "PDCD6IP"    "SEC31A"     "EXOC3"      "H4C8"       "HLA-G"
#  [46] "APOM"       "CYP21A2"    "AL662884.4" "POLR2J3"    "STAG3"
#  [51] "ZCWPW1"     "PILRB"      "MEPCE"      "C7orf61"    "SLC20A2"
#  [56] "SMIM19"     "DSCAML1"    "WASHC3"     "PARPBP"     "MAPK1IP1L"
#  [61] "PPP4R3A"    "NUPR1"      "HIRIP3"     "ZNF768"     "SEZ6L2"
#  [66] "SULT1A3"    "SETD1A"     "PRSS36"     "NOL3"       "TMEM208"
#  [71] "SLC7A6OS"   "NRN1L"      "NFAT5"      "VAC14"      "ZNRF1"
#  [76] "AKAP10"     "HELZ"       "DYRK1B"     "TAS1R3"     "HM13"
#  [81] "COX4I2"     "ABI2"       "ZNF717"     "POLR2B"     "REST"
#  [86] "HLA-B"      "PRRC2A"     "DNAJC2"     "NYAP1"      "TNFRSF11B"
#  [91] "ZIC1"       "KLF3"       "CD101"      "IGFBP7"     "ENOPH1"
#  [96] "LIN54"      "AHRR"       "SLC9A3"     "HLA-A"      "TRIM39"
# [101] "COL21A1"    "CENPW"      "TULP4"      "TMEM181"    "SOD2"
# [106] "WTAP"       "ACAT2"      "TCP1"       "MRPL18"     "PNLDC1"
# [111] "AMZ1"       "GNA12"      "PILRA"      "TSC22D4"    "FAM160B2"
# [116] "EFCAB1"     "SAA4"       "SAA2"       "HPS5"       "GTF2H1"
# [121] "ENO4"       "SHTN1"      "CNTN1"      "EIF2B2"     "MLH3"
# [126] "ACYP1"      "ZC2HC1C"    "NEK9"       "TMED10"     "NPIPA1"
# [131] "NPIPA5"     "SH2B1"      "ATP2A1"     "DYNC1LI2"   "ATP9B"
# [136] "SLC4A11"    "DNAJC5"

# %%
Aging2_gene
# Out:
#   [1] "ZRANB1"         "LHPP"           "EEF1AKMT2"      "WAC"
#   [5] "MDK"            "TESC"           "NOS1"           "TBC1D30"
#   [9] "WIF1"           "LEMD3"          "XPOT"           "AC078815.1"
#  [13] "HELB"           "YPEL3"          "MAPK3"          "TMEM219"
#  [17] "INO80E"         "ASPHD1"         "C16orf54"       "RHOT1"
#  [21] "LRRC37B"        "RAD51C"         "MTMR4"          "MAEL"
#  [25] "NAV1"           "FAAH"           "PDZK1IP1"       "CDKN2C"
#  [29] "FAF1"           "SLC35D1"        "H6PD"           "HLCS"
#  [33] "SLC4A10"        "MSH6"           "SLC9B1"         "TRMT11"
#  [37] "HINT3"          "PLXNA4"         "ZNF786"         "NACAD"
#  [41] "XKR6"           "RP1L1"          "FAM86B2"        "FAM167A"
#  [45] "FBXW8"          "PAN2"           "MSRB3"          "BOLA2-SMG1P6"
#  [49] "NPIPB12"        "BOLA2"          "CORO1A"         "TBX6"
#  [53] "DOC2A"          "SEZ6L2"         "KCTD13"         "SEPHS2"
#  [57] "NPIPB13"        "SPAG5"          "BLMH"           "GOSR1"
#  [61] "NSRP1"          "SSH2"           "EFCAB5"         "MAP3K14"
#  [65] "PPM1E"          "RNF11"          "BCL2L1"         "PLCG1"
#  [69] "ACVR2A"         "TANK"           "NFKB1"          "CISD2"
#  [73] "TNIP1"          "VCAN"           "TMEM170B"       "RSPO3"
#  [77] "CENPW"          "ZNF398"         "SLX1B"          "SOX7"
#  [81] "MAST2"          "DOCK10"         "ARL4C"          "MAST4"
#  [85] "RPA3"           "FAM126A"        "KLHL7"          "NUP42"
#  [89] "GPNMB"          "C7orf33"        "ZNF425"         "AC068896.1"
#  [93] "SYT10"          "DYRK2"          "WASHC3"         "PARPBP"
#  [97] "SOHLH2"         "CCDC169-SOHLH2" "CCDC169"        "SPART"
# [101] "NPIPA1"         "GDPD3"          "CORO6"          "TRIM37"

# %%
Aging3_gene
# Out:
#  [1] "SHTN1"           "SFXN4"           "WIF1"            "ACTR10"
#  [5] "ARMH4"           "CCDC175"         "MAPK3"           "CDC42EP3"
#  [9] "SPTBN1"          "EML6"            "VRK2"            "VEGFA"
# [13] "XKR6"            "RP1L1"           "FDFT1"           "FAM86B2"
# [17] "FAM167A"         "FAM86B1"         "MFHAS1"          "TUT7"
# [21] "ISCA1"           "MSRB3"           "ARID4A"          "PSMA3"
# [25] "MAP2K1"          "GDPD3"           "TBX6"            "TAOK2"
# [29] "PDF"             "KCNK2"           "ITCH"            "GGT7"
# [33] "RRP1B"           "MPPED1"          "BIN1"            "RSPO3"
# [37] "CENPW"           "TRIM26"          "KIAA0586"        "NCOA6"
# [41] "SOX7"            "HSPG2"           "CDC42"           "UGT2B7"
# [45] "ENO4"            "KDM2B"           "IRS2"            "SEZ6L2"
# [49] "ASPHD1"          "KCTD13"          "TMEM219"         "PTGES3L-AARSD1"
# [53] "ARHGAP27"        "PLEKHM1"         "LINC02210-CRHR1" "CRHR1"
# [57] "SPPL2C"          "MAPT"            "STH"             "KANSL1"
# [61] "ARL17B"          "LRRC37A"         "LRRC37A2"        "ARL17A"
# [65] "NSF"             "AC005670.2"      "MAP1LC3A"        "TRPC4AP"
# [69] "DNAJC5"          "DDX17"           "FAM227A"         "CBY1"
# [73] "TOMM22"          "JOSD1"           "SUN2"            "HSF2BP"
# [77] "PDXK"

# %%
Aging4_gene
# Out:
#  [1] "STN1"           "TCF25"          "CDK10"          "MC1R"
#  [5] "SSH2"           "NMT1"           "DCAKD"          "SMARCD2"
#  [9] "KPNA2"          "RPRD1A"         "ATP9B"          "UPK1A"
# [13] "COX6B1"         "PROSER3"        "KMT2B"          "TAF13"
# [17] "CFAP74"         "RAB29"          "SLC41A1"        "PM20D1"
# [21] "IRF2BP2"        "WDR75"          "SHPRH"          "BRAF"
# [25] "STK17A"         "MAL2"           "PURG"           "ANGPT2"
# [29] "IFIT1B"         "EVI2A"          "ATAD3A"         "AVPR1B"
# [33] "RAB7B"          "KCNK2"          "GGPS1"          "KHK"
# [37] "IQCJ-SCHIP1"    "PRPF4B"         "TOX3"           "SLC26A9"
# [41] "CTSE"           "RHEX"           "ERO1B"          "GFM1"
# [45] "AP3B1"          "BMP6"           "TXNDC5"         "BLOC1S5-TXNDC5"
# [49] "SUPT3H"         "AMZ1"           "GNA12"          "ENPP2"
# [53] "FAT3"           "SLC36A4"        "TCF7L2"         "NABP2"
# [57] "ANKRD52"        "COQ10A"         "CS"             "CNPY2"
# [61] "PAN2"           "IL23A"          "STAT2"          "BPTF"
# [65] "TPGS2"          "KIAA1328"       "ZBTB32"         "COQ8B"

# %%
Aging5_gene
# Out:
#   [1] "SH3PXD2A"    "ARL3"        "CNNM2"       "WBP1L"       "BORCS7"
#   [6] "TRIM8"       "AS3MT"       "OAF"         "ARHGEF12"    "FADS1"
#  [11] "AKIP1"       "SCUBE2"      "MMP17"       "TMEM101"     "DUSP3"
#  [16] "WNT3"        "ATP5MC1"     "UBE2Z"       "LRRC37A"     "ARL17A"
#  [21] "MAPT"        "ARL17B"      "LRRC37A2"    "CYGB"        "ZNF568"
#  [26] "ZNF260"      "TIMM50"      "LGALS4"      "CAPN12"      "C5AR1"
#  [31] "ARNT"        "RBBP5"       "DSTYK"       "TMCC2"       "TMEM81"
#  [36] "CNTN2"       "C1QB"        "TRIOBP"      "RIBC2"       "LIMS1"
#  [41] "RGPD4"       "NOP58"       "CARF"        "WDR12"       "NBEAL1"
#  [46] "ICA1L"       "RAPH1"       "KIAA2012"    "TRIM38"      "H4C8"
#  [51] "H1-2"        "H4C3"        "H4C2"        "BTN3A3"      "BTN2A1"
#  [56] "BTN2A2"      "BTN3A2"      "ZKSCAN3"     "ZKSCAN8"     "ZSCAN31"
#  [61] "AL021997.2"  "ZSCAN23"     "PPP1R11"     "HLA-G"       "HLA-A"
#  [66] "FLOT1"       "VARS2"       "MICB"        "HLA-C"       "CCHCR1"
#  [71] "PSORS1C1"    "MRPS18B"     "DDR1"        "ATP6V1G2"    "TRIM26"
#  [76] "SKIV2L"      "EHMT2"       "HSPA1A"      "MPIG6B"      "GPANK1"
#  [81] "BAG6"        "ATF6B"       "CLIC1"       "C4B"         "CYP21A2"
#  [86] "C4A"         "MSH5-SAPCD1" "HLA-DRB1"    "HLA-DRA"     "NOTCH4"
#  [91] "BRD2"        "HLA-DMA"     "TAP2"        "PSMB9"       "TMEM140"
#  [96] "GNA12"       "AMZ1"        "CARD11"      "DSCC1"       "CYP17A1"
# [101] "BTRC"        "LDB1"        "COL17A1"     "CALHM2"      "GOSR2"
# [106] "SNF8"        "PSG9"        "EPC2"        "FAM117B"     "BMPR2"
# [111] "U2SURP"      "H3C1"        "HFE"         "IER3"        "PRRC2A"
# [116] "CUTA"        "SNX8"        "TNFRSF11B"   "SVEP1"       "TLCD5"
# [121] "PLEKHM1"     "PSG8"        "PRSS16"      "ZKSCAN4"     "SULT1C4"
# [126] "GCC2"        "RANBP2"      "NUP210"      "NR2C2"       "RARB"
# [131] "CCDC12"      "NBEAL2"      "SCAP"        "ELP6"        "STIMATE"
# [136] "EPHA3"       "TRIM31"      "VWA7"        "TNXB"        "FUT9"
# [141] "UFL1"        "FHL5"        "CENPW"       "DENND2B"     "TMEM9B"
# [146] "IRAG1"       "MYRF"        "TMEM258"     "FADS2"       "MARK2"
# [151] "SYNPO2L"     "VCL"         "ADK"         "NT5C2"       "RHBDF1"
# [156] "VPS9D1"      "EFCAB13"     "LRRC46"      "TTLL6"       "CALCOCO2"
# [161] "SEPTIN9"     "CCDC9"       "FAM118A"

# %%
intersect(AD$gene_name, AD1$gene_name)
# Out:
#  [1] "AGBL4"    "CDC42EP3" "GCC2"     "ARL4C"    "NBEAL2"   "SETD2"
#  [7] "CSPG5"    "SMARCC1"  "MAP4"     "PLXNB1"   "KIF13A"   "AMZ1"
# [13] "EGFR"     "MFHAS1"   "TNKS"     "XKR6"     "CTSB"     "ANK1"
# [19] "ENPP2"    "DEPTOR"   "MFSD13A"  "ACTR1A"   "SUFU"     "TRIM8"
# [25] "STN1"     "ARHGAP9"  "KDM2B"    "ACTR10"   "DAAM1"    "CCDC175"
# [31] "EML1"     "SSH2"     "MAPT"     "UQCC1"    "PI4KA"

# %%
intersect(AD$gene_name, AD2$gene_name)
# Out:
#  [1] "ATAD3A"         "TCEA3"          "ASAP3"          "FAF1"
#  [5] "SPTBN1"         "TANK"           "TTLL4"          "SPEG"
#  [9] "DIS3L2"         "ECEL1"          "MAST4"          "TNIP1"
# [13] "CYFIP2"         "TMEM170B"       "FILIP1"         "CCM2"
# [17] "TBRG4"          "PINX1"          "SEMA4D"         "ATG13"
# [21] "CKAP5"          "LRP4"           "C11orf49"       "NR1H3"
# [25] "CTNND1"         "TMEM109"        "ANKRD52"        "AC078815.1"
# [29] "LEMD3"          "FBXW8"          "TESC"           "NOS1"
# [33] "SOHLH2"         "CCDC169-SOHLH2" "CCDC169"        "SPART"
# [37] "GDPD3"          "MAPK3"          "DHX8"           "RUNDC3A"
# [41] "FAM171A2"       "ITGA2B"         "NMT1"           "PLCD3"
# [45] "KANSL1"         "ARL17B"         "ARL17A"         "CCDC57"
# [49] "UQCC1"          "CEP250"         "ERGIC3"

# %%
intersect(AD$gene_name, Aging1$gene_name)
# Out:
#  [1] "PRKCZ"     "AGBL4"     "ZIC4"      "ZIC1"      "REST"      "POLR2B"
#  [7] "IGFBP7"    "AHRR"      "TULP4"     "TMEM181"   "SOD2"      "WTAP"
# [13] "AMZ1"      "STAG3"     "C7orf61"   "POLR2J3"   "DNAJC2"    "FAM160B2"
# [19] "SLC20A2"   "SMIM19"    "PDE3B"     "HPS5"      "GTF2H1"    "DSCAML1"
# [25] "SHTN1"     "CHPT1"     "WASHC3"    "PARPBP"    "WDHD1"     "KTN1"
# [31] "PELI2"     "EIF2B2"    "MLH3"      "ZC2HC1C"   "CCDC88C"   "NPIPA1"
# [37] "PDXDC1"    "NPIPA5"    "TNRC6A"    "SLC5A11"   "IL21R"     "EIF3C"
# [43] "SEZ6L2"    "SETD1A"    "PRSS36"    "SLC7A6OS"  "WWP2"      "COG4"
# [49] "VAC14"     "AKAP10"    "HELZ"      "KPNA2"     "ATP9B"     "ITPA"
# [55] "C20orf194" "PYGB"      "ABHD12"    "COX4I2"    "BCL2L1"    "DNAJC5"

# %%
intersect(AD$gene_name, Aging2$gene_name)
# Out:
#  [1] "FAAH"           "PDZK1IP1"       "FAF1"           "SLC35D1"
#  [5] "NAV1"           "ACVR2A"         "TANK"           "SLC4A10"
#  [9] "DOCK10"         "ARL4C"          "NFKB1"          "MAST4"
# [13] "TNIP1"          "TMEM170B"       "RPA3"           "NUP42"
# [17] "GPNMB"          "PLXNA4"         "XKR6"           "LHPP"
# [21] "ZRANB1"         "AC078815.1"     "WIF1"           "LEMD3"
# [25] "WASHC3"         "PARPBP"         "FBXW8"          "TESC"
# [29] "NOS1"           "SOHLH2"         "CCDC169-SOHLH2" "CCDC169"
# [33] "SPART"          "NPIPA1"         "SEZ6L2"         "ASPHD1"
# [37] "KCTD13"         "TMEM219"        "INO80E"         "DOC2A"
# [41] "TBX6"           "YPEL3"          "GDPD3"          "MAPK3"
# [45] "CORO6"          "SSH2"           "EFCAB5"         "BLMH"
# [49] "GOSR1"          "RHOT1"          "MAP3K14"        "PPM1E"
# [53] "TRIM37"         "BCL2L1"

# %%
intersect(AD$gene_name, Aging3$gene_name)
# Out:
#  [1] "HSPG2"    "CDC42"    "CDC42EP3" "SPTBN1"   "BIN1"     "MFHAS1"
#  [7] "XKR6"     "SHTN1"    "SFXN4"    "WIF1"     "KDM2B"    "ACTR10"
# [13] "CCDC175"  "MAP2K1"   "SEZ6L2"   "ASPHD1"   "KCTD13"   "TMEM219"
# [19] "TAOK2"    "TBX6"     "GDPD3"    "MAPK3"    "ARHGAP27" "PLEKHM1"
# [25] "MAPT"     "KANSL1"   "ARL17B"   "LRRC37A"  "LRRC37A2" "ARL17A"
# [31] "NSF"      "ITCH"     "MAP1LC3A" "NCOA6"    "TRPC4AP"  "DNAJC5"
# [37] "DDX17"    "FAM227A"  "CBY1"     "TOMM22"   "JOSD1"    "SUN2"
# [43] "MPPED1"   "RRP1B"

# %%
intersect(AD$gene_name, Aging4$gene_name)
# Out:
#  [1] "ATAD3A"      "CFAP74"      "PM20D1"      "WDR75"       "GFM1"
#  [6] "IQCJ-SCHIP1" "SUPT3H"      "SHPRH"       "AMZ1"        "BRAF"
# [11] "PURG"        "ENPP2"       "STN1"        "ANKRD52"     "TOX3"
# [16] "CDK10"       "TCF25"       "MC1R"        "SSH2"        "EVI2A"
# [21] "NMT1"        "DCAKD"       "BPTF"        "KPNA2"       "TPGS2"
# [26] "ATP9B"       "UPK1A"       "KMT2B"

# %%
intersect(AD$gene_name, Aging5$gene_name)
# Out:
#  [1] "ARNT"     "CNTN2"    "TMEM81"   "RBBP5"    "DSTYK"    "TMCC2"
#  [7] "RGPD4"    "SULT1C4"  "GCC2"     "LIMS1"    "EPC2"     "KIAA2012"
# [13] "NBEAL1"   "RAPH1"    "NUP210"   "RARB"     "NBEAL2"   "EPHA3"
# [19] "U2SURP"   "UFL1"     "FHL5"     "AMZ1"     "CARD11"   "SVEP1"
# [25] "AKIP1"    "TMEM9B"   "IRAG1"    "TMEM258"  "FADS2"    "OAF"
# [31] "LDB1"     "TRIM8"    "WBP1L"    "CYP17A1"  "BORCS7"   "AS3MT"
# [37] "SH3PXD2A" "VPS9D1"   "PLEKHM1"  "MAPT"     "ARL17B"   "LRRC37A"
# [43] "LRRC37A2" "ARL17A"   "WNT3"     "EFCAB13"  "CALCOCO2" "CCDC9"
# [49] "FAM118A"

# %%
intersect(TL1$gene_name, AD1$gene_name)
# Out:
#  [1] "CCDC12" "NBEAL2" "KLHL18" "SCAP"   "CSPG5"  "MON1A"  "KIF13A" "EGFR"
#  [9] "CTSB"   "SBSPON" "DEPTOR" "THNSL1" "ACTR1A" "STN1"   "CBX5"   "KDM2B"
# [17] "SSH2"   "MMP24"  "UQCC1"  "GDF5"   "LGALS1"

# %%
intersect(TL1$gene_name, AD2$gene_name)
# Out:
#  [1] "TCEA3"      "ASAP3"      "MAEL"       "SPTBN1"     "USP37"
#  [6] "CNOT9"      "PLCD4"      "TTLL4"      "TMEM170B"   "BTN3A3"
# [11] "ZNF322"     "ZKSCAN8"    "AL021997.2" "ZSCAN31"    "ZKSCAN3"
# [16] "ZSCAN23"    "ZNF311"     "TRIM26"     "FLOT1"      "VARS2"
# [21] "C4A"        "C4B"        "ATF6B"      "TRMT11"     "CCM2"
# [26] "TBRG4"      "TES"        "SEMA4D"     "MDK"        "C11orf49"
# [31] "NR1H3"      "TMEM109"    "XPOT"       "AC078815.1" "SOHLH2"
# [36] "CCDC169"    "DHX8"       "HDAC5"      "FAM171A2"   "ARL17B"
# [41] "ARL17A"     "MMP24"      "UQCC1"      "GDF5"

# %%
intersect(TL1$gene_name, Aging1$gene_name)
# Out:
#  [1] "ABI2"      "REST"      "POLR2B"    "SEC31A"    "AHRR"      "H4C8"
#  [7] "HLA-G"     "HLA-A"     "HLA-B"     "PRRC2A"    "COL21A1"   "SOD2"
# [13] "WTAP"      "MRPL18"    "PILRA"     "ZCWPW1"    "MEPCE"     "C7orf61"
# [19] "POLR2J3"   "PDE3B"     "GTF2H1"    "WDHD1"     "MAPK1IP1L" "FBXO34"
# [25] "CCDC88C"   "PDXDC1"    "NPIPA5"    "SLC5A11"   "NPIPB7"    "CLN3"
# [31] "NUPR1"     "SGF29"     "SULT1A1"   "EIF3C"     "TUFM"      "LAT"
# [37] "PRSS36"    "SLC7A6OS"  "NOB1"      "WWP2"      "COG4"      "SF3B3"
# [43] "VAC14"     "ZNRF1"     "SRR"       "PYGB"      "ABHD12"    "HM13"
# [49] "DNAJC5"    "DYRK1B"

# %%
intersect(TL1$gene_name, Aging2$gene_name)
# Out:
#  [1] "FAAH"       "MAEL"       "MSH6"       "SLC4A10"    "DOCK10"
#  [6] "NFKB1"      "TMEM170B"   "TRMT11"     "RSPO3"      "FAM126A"
# [11] "KLHL7"      "NUP42"      "GPNMB"      "NACAD"      "MDK"
# [16] "SYT10"      "XPOT"       "AC078815.1" "HELB"       "SOHLH2"
# [21] "CCDC169"    "CORO6"      "SSH2"       "GOSR1"      "LRRC37B"
# [26] "RHOT1"      "MTMR4"      "PPM1E"      "TRIM37"     "HLCS"

# %%
intersect(TL1$gene_name, Aging3$gene_name)
# Out:
#  [1] "SPTBN1"   "EML6"     "TRIM26"   "RSPO3"    "TUT7"     "KDM2B"
#  [7] "ARL17B"   "LRRC37A"  "LRRC37A2" "ARL17A"   "NSF"      "ITCH"
# [13] "MAP1LC3A" "NCOA6"    "GGT7"     "TRPC4AP"  "DNAJC5"   "DDX17"
# [19] "FAM227A"  "CBY1"     "TOMM22"   "JOSD1"

# %%
intersect(TL1$gene_name, Aging4$gene_name)
# Out:
# [1] "SLC26A9"     "GGPS1"       "WDR75"       "IQCJ-SCHIP1" "SUPT3H"
# [6] "PURG"        "STN1"        "SSH2"        "DCAKD"

# %%
intersect(TL1$gene_name, Aging5$gene_name)
# Out:
#  [1] "ARNT"       "CNTN2"      "DSTYK"      "KIAA2012"   "NOP58"
#  [6] "NBEAL1"     "RAPH1"      "CCDC12"     "NBEAL2"     "SCAP"
# [11] "STIMATE"    "H4C2"       "H1-2"       "H4C8"       "BTN3A2"
# [16] "BTN3A3"     "PRSS16"     "ZKSCAN8"    "AL021997.2" "ZSCAN31"
# [21] "ZKSCAN3"    "ZSCAN23"    "HLA-G"      "HLA-A"      "PPP1R11"
# [26] "TRIM26"     "FLOT1"      "VARS2"      "PSORS1C1"   "HLA-C"
# [31] "MICB"       "ATP6V1G2"   "PRRC2A"     "BAG6"       "GPANK1"
# [36] "MPIG6B"     "CLIC1"      "EHMT2"      "C4A"        "C4B"
# [41] "TNXB"       "ATF6B"      "NOTCH4"     "TAP2"       "HLA-DMA"
# [46] "BRD2"       "FUT9"       "UFL1"       "FHL5"       "MYRF"
# [51] "TMEM258"    "FADS2"      "FADS1"      "MARK2"      "BTRC"
# [56] "AS3MT"      "CNNM2"      "NT5C2"      "SH3PXD2A"   "COL17A1"
# [61] "ARL17B"     "LRRC37A"    "LRRC37A2"   "ARL17A"     "UBE2Z"
# [66] "SNF8"       "ZNF260"     "CAPN12"     "TRIOBP"     "FAM118A"
# [71] "RIBC2"

# %%
intersect(AD1$gene_name, TL1$gene_name)
# Out:
#  [1] "STN1"   "ACTR1A" "SSH2"   "UQCC1"  "GDF5"   "MMP24"  "LGALS1" "SCAP"
#  [9] "NBEAL2" "CTSB"   "DEPTOR" "CBX5"   "KLHL18" "CCDC12" "MON1A"  "CSPG5"
# [17] "KIF13A" "EGFR"   "SBSPON" "THNSL1" "KDM2B"

# %%
intersect(AD1_gene, Aging1_gene)
# Out:
# [1] "AGBL4" "NINL"  "AMZ1"  "GNA12"

# %%
intersect(AD1_gene, Aging2_gene)
# Out:
# [1] "SSH2"    "XKR6"    "RP1L1"   "FAM86B2" "FAM167A" "SOX7"    "ARL4C"

# %%
intersect(AD1_gene, Aging3_gene)
# Out:
#  [1] "ACTR10"   "ARMH4"    "CCDC175"  "MAPT"     "CDC42EP3" "XKR6"
#  [7] "RP1L1"    "FDFT1"    "FAM86B2"  "FAM167A"  "FAM86B1"  "MFHAS1"
# [13] "ARID4A"   "PSMA3"    "KIAA0586" "SOX7"     "UGT2B7"   "KDM2B"

# %%
intersect(AD1_gene, Aging4_gene)
# Out:
# [1] "STN1"  "SSH2"  "ENPP2" "AMZ1"  "GNA12"

# %%
intersect(AD1_gene, Aging5_gene)
# Out:
#  [1] "ARL3"   "TRIM8"  "MAPT"   "GCC2"   "SCAP"   "NBEAL2" "CCDC12" "ELP6"
#  [9] "AMZ1"   "GNA12"

# %%
intersect(Aging3_gene, Aging5_gene)
# Out:
# [1] "CENPW"    "TRIM26"   "PLEKHM1"  "MAPT"     "ARL17B"   "LRRC37A"  "LRRC37A2"
# [8] "ARL17A"

# %% [markdown]
# CENPV is deubiquitylated by CYLD and localizes in interphase to primary cilia where it increases the ciliary levels of acetylated α-tubulin.
# Cenpj, a protein that is required for centriole biogenesis, plays a role in regulating cilium disassembly in vivo..
# CENPW's role in cillia is less direct and well-characterized.

# %%
intersect(AD1_gene, AD2_gene)
# Out:
# [1] "UQCC1" "GDF5"  "MMP24"

# %% [markdown]
# no overlap between AD2 and image_Aging1, Aging3 or Aging5

# %%
intersect(Aging1_gene, AD2_gene)
# Out:
# character(0)

# %%
intersect(Aging2_gene, AD2_gene)
# Out:
#  [1] "MDK"            "TESC"           "NOS1"           "TBC1D30"
#  [5] "LEMD3"          "XPOT"           "AC078815.1"     "MAPK3"
#  [9] "MAEL"           "FAF1"           "TRMT11"         "FBXW8"
# [13] "PAN2"           "MSRB3"          "TANK"           "TNIP1"
# [17] "VCAN"           "TMEM170B"       "MAST4"          "SOHLH2"
# [21] "CCDC169-SOHLH2" "CCDC169"        "SPART"          "GDPD3"

# %% [markdown]
# Loss-of-function mutations in the SPART gene cause Troyer syndrome, a recessive form of spastic paraplegia resulting in muscle weakness, short stature, and cognitive defects. SPART encodes for Spartin, a protein linked to endosomal trafficking and mitochondrial membrane potential maintenance. Here, we identified with whole exome sequencing (WES) a novel frameshift mutation in the SPART gene in 2 brothers presenting an uncharacterized developmental delay and short stature. Functional characterization in an SH-SY5Y cell model shows that this mutation is associated with increased neurite outgrowth. These cells also show a marked decrease in mitochondrial complex I (NADH dehydrogenase) activity, coupled to decreased ATP synthesis and defective mitochondrial membrane potential. The cells also presented an increase in reactive oxygen species, extracellular pyruvate, and NADH levels, consistent with impaired complex I activity. In concordance with a severe mitochondrial failure, Spartin loss also led to an altered intracellular Ca2+ homeostasis that was restored after transient expression of wild-type Spartin.

# %%
intersect(Aging3_gene, AD2_gene)
# Out:
# [1] "MAPK3"  "SPTBN1" "MSRB3"  "GDPD3"  "TRIM26" "KANSL1" "ARL17B" "ARL17A"

# %%
intersect(Aging4_gene, AD2_gene)
# Out:
#  [1] "NMT1"    "ATAD3A"  "ERO1B"   "AP3B1"   "NABP2"   "ANKRD52" "COQ10A"
#  [8] "CS"      "CNPY2"   "PAN2"    "IL23A"   "STAT2"

# %%
AD2_Aging5_gene = intersect(Aging5_gene, AD2_gene)
intersect(AD2_Aging5_gene, TL1_gene)
# Out:
#  [1] "ARL17A"     "ARL17B"     "BTN3A3"     "ZKSCAN3"    "ZKSCAN8"
#  [6] "ZSCAN31"    "AL021997.2" "ZSCAN23"    "FLOT1"      "VARS2"
# [11] "TRIM26"     "ATF6B"      "C4B"        "C4A"

# %%
intersect(Aging3_gene, Aging1_gene)
# Out:
# [1] "SHTN1"  "CENPW"  "ENO4"   "SEZ6L2" "DNAJC5"

# %%
library(UpSetR)
# Create named list of gene sets
gene_sets <- list(
  "AD1" = AD1_gene,
  "AD2" = AD2_gene, 
  "Aging1" = Aging1_gene,
  "Aging2" = Aging2_gene,
  "Aging3" = Aging3_gene,
  "Aging4" = Aging4_gene,
  "Aging5" = Aging5_gene
  # "AD" = AD_gene,
  # "Telomere_Length_PC1" = TL1_gene
  # "mvAge" = mvAge_gene,
  # "PD" = PD_gene
)

# Remove any NA values
gene_sets <- lapply(gene_sets, function(x) x[!is.na(x)])
# Convert to binary matrix for UpSet plot
all_genes <- unique(unlist(gene_sets))
upset_data <- data.frame(gene = all_genes)

for(set_name in names(gene_sets)) {
  upset_data[[set_name]] <- upset_data$gene %in% gene_sets[[set_name]]
}
str(gene_sets)
# Convert to proper format for UpSetR
upset_r_data <- upset_data
# Remove the 'gene' column and convert to 0/1 instead of TRUE/FALSE
upset_r_data <- upset_r_data[, -1]  # Remove gene column
upset_r_data <- as.data.frame(lapply(upset_r_data, as.numeric))

# Add row names if needed
rownames(upset_r_data) <- upset_data$gene

# Create UpSetR plot with proper error handling
tryCatch({
  upset_r_plot <- upset(upset_r_data, 
                       sets = names(gene_sets),
                       order.by = "freq",
                       decreasing = TRUE,
                       mb.ratio = c(0.6, 0.4),
                       number.angles = 0,
                       text.scale = 1.2,
                       point.size = 3,
                       line.size = 1.5,
                       mainbar.y.label = "Intersection Size",
                       sets.x.label = "Gene Set Size",
                       sets.bar.color = "steelblue",
                       main.bar.color = "darkblue")
  
  cat("UpSetR plot created successfully\n")
}, error = function(e) {
  cat("UpSetR failed, using alternative method\n")
  
  # Alternative: Create a simple intersection matrix
  intersection_matrix <- matrix(0, nrow = length(unique(DNE$gene_name)), ncol = length(gene_sets))
  rownames(intersection_matrix) <- unique(DNE$gene_name)
  colnames(intersection_matrix) <- names(gene_sets)
  
  for(i in 1:length(gene_sets)) {
    intersection_matrix[unique(DNE$gene_name) %in% gene_sets[[i]], i] <- 1
  }
  
  print(head(intersection_matrix))
})
# Out:
# List of 7
#  $ AD1   : chr [1:85] "SUFU" "STN1" "ACTR1A" "MFSD13A" ...
#  $ AD2   : chr [1:124] "MDK" "C11orf49" "PACSIN3" "TMEM109" ...
#  $ Aging1: chr [1:137] "PDE3B" "NUP37" "CHPT1" "KTN1" ...
#  $ Aging2: chr [1:104] "ZRANB1" "LHPP" "EEF1AKMT2" "WAC" ...
#  $ Aging3: chr [1:77] "SHTN1" "SFXN4" "WIF1" "ACTR10" ...
#  $ Aging4: chr [1:68] "STN1" "TCF25" "CDK10" "MC1R" ...
#  $ Aging5: chr [1:163] "SH3PXD2A" "ARL3" "CNNM2" "WBP1L" ...
# UpSetR plot created successfully

# %%
png("~/xqtl-analysis/production/image_QTL/interested_genes/TWAS_QTL/manual_cTWAS_QTL_gene/DNE_gene_overlap_upset_plot.png", width = 12, height = 8, units = "in", res = 300)
print(upset_r_plot)
dev.off()
# Out:
# agg_record_2083461291
#                     2
