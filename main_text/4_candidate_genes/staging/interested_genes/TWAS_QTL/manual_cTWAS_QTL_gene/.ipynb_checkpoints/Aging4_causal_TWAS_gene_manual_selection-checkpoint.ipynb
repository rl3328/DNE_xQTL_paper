# %% [markdown]
# # Manually Selection of the Most Likely Causal Genes from Significant TWAS Genes
#
# ## Aim
#
# Genomewide MR was skipped due to missing `MAF` column in the imputed GWAS sumstats, and our [TWAS pipeline](https://github.com/rl3328/xqtl-protocol/blob/main/code/pecotmr_integration/twas_ctwas.ipynb) runs TWAS and MR in the same step (`twas`). This notebook serves as a quick rescue to manually diminish noise from LD hitchhiking and identify the most likely causal genes.
#
#
#
# ## Steps
#
# ### 1. Filter genes qualified for MR analysis
#
# Most thresholds follow the default requirements in \[`twas`], except I use a stricter `twas_pval` cutoff. The reason is that I want to directly apply the filter to “significant” TWAS genes in my manuscript while also saving resources.
#
# **Criteria:**
#
# 1. Strong and reliable TWAS signals:
#
#    * `twas_pval < 2.5*1e-6`
#    * `rsq_cv > 0.01`
#    * `rsq_pval < 0.05`
# 2. Strong GWAS signals:
#
#    * Have `CS`, which can be extracted from `twas_weight(.rds)` files
#
# ### 2. Manually select the most likely causal gene
#
# Within each LD block and by context, I define the gene with the strongest GWAS signal as follows:
#
# * For each gene–context combination:
#
#   * If no credible set (CS) is available, skip (this corresponds to filtering step 1.2).
#   * If a 95% CS exists, select the gene containing the variant with the highest PIP within the 95% CS. If not, fall back to 70% CS.
#   * If a 70% CS exists, select the gene containing the variant with the highest PIP within the 70% CS. If not, fall back to 50% CS.
#   * If a 50% CS exists, select the gene containing the variant with the highest PIP within the 50% CS.
#
#
#
# ## Note
#
# There are some differences between this identification and the [loose gene list](https://github.com/rl3328/xqtl-analysis/blob/main/production/image_QTL/interested_genes/TWAS_QTL/loose_gene/image_Aging4_gene_list.tsv).
#
# * Loose list: 42 genes, filtered by `is_selected_method` and `twas_pval < 2.5*1e-6`
# * Current identification: 443 genes are strong TWAS genes(twas_pval < 2.5*1e-6 & rsq_cv > 0.01 & pval_cv < 0.05) for Aging4 and Knight cohort, 48 genes were identified as the final list.
#
#
#
# ## Input
#
# 1. **Merged TWAS results** (`*.twas.tsv.gz`):
#
#    * `s3://statfungen/ftp_fgc_xqtl/interactive_analysis/rl3328/image_QTL/twas/image_Aging4_twas_merged.tsv.gz.combined_twas.tsv.gz`
# 2. **xQTL\_meta\_file** (meta file specifying TWAS weight paths by cohort):
#
#    * `s3://statfungen/ftp_fgc_xqtl/interactive_analysis/cl4215/KNIGHT_eQTL_pQTL_twas_wgw_xqtl_meta_data.tsv`
#
#
# ## Plan
#
# Other GWAS studies and other cohorts will be analyzed in the same way.

# %%
library(data.table)
library(tidyverse)
library(pecotmr)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.2     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::between()     masks data.table::between()
# ✖ dplyr::filter()      masks stats::filter()
# ✖ dplyr::first()       masks data.table::first()
# ✖ lubridate::hour()    masks data.table::hour()
# ✖ lubridate::isoweek() masks data.table::isoweek()
# ✖ dplyr::lag()         masks stats::lag()
# ✖ dplyr::last()        masks data.table::last()
# ✖ lubridate::mday()    masks data.table::mday()
# ✖ lubridate::minute()  masks data.table::minute()
# ✖ lubridate::month()   masks data.table::month()
# ✖ lubridate::quarter() masks data.table::quarter()
# ✖ lubridate::second()  masks data.table::second()
# ✖ purrr::transpose()   masks data.table::transpose()
# ✖ lubridate::wday()    masks data.table::wday()
# ✖ lubridate::week()    masks data.table::week()
# ✖ lubridate::yday()    masks data.table::yday()
# ✖ lubridate::year()    masks data.table::year()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Warning message:
# “replacing previous import ‘vroom::cols’ by ‘readr::cols’ when loading ‘pecotmr’”

# %%
setwd("~/data")

# %%
##Bonfferroni correction is too strict
# Aging4_twas = fread("~/project/image_QTL/twas/multiple_testing/image_Aging4_twas_bonff.bonf_corrected.tsv.gz")

# %%
Aging4_twas = fread("~/project/image_QTL/twas/image_Aging4_twas_merged.tsv.gz.combined_twas.tsv.gz")

# %%
# weight_db_list = fread("~/data/interactive_analysis/cl4215/KNIGHT_eQTL_pQTL_twas_wgw_xqtl_meta_data.tsv")
# weight_db_list = fread("~/project/image_QTL/twas/MSBB_eQTL_pQTL_twas_wgw_xqtl_meta_data.tsv")
# weight_db_list = fread("~/data/interactive_analysis/cl4215/ROSMAP_twas_wgw_xqtl_meta_data.tsv")
# weight_db_list = fread("~/data/interactive_analysis/cl4215/ROSMAP_mega_twas_wgw_xqtl_meta_data.tsv")

# %%
# No gene presents in multiple blocks
genes_in_multiple_blocks <- Aging4_twas %>% group_by(molecular_id) %>% summarise(
    number_of_blocks = n_distinct(block)) %>%
    filter(number_of_blocks > 1)

print(genes_in_multiple_blocks)
# Out:
# # A tibble: 0 × 2
# # ℹ 2 variables: molecular_id <chr>, number_of_blocks <int>

# %%
head(Aging4_twas)
dim(Aging4_twas)
# Out:
#   chr molecular_id    TSS       start     end       context
# 1 10  ENSG00000055950 100987514  99320000 102120000 Knight_eQTL_brain
# 2 10  ENSG00000055950 100987514  99320000 102120000 Knight_eQTL_brain
# 3 10  ENSG00000055950 100987514  99320000 102120000 Knight_eQTL_brain
# 4 10  ENSG00000055950 100987514  99320000 102120000 Knight_eQTL_brain
# 5 10  ENSG00000059915 102421538 101402617 103680000 Knight_eQTL_brain
# 6 10  ENSG00000059915 102421538 101402617 103680000 Knight_eQTL_brain
#   gwas_study   method is_imputable is_selected_method rsq_cv      pval_cv
# 1 image_Aging4 enet   TRUE         FALSE              0.098757440 8.923911e-10
# 2 image_Aging4 lasso  TRUE         FALSE              0.103370596 3.541036e-10
# 3 image_Aging4 mrash  TRUE         FALSE              0.089177838 6.013310e-09
# 4 image_Aging4 susie  TRUE          TRUE              0.121638427 8.766557e-12
# 5 image_Aging4 enet   TRUE         FALSE              0.007872702 5.201216e-02
# 6 image_Aging4 lasso  TRUE         FALSE              0.006195072 7.447581e-02
#   twas_z    twas_pval   type block
# 1 -2.925529 0.003438716 eQTL chr10_100331627_104378781
# 2 -2.953063 0.003146377 eQTL chr10_100331627_104378781
# 3 -2.792398 0.005231890 eQTL chr10_100331627_104378781
# 4 -2.932920 0.003357909 eQTL chr10_100331627_104378781
# 5  1.188241 0.234738536 eQTL chr10_100331627_104378781
# 6  1.045410 0.295833712 eQTL chr10_100331627_104378781
#   region                    study_context
# 1 chr10_100331627_104378781 KNIGHT_eQTL_pQTL
# 2 chr10_100331627_104378781 KNIGHT_eQTL_pQTL
# 3 chr10_100331627_104378781 KNIGHT_eQTL_pQTL
# 4 chr10_100331627_104378781 KNIGHT_eQTL_pQTL
# 5 chr10_100331627_104378781 KNIGHT_eQTL_pQTL
# 6 chr10_100331627_104378781 KNIGHT_eQTL_pQTL
#   source_file
# 1 KNIGHT_eQTL_pQTL.chr10_100331627_104378781.twas.tsv.gz
# 2 KNIGHT_eQTL_pQTL.chr10_100331627_104378781.twas.tsv.gz
# 3 KNIGHT_eQTL_pQTL.chr10_100331627_104378781.twas.tsv.gz
# 4 KNIGHT_eQTL_pQTL.chr10_100331627_104378781.twas.tsv.gz
# 5 KNIGHT_eQTL_pQTL.chr10_100331627_104378781.twas.tsv.gz
# 6 KNIGHT_eQTL_pQTL.chr10_100331627_104378781.twas.tsv.gz
# [1] 928827     19

# %%
# Strong and reliable TWAS signals:
Aging4_twas_filtered <- Aging4_twas |>
    filter(
        twas_pval < 2.5*1e-6 &     # Stricter p-value threshold 
        rsq_cv > 0.01 &          # Cross-validation R²
        pval_cv < 0.05          # R² significance
    )
Aging4_block = unique(Aging4_twas_filtered$block)

# %%
dim(Aging4_twas_filtered)
# Out:
# [1] 255  19

# %%
most_likely_causal_genes = Aging4_twas_filtered |> 
  group_by(context, region) |> 
  slice_max(twas_z, n = 1)

# %%
head(most_likely_causal_genes)
dim(most_likely_causal_genes)
# Out:
#   chr molecular_id    TSS       start     end       context
# 1 16  ENSG00000258839  89913417  85040000  90338345 AC_DeJager_eQTL
# 2 17  ENSG00000141298  29930275  28360000  32440000 AC_DeJager_eQTL
# 3 17  ENSG00000136448  44957991  42560000  46680000 AC_DeJager_eQTL
# 4 19  ENSG00000126267  35648322  32720000  43520000 AC_DeJager_eQTL
# 5  1  ENSG00000142609   2003836         0   6480000 AC_DeJager_eQTL
# 6  1  ENSG00000162877 205850131 201840000 206850132 AC_DeJager_eQTL
#   gwas_study   method  is_imputable is_selected_method rsq_cv     pval_cv
# 1 image_Aging4 mvsusie TRUE         FALSE              0.08744415 1.185243e-13
# 2 image_Aging4 lasso   TRUE          TRUE              0.10028261 1.687481e-15
# 3 image_Aging4 susie   TRUE         FALSE              0.18908461 5.732138e-29
# 4 image_Aging4 enet    TRUE         FALSE              0.23413037 2.390473e-36
# 5 image_Aging4 enet    TRUE         FALSE              0.08470651 2.915831e-13
# 6 image_Aging4 bayes_l TRUE         FALSE              0.33760717 4.702438e-55
#   twas_z    twas_pval    type block                    region
# 1  4.850124 1.233842e-06 eQTL chr16_88382277_90220225  chr16_88382277_90220225
# 2 -4.735719 2.182797e-06 eQTL chr17_27951253_31594410  chr17_27951253_31594410
# 3 -4.791365 1.656504e-06 eQTL chr17_42087601_45383525  chr17_42087601_45383525
# 4  4.829141 1.371233e-06 eQTL chr19_35206200_36997570  chr19_35206200_36997570
# 5 -4.895879 9.786749e-07 eQTL chr1_16103_2888443       chr1_16103_2888443
# 6  5.528340 3.232757e-08 eQTL chr1_204142966_205972031 chr1_204142966_205972031
#   study_context    source_file
# 1 ROSMAP_eQTL_pQTL ROSMAP_eQTL_pQTL.chr16_88382277_90220225.twas.tsv.gz
# 2 ROSMAP_eQTL_pQTL ROSMAP_eQTL_pQTL.chr17_27951253_31594410.twas.tsv.gz
# 3 ROSMAP_eQTL_pQTL ROSMAP_eQTL_pQTL.chr17_42087601_45383525.twas.tsv.gz
# 4 ROSMAP_eQTL_pQTL ROSMAP_eQTL_pQTL.chr19_35206200_36997570.twas.tsv.gz
# 5 ROSMAP_eQTL_pQTL ROSMAP_eQTL_pQTL.chr1_16103_2888443.twas.tsv.gz
# 6 ROSMAP_eQTL_pQTL ROSMAP_eQTL_pQTL.chr1_204142966_205972031.twas.tsv.gz
# [1] 82 19

# %%
most_likely_causal_genes |> count(molecular_id) |> nrow()
# Out:
# [1] 82

# %%
Aging4_gene = unique(most_likely_causal_genes$molecular_id)

# %%
image_Aging4_gene_list <- Aging4_twas |> 
  dplyr::filter(molecular_id %in% Aging4_gene) |> 
  dplyr::mutate(`#chr` = paste0("chr", chr), molecular_id = molecular_id) |> 
  dplyr::select(`#chr`, start, end, molecular_id) |> 
  unique()

# %%
dim(image_Aging4_gene_list)
# Out:
# [1] 41  4

# %%
DNE_QTL_gene = fread("~/project/image_QTL/twas/annotated_dne_gene.tsv")

# %%
image_Aging4_QTL_gene = DNE_QTL_gene |> filter(str_detect(event_ID, "image_Aging4")) |> dplyr::select(-strand,-event_ID)

# %%
image_Aging4_gene = bind_rows(image_Aging4_gene_list, image_Aging4_QTL_gene)

# %%
fwrite(image_Aging4_gene, "~/DNE_xQTL_paper/main_text/4_candidate_genes/staging/interested_genes/TWAS_QTL/manual_cTWAS_QTL_gene/image_Aging4_gene_list.tsv", sep = '\t')

# %% [markdown]
# ### image_Aging4_QTL list

# %%
library(clusterProfiler)
library(org.Hs.eg.db)
# Out:
# clusterProfiler v4.10.1  For help: https://yulab-smu.top/biomedical-knowledge-mining-book/
#
# If you use clusterProfiler in published research, please cite:
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal enrichment tool for interpreting omics data. The Innovation. 2021, 2(3):100141
#
#
# Attaching package: ‘clusterProfiler’
#
#
# The following object is masked from ‘package:purrr’:
#
#     simplify
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# Loading required package: AnnotationDbi
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:lubridate’:
#
#     intersect, setdiff, union
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: IRanges
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
#
# The following objects are masked from ‘package:lubridate’:
#
#     second, second<-
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# The following objects are masked from ‘package:data.table’:
#
#     first, second
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     I, expand.grid, unname
#
#
#
# Attaching package: ‘IRanges’
#
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# The following object is masked from ‘package:lubridate’:
#
#     %within%
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# The following object is masked from ‘package:purrr’:
#
#     reduce
#
#
# The following object is masked from ‘package:data.table’:
#
#     shift
#
#
#
# Attaching package: ‘AnnotationDbi’
#
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select

# %%
image_Aging4_gene = fread("~/DNE_xQTL_paper/main_text/4_candidate_genes/staging/interested_genes/TWAS_QTL/manual_cTWAS_QTL_gene/image_Aging4_gene_list.tsv")

# %%
Aging4_sig_gene_ego <- enrichGO(
  gene          = unique(image_Aging4_gene$molecular_id),
  OrgDb         = org.Hs.eg.db,
  keyType       = "ENSEMBL",
  ont           = "BP",
  pAdjustMethod = "BH",
  pvalueCutoff  = 1,
  qvalueCutoff  = 1
)

# %%
head(Aging4_sig_gene_ego, n=10)
# Out:
#            ID
# GO:2000279 GO:2000279
# GO:0016233 GO:0016233
# GO:0010639 GO:0010639
# GO:0002429 GO:0002429
# GO:0002752 GO:0002752
# GO:0009314 GO:0009314
# GO:0048678 GO:0048678
# GO:0002768 GO:0002768
# GO:0033044 GO:0033044
# GO:0002220 GO:0002220
#            Description
# GO:2000279 negative regulation of DNA biosynthetic process
# GO:0016233 telomere capping
# GO:0010639 negative regulation of organelle organization
# GO:0002429 immune response-activating cell surface receptor signaling pathway
# GO:0002752 cell surface pattern recognition receptor signaling pathway
# GO:0009314 response to radiation
# GO:0048678 response to axon injury
# GO:0002768 immune response-regulating cell surface receptor signaling pathway
# GO:0033044 regulation of chromosome organization
# GO:0002220 innate immune response activating cell surface receptor signaling pathway
#            GeneRatio BgRatio   pvalue      p.adjust  qvalue
# GO:2000279 2/39      41/21261  0.002569760 0.3183419 0.2935766
# GO:0016233 2/39      42/21261  0.002695131 0.3183419 0.2935766
# GO:0010639 4/39      405/21261 0.006304105 0.3183419 0.2935766
# GO:0002429 4/39      410/21261 0.006579296 0.3183419 0.2935766
# GO:0002752 2/39      74/21261  0.008148296 0.3183419 0.2935766
# GO:0009314 4/39      465/21261 0.010148833 0.3183419 0.2935766
# GO:0048678 2/39      84/21261  0.010396109 0.3183419 0.2935766
# GO:0002768 4/39      490/21261 0.012120256 0.3183419 0.2935766
# GO:0033044 3/39      280/21261 0.014561084 0.3183419 0.2935766
# GO:0002220 2/39      107/21261 0.016471299 0.3183419 0.2935766
#            geneID
# GO:2000279 ENSG00000107960/ENSG00000082482
# GO:0016233 ENSG00000107960/ENSG00000139579
# GO:0010639 ENSG00000107960/ENSG00000185324/ENSG00000141298/ENSG00000283154
# GO:0002429 ENSG00000117280/ENSG00000157764/ENSG00000126262/ENSG00000276600
# GO:0002752 ENSG00000126262/ENSG00000276600
# GO:0009314 ENSG00000258839/ENSG00000136448/ENSG00000157764/ENSG00000139579
# GO:0048678 ENSG00000157764/ENSG00000082482
# GO:0002768 ENSG00000117280/ENSG00000157764/ENSG00000126262/ENSG00000276600
# GO:0033044 ENSG00000107960/ENSG00000108604/ENSG00000139579
# GO:0002220 ENSG00000126262/ENSG00000276600
#            Count
# GO:2000279 2
# GO:0016233 2
# GO:0010639 4
# GO:0002429 4
# GO:0002752 2
# GO:0009314 4
# GO:0048678 2
# GO:0002768 4
# GO:0033044 3
# GO:0002220 2

# %%
barplot(Aging4_sig_gene_ego, showCategory = 10, title = "GO Enrichment - BP")
# Out:
# plot without title

# %%
Aging4_sig_gene_ego_cc <- enrichGO(
  gene          = unique(image_Aging4_gene$molecular_id),
  OrgDb         = org.Hs.eg.db,
  keyType       = "ENSEMBL",
  ont           = "CC",
  pAdjustMethod = "BH",
  pvalueCutoff  = 1,
  qvalueCutoff  = 1
)

# %%
head(Aging4_sig_gene_ego_cc, n=15)
# Out:
#            ID         Description                                  GeneRatio
# GO:0042564 GO:0042564 NLS-dependent protein nuclear import complex 1/41
# GO:0140092 GO:0140092 bBAF complex                                 1/41
# GO:0005802 GO:0005802 trans-Golgi network                          3/41
# GO:0000782 GO:0000782 telomere cap complex                         1/41
# GO:0000783 GO:0000783 nuclear telomere cap complex                 1/41
# GO:0031074 GO:0031074 nucleocytoplasmic transport complex          1/41
# GO:0097550 GO:0097550 transcription preinitiation complex          1/41
# GO:0140445 GO:0140445 chromosome, telomeric repeat region          1/41
# GO:0035060 GO:0035060 brahma complex                               1/41
# GO:0016586 GO:0016586 RSC-type complex                             1/41
# GO:0097449 GO:0097449 astrocyte projection                         1/41
# GO:0044305 GO:0044305 calyx of Held                                1/41
# GO:0043194 GO:0043194 axon initial segment                         1/41
# GO:0005751 GO:0005751 mitochondrial respiratory chain complex IV   1/41
# GO:0098687 GO:0098687 chromosomal region                           3/41
#            BgRatio   pvalue     p.adjust  qvalue
# GO:0042564 11/22568  0.01980785 0.3069229 0.2777856
# GO:0140092 11/22568  0.01980785 0.3069229 0.2777856
# GO:0005802 332/22568 0.02227434 0.3069229 0.2777856
# GO:0000782 13/22568  0.02336792 0.3069229 0.2777856
# GO:0000783 13/22568  0.02336792 0.3069229 0.2777856
# GO:0031074 13/22568  0.02336792 0.3069229 0.2777856
# GO:0097550 13/22568  0.02336792 0.3069229 0.2777856
# GO:0140445 14/22568  0.02514323 0.3069229 0.2777856
# GO:0035060 15/22568  0.02691538 0.3069229 0.2777856
# GO:0016586 16/22568  0.02868439 0.3069229 0.2777856
# GO:0097449 19/22568  0.03397261 0.3185845 0.2883401
# GO:0044305 20/22568  0.03572910 0.3185845 0.2883401
# GO:0043194 22/22568  0.03923274 0.3229157 0.2922601
# GO:0005751 26/22568  0.04620280 0.3235047 0.2927933
# GO:0098687 444/22568 0.04649286 0.3235047 0.2927933
#            geneID                                          Count
# GO:0042564 ENSG00000182481                                 1
# GO:0140092 ENSG00000108604                                 1
# GO:0005802 ENSG00000166377/ENSG00000117280/ENSG00000276600 3
# GO:0000782 ENSG00000107960                                 1
# GO:0000783 ENSG00000107960                                 1
# GO:0031074 ENSG00000182481                                 1
# GO:0097550 ENSG00000141425                                 1
# GO:0140445 ENSG00000107960                                 1
# GO:0035060 ENSG00000108604                                 1
# GO:0016586 ENSG00000108604                                 1
# GO:0097449 ENSG00000082482                                 1
# GO:0044305 ENSG00000082482                                 1
# GO:0043194 ENSG00000283154                                 1
# GO:0005751 ENSG00000126267                                 1
# GO:0098687 ENSG00000107960/ENSG00000108604/ENSG00000139579 3

# %%
barplot(Aging4_sig_gene_ego_cc, showCategory = 10, title = "GO Enrichment - CC")
# Out:
# plot without title

# %%
image_Aging4_sig_gene_ego_mf <- enrichGO(
  gene          = unique(image_Aging4_gene$molecular_id),
  OrgDb         = org.Hs.eg.db,
  keyType       = "ENSEMBL",
  ont           = "MF",
  pAdjustMethod = "BH",
  pvalueCutoff  = 1,
  qvalueCutoff  = 1
)

# %%
head(image_Aging4_sig_gene_ego_mf, n=10)
# Out:
#            ID         Description                                   GeneRatio
# GO:0043047 GO:0043047 single-stranded telomeric DNA binding         2/40
# GO:0098847 GO:0098847 sequence-specific single stranded DNA binding 2/40
# GO:0042162 GO:0042162 telomeric DNA binding                         2/40
# GO:0106310 GO:0106310 protein serine kinase activity                4/40
# GO:0004674 GO:0004674 protein serine/threonine kinase activity      4/40
# GO:0045322 GO:0045322 unmethylated CpG binding                      1/40
# GO:0098505 GO:0098505 G-rich strand telomeric DNA binding           1/40
# GO:0099122 GO:0099122 RNA polymerase II C-terminal domain binding   1/40
# GO:0019107 GO:0019107 myristoyltransferase activity                 1/40
# GO:0019911 GO:0019911 structural constituent of myelin sheath       1/40
#            BgRatio   pvalue       p.adjust   qvalue
# GO:0043047 12/21059  0.0002293973 0.02272727 0.01818182
# GO:0098847 15/21059  0.0003636363 0.02272727 0.01818182
# GO:0042162 40/21059  0.0026214417 0.10922674 0.08738139
# GO:0106310 377/21059 0.0055568387 0.17365121 0.13892097
# GO:0004674 467/21059 0.0116167425 0.18974280 0.15179424
# GO:0045322 10/21059  0.0188367132 0.18974280 0.15179424
# GO:0098505 10/21059  0.0188367132 0.18974280 0.15179424
# GO:0099122 10/21059  0.0188367132 0.18974280 0.15179424
# GO:0019107 11/21059  0.0207012451 0.18974280 0.15179424
# GO:0019911 11/21059  0.0207012451 0.18974280 0.15179424
#            geneID
# GO:0043047 ENSG00000107960/ENSG00000139579
# GO:0098847 ENSG00000107960/ENSG00000139579
# GO:0042162 ENSG00000107960/ENSG00000139579
# GO:0106310 ENSG00000185324/ENSG00000157764/ENSG00000164543/ENSG00000112739
# GO:0004674 ENSG00000185324/ENSG00000157764/ENSG00000164543/ENSG00000112739
# GO:0045322 ENSG00000272333
# GO:0098505 ENSG00000139579
# GO:0099122 ENSG00000141425
# GO:0019107 ENSG00000136448
# GO:0019911 ENSG00000147676
#            Count
# GO:0043047 2
# GO:0098847 2
# GO:0042162 2
# GO:0106310 4
# GO:0004674 4
# GO:0045322 1
# GO:0098505 1
# GO:0099122 1
# GO:0019107 1
# GO:0019911 1

# %%
barplot(image_Aging4_sig_gene_ego_mf, showCategory = 10, title = "GO Enrichment - MF")
# Out:
# plot without title

# %%
entrez_ids <- bitr(image_Aging4_gene$molecular_id, fromType = "ENSEMBL", 
                   toType = "ENTREZID", OrgDb = org.Hs.eg.db)

kegg_enrich <- enrichKEGG(gene         = entrez_ids$ENTREZID,
                          organism     = 'hsa',
                          pvalueCutoff = 1,
                         qvalueCutoff = 1)
# Out:
# 'select()' returned 1:many mapping between keys and columns
#
# Warning message in bitr(image_Aging4_gene$molecular_id, fromType = "ENSEMBL", toType = "ENTREZID", :
# “2.38% of input gene IDs are fail to map...”
# Reading KEGG annotation online: "https://rest.kegg.jp/link/hsa/pathway"...
#
# Reading KEGG annotation online: "https://rest.kegg.jp/list/pathway/hsa"...

# %%
kegg_enrich %>% head(n=20)
# Out:
#          category
# hsa04024 Environmental Information Processing
# hsa04270 Organismal Systems
# hsa04934 Human Diseases
# hsa05160 Human Diseases
# hsa05225 Human Diseases
# hsa00900 Metabolism
# hsa04015 Environmental Information Processing
# hsa04081 NA
# hsa00051 Metabolism
# hsa05208 Human Diseases
# hsa04810 Cellular Processes
# hsa05216 Human Diseases
# hsa04714 Organismal Systems
# hsa05219 Human Diseases
# hsa03022 Genetic Information Processing
# hsa04010 Environmental Information Processing
# hsa05213 Human Diseases
# hsa04730 Organismal Systems
# hsa00310 Metabolism
# hsa04927 Organismal Systems
#          subcategory                              ID
# hsa04024 Signal transduction                      hsa04024
# hsa04270 Circulatory system                       hsa04270
# hsa04934 Endocrine and metabolic disease          hsa04934
# hsa05160 Infectious disease: viral                hsa05160
# hsa05225 Cancer: specific types                   hsa05225
# hsa00900 Metabolism of terpenoids and polyketides hsa00900
# hsa04015 Signal transduction                      hsa04015
# hsa04081 NA                                       hsa04081
# hsa00051 Carbohydrate metabolism                  hsa00051
# hsa05208 Cancer: overview                         hsa05208
# hsa04810 Cell motility                            hsa04810
# hsa05216 Cancer: specific types                   hsa05216
# hsa04714 Environmental adaptation                 hsa04714
# hsa05219 Cancer: specific types                   hsa05219
# hsa03022 Transcription                            hsa03022
# hsa04010 Signal transduction                      hsa04010
# hsa05213 Cancer: specific types                   hsa05213
# hsa04730 Nervous system                           hsa04730
# hsa00310 Amino acid metabolism                    hsa00310
# hsa04927 Endocrine system                         hsa04927
#          Description                                       GeneRatio BgRatio
# hsa04024 cAMP signaling pathway                            3/17      226/9446
# hsa04270 Vascular smooth muscle contraction                2/17      134/9446
# hsa04934 Cushing syndrome                                  2/17      155/9446
# hsa05160 Hepatitis C                                       2/17      159/9446
# hsa05225 Hepatocellular carcinoma                          2/17      170/9446
# hsa00900 Terpenoid backbone biosynthesis                   1/17      23/9446
# hsa04015 Rap1 signaling pathway                            2/17      212/9446
# hsa04081 Hormone signaling                                 2/17      219/9446
# hsa00051 Fructose and mannose metabolism                   1/17      35/9446
# hsa05208 Chemical carcinogenesis - reactive oxygen species 2/17      227/9446
# hsa04810 Regulation of actin cytoskeleton                  2/17      232/9446
# hsa05216 Thyroid cancer                                    1/17      37/9446
# hsa04714 Thermogenesis                                     2/17      235/9446
# hsa05219 Bladder cancer                                    1/17      41/9446
# hsa03022 Basal transcription factors                       1/17      44/9446
# hsa04010 MAPK signaling pathway                            2/17      300/9446
# hsa05213 Endometrial cancer                                1/17      59/9446
# hsa04730 Long-term depression                              1/17      60/9446
# hsa00310 Lysine degradation                                1/17      63/9446
# hsa04927 Cortisol synthesis and secretion                  1/17      65/9446
#          pvalue      p.adjust  qvalue    geneID        Count
# hsa04024 0.007171338 0.3281671 0.3192032 673/2867/3776 3
# hsa04270 0.023633832 0.3281671 0.3192032 673/553       2
# hsa04934 0.030963298 0.3281671 0.3192032 673/3776      2
# hsa05160 0.032450779 0.3281671 0.3192032 673/439996    2
# hsa05225 0.036685405 0.3281671 0.3192032 6603/673      2
# hsa00900 0.040630366 0.3281671 0.3192032 9453          1
# hsa04015 0.054659779 0.3281671 0.3192032 673/285       2
# hsa04081 0.057912286 0.3281671 0.3192032 4157/553      2
# hsa00051 0.061206951 0.3281671 0.3192032 3795          1
# hsa05208 0.061712424 0.3281671 0.3192032 1340/673      2
# hsa04810 0.064131208 0.3281671 0.3192032 85464/673     2
# hsa05216 0.064595733 0.3281671 0.3192032 673           1
# hsa04714 0.065598248 0.3281671 0.3192032 6603/1340     2
# hsa05219 0.071338787 0.3281671 0.3192032 673           1
# hsa03022 0.076366026 0.3281671 0.3192032 6884          1
# hsa04010 0.099996645 0.3281671 0.3192032 673/285       2
# hsa05213 0.101120334 0.3281671 0.3192032 673           1
# hsa04730 0.102748219 0.3281671 0.3192032 673           1
# hsa00310 0.107615241 0.3281671 0.3192032 9757          1
# hsa04927 0.110846107 0.3281671 0.3192032 3776          1

# %%
barplot(kegg_enrich, showCategory = 10, title = "KEGG Pathway Enrichment")
# Out:
# plot without title
