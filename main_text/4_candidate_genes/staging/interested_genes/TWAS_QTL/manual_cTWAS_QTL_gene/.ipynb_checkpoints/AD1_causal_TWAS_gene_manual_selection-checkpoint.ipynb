# %% [markdown]
# # Manually Selection of the Most Likely Causal Genes from Significant TWAS Genes
#
# ## Aim
#
# Genomewide MR was skipped due to missing `MAF` column in the imputed GWAS sumstats, and our [TWAS pipeline](https://github.com/rl3328/xqtl-protocol/blob/main/code/pecotmr_integration/twas_ctwas.ipynb) runs TWAS and MR in the same step (`twas`). This notebook serves as a quick rescue to manually diminish noise from LD hitchhiking and identify the most likely causal genes.
#
#
#
# ## Steps
#
# ### 1. Filter genes qualified for MR analysis
#
# Most thresholds follow the default requirements in \[`twas`], except I use a stricter `twas_pval` cutoff. The reason is that I want to directly apply the filter to “significant” TWAS genes in my manuscript while also saving resources.
#
# **Criteria:**
#
# 1. Strong and reliable TWAS signals:
#
#    * `twas_pval < 2.5*1e-6`
#    * `rsq_cv > 0.01`
#    * `rsq_pval < 0.05`
# 2. Strong GWAS signals:
#
#    * Have `CS`, which can be extracted from `twas_weight(.rds)` files
#
# ### 2. Manually select the most likely causal gene
#
# Within each LD block and by context, I define the gene with the strongest GWAS signal as follows:
#
# * For each gene–context combination:
#
#   * If no credible set (CS) is available, skip (this corresponds to filtering step 1.2).
#   * If a 95% CS exists, select the gene containing the variant with the highest PIP within the 95% CS. If not, fall back to 70% CS.
#   * If a 70% CS exists, select the gene containing the variant with the highest PIP within the 70% CS. If not, fall back to 50% CS.
#   * If a 50% CS exists, select the gene containing the variant with the highest PIP within the 50% CS.
#
#
#
# ## Note
#
# There are some differences between this identification and the [loose gene list](https://github.com/rl3328/xqtl-analysis/blob/main/production/image_QTL/interested_genes/TWAS_QTL/loose_gene/image_AD1_gene_list.tsv).
#
# * Loose list: 42 genes, filtered by `is_selected_method` and `twas_pval < 2.5*1e-6`
# * Current identification: 443 genes are strong TWAS genes(twas_pval < 2.5*1e-6 & rsq_cv > 0.01 & pval_cv < 0.05) for AD1 and Knight cohort, 48 genes were identified as the final list.
#
#
#
# ## Input
#
# 1. **Merged TWAS results** (`*.twas.tsv.gz`):
#
#    * `s3://statfungen/ftp_fgc_xqtl/interactive_analysis/rl3328/image_QTL/twas/image_AD1_twas_merged.tsv.gz.combined_twas.tsv.gz`
# 2. **xQTL\_meta\_file** (meta file specifying TWAS weight paths by cohort):
#
#    * `s3://statfungen/ftp_fgc_xqtl/interactive_analysis/cl4215/KNIGHT_eQTL_pQTL_twas_wgw_xqtl_meta_data.tsv`
#
#
# ## Plan
#
# Other GWAS studies and other cohorts will be analyzed in the same way.

# %%
library(data.table)
library(tidyverse)
library(pecotmr)

# %%
setwd("~/data")

# %%
##Bonfferroni correction is too strict
# AD1_twas = fread("~/project/image_QTL/twas/multiple_testing/image_AD1_twas_bonff.bonf_corrected.tsv.gz")

# %%
AD1_twas = fread("~/project/image_QTL/twas/image_AD1_twas_merged.tsv.gz.combined_twas.tsv.gz")

# %%
# No gene presents in multiple blocks
genes_in_multiple_blocks <- AD1_twas %>% group_by(molecular_id) %>% summarise(
    number_of_blocks = n_distinct(block)) %>%
    filter(number_of_blocks > 1)

print(genes_in_multiple_blocks)
# Out:
# # A tibble: 0 × 2
# # ℹ 2 variables: molecular_id <chr>, number_of_blocks <int>

# %%
head(AD1_twas)
dim(AD1_twas)
# Out:
#   chr molecular_id    TSS       start     end       context
# 1 10  ENSG00000055950 100987514  99320000 102120000 Knight_eQTL_brain
# 2 10  ENSG00000055950 100987514  99320000 102120000 Knight_eQTL_brain
# 3 10  ENSG00000055950 100987514  99320000 102120000 Knight_eQTL_brain
# 4 10  ENSG00000055950 100987514  99320000 102120000 Knight_eQTL_brain
# 5 10  ENSG00000059915 102421538 101402617 103680000 Knight_eQTL_brain
# 6 10  ENSG00000059915 102421538 101402617 103680000 Knight_eQTL_brain
#   gwas_study method is_imputable is_selected_method rsq_cv      pval_cv
# 1 image_AD1  enet   TRUE         FALSE              0.098757440 8.923911e-10
# 2 image_AD1  lasso  TRUE         FALSE              0.103370596 3.541036e-10
# 3 image_AD1  mrash  TRUE         FALSE              0.089177838 6.013310e-09
# 4 image_AD1  susie  TRUE          TRUE              0.121638427 8.766557e-12
# 5 image_AD1  enet   TRUE         FALSE              0.007872702 5.201216e-02
# 6 image_AD1  lasso  TRUE         FALSE              0.006195072 7.447581e-02
#   twas_z     twas_pval    type block
# 1  0.4604784 0.6451729061 eQTL chr10_100331627_104378781
# 2  0.4628714 0.6434565734 eQTL chr10_100331627_104378781
# 3  0.6389774 0.5228376549 eQTL chr10_100331627_104378781
# 4  0.4641349 0.6425511004 eQTL chr10_100331627_104378781
# 5 -3.5326758 0.0004113766 eQTL chr10_100331627_104378781
# 6 -3.4892189 0.0004844343 eQTL chr10_100331627_104378781
#   region                    study_context
# 1 chr10_100331627_104378781 KNIGHT_eQTL_pQTL
# 2 chr10_100331627_104378781 KNIGHT_eQTL_pQTL
# 3 chr10_100331627_104378781 KNIGHT_eQTL_pQTL
# 4 chr10_100331627_104378781 KNIGHT_eQTL_pQTL
# 5 chr10_100331627_104378781 KNIGHT_eQTL_pQTL
# 6 chr10_100331627_104378781 KNIGHT_eQTL_pQTL
#   source_file
# 1 KNIGHT_eQTL_pQTL.chr10_100331627_104378781.twas.tsv.gz
# 2 KNIGHT_eQTL_pQTL.chr10_100331627_104378781.twas.tsv.gz
# 3 KNIGHT_eQTL_pQTL.chr10_100331627_104378781.twas.tsv.gz
# 4 KNIGHT_eQTL_pQTL.chr10_100331627_104378781.twas.tsv.gz
# 5 KNIGHT_eQTL_pQTL.chr10_100331627_104378781.twas.tsv.gz
# 6 KNIGHT_eQTL_pQTL.chr10_100331627_104378781.twas.tsv.gz
# [1] 927133     19

# %%
# Strong and reliable TWAS signals:
AD1_twas_filtered <- AD1_twas |>
    filter(
        twas_pval < 2.5*1e-6 &     # Stricter p-value threshold 
        rsq_cv > 0.01 &          # Cross-validation R²
        pval_cv < 0.05          # R² significance
    )
AD1_block = unique(AD1_twas_filtered$block)

# %%
dim(AD1_twas_filtered)
# Out:
# [1] 443  19

# %%
most_likely_causal_genes = AD1_twas_filtered |> 
  group_by(context, region) |> 
  slice_max(abs(twas_z), n = 1)

# %%
head(most_likely_causal_genes)
dim(most_likely_causal_genes)
# Out:
#   chr molecular_id    TSS       start     end       context         gwas_study
# 1 10  ENSG00000138175 102714396 101673731 103714397 AC_DeJager_eQTL image_AD1
# 2 14  ENSG00000151838  59576811  58080000  60600000 AC_DeJager_eQTL image_AD1
# 3 16  ENSG00000157315  69351785  66880000  71160000 AC_DeJager_eQTL image_AD1
# 4 17  ENSG00000186868  45894526  42560000  47028334 AC_DeJager_eQTL image_AD1
# 5 20  ENSG00000125965  35454745  34433347  37080000 AC_DeJager_eQTL image_AD1
# 6  2  ENSG00000163171  37738467  36641882  39240000 AC_DeJager_eQTL image_AD1
#   method  is_imputable is_selected_method rsq_cv     pval_cv      twas_z
# 1 bayes_r TRUE         FALSE              0.02819203 2.346740e-05 -5.154788
# 2 bayes_l TRUE         FALSE              0.04270906 2.288710e-07 -5.965036
# 3 enet    TRUE         FALSE              0.03231437 6.299037e-06 -4.774097
# 4 bayes_r TRUE         FALSE              0.01088200 6.310740e-03  5.010780
# 5 mrash   TRUE         FALSE              0.03551907 2.267474e-06 -4.796997
# 6 bayes_l TRUE         FALSE              0.06346084 2.940073e-10  4.913180
#   twas_pval    type block                     region
# 1 2.539182e-07 eQTL chr10_100331627_104378781 chr10_100331627_104378781
# 2 2.445800e-09 eQTL chr14_58669547_61213190   chr14_58669547_61213190
# 3 1.805153e-06 eQTL chr16_68398988_70662193   chr16_68398988_70662193
# 4 5.420980e-07 eQTL chr17_45383525_50162864   chr17_45383525_50162864
# 5 1.610617e-06 eQTL chr20_32060775_36429279   chr20_32060775_36429279
# 6 8.961082e-07 eQTL chr2_37591842_40054824    chr2_37591842_40054824
#   study_context    source_file
# 1 ROSMAP_eQTL_pQTL ROSMAP_eQTL_pQTL.chr10_100331627_104378781.twas.tsv.gz
# 2 ROSMAP_eQTL_pQTL ROSMAP_eQTL_pQTL.chr14_58669547_61213190.twas.tsv.gz
# 3 ROSMAP_eQTL_pQTL ROSMAP_eQTL_pQTL.chr16_68398988_70662193.twas.tsv.gz
# 4 ROSMAP_eQTL_pQTL ROSMAP_eQTL_pQTL.chr17_45383525_50162864.twas.tsv.gz
# 5 ROSMAP_eQTL_pQTL ROSMAP_eQTL_pQTL.chr20_32060775_36429279.twas.tsv.gz
# 6 ROSMAP_eQTL_pQTL ROSMAP_eQTL_pQTL.chr2_37591842_40054824.twas.tsv.gz
# [1] 132  19

# %%
most_likely_causal_genes |> count(molecular_id) |> nrow()
# Out:
# [1] 132

# %%
AD1_gene = unique(most_likely_causal_genes$molecular_id)

# %%
image_AD1_gene_list <- AD1_twas |> 
  dplyr::filter(molecular_id %in% AD1_gene) |> 
  dplyr::mutate(`#chr` = paste0("chr", chr), molecular_id = molecular_id) |> 
  dplyr::select(`#chr`, start, end, molecular_id) |> 
  unique()

# %%
dim(image_AD1_gene_list)
# Out:
# [1] 66  4

# %%
DNE_QTL_gene = fread("~/project/image_QTL/twas/annotated_dne_gene.tsv")

# %%
image_AD1_QTL_gene = DNE_QTL_gene |> filter(str_detect(event_ID, "image_AD1")) |> dplyr::select(-strand,-event_ID)

# %%
image_AD1_gene = bind_rows(image_AD1_gene_list, image_AD1_QTL_gene)

# %%
fwrite(image_AD1_gene, "~/DNE_xQTL_paper/main_text/4_candidate_genes/staging/interested_genes/TWAS_QTL/manual_cTWAS_QTL_gene/image_AD1_gene_list.tsv", sep = '\t')

# %% [markdown]
# ### image_AD1_QTL list

# %%
library(clusterProfiler)
library(org.Hs.eg.db)

# %%
image_AD1_gene = fread("~/DNE_xQTL_paper/main_text/4_candidate_genes/staging/interested_genes/TWAS_QTL/manual_cTWAS_QTL_gene/image_AD1_gene_list.tsv")
AD1_gene = image_AD1_gene |> filter(gene_name == '')  |> pull(molecular_id)

# %%
AD1_sig_gene_ego <- enrichGO(
  gene          = unique(image_AD1_gene$molecular_id),
  OrgDb         = org.Hs.eg.db,
  keyType       = "ENSEMBL",
  ont           = "BP",
  pAdjustMethod = "BH",
  pvalueCutoff  = 1,
  qvalueCutoff  = 1
)

# %%
head(AD1_sig_gene_ego, n=10)
# Out:
#            ID
# GO:0019896 GO:0019896
# GO:0034643 GO:0034643
# GO:0047497 GO:0047497
# GO:1904357 GO:1904357
# GO:0051654 GO:0051654
# GO:0033044 GO:0033044
# GO:0032205 GO:0032205
# GO:0018023 GO:0018023
# GO:0051646 GO:0051646
# GO:0032204 GO:0032204
#            Description
# GO:0019896 axonal transport of mitochondrion
# GO:0034643 establishment of mitochondrion localization, microtubule-mediated
# GO:0047497 mitochondrion transport along microtubule
# GO:1904357 negative regulation of telomere maintenance via telomere lengthening
# GO:0051654 establishment of mitochondrion localization
# GO:0033044 regulation of chromosome organization
# GO:0032205 negative regulation of telomere maintenance
# GO:0018023 peptidyl-lysine trimethylation
# GO:0051646 mitochondrion localization
# GO:0032204 regulation of telomere maintenance
#            GeneRatio BgRatio   pvalue       p.adjust   qvalue
# GO:0019896 3/64      20/21261  2.859134e-05 0.03369257 0.02980701
# GO:0034643 3/64      28/21261  8.076156e-05 0.03369257 0.02980701
# GO:0047497 3/64      28/21261  8.076156e-05 0.03369257 0.02980701
# GO:1904357 3/64      32/21261  1.212301e-04 0.03369257 0.02980701
# GO:0051654 3/64      33/21261  1.330670e-04 0.03369257 0.02980701
# GO:0033044 6/64      280/21261 1.954289e-04 0.04123549 0.03648006
# GO:0032205 3/64      40/21261  2.373705e-04 0.04293014 0.03797927
# GO:0018023 2/64      10/21261  3.952113e-04 0.06254219 0.05532958
# GO:0051646 3/64      53/21261  5.473446e-04 0.07699314 0.06811399
# GO:0032204 4/64      130/21261 6.384218e-04 0.08082419 0.07150324
#            geneID
# GO:0019896 ENSG00000131966/ENSG00000186868/ENSG00000186094
# GO:0034643 ENSG00000131966/ENSG00000186868/ENSG00000186094
# GO:0047497 ENSG00000131966/ENSG00000186868/ENSG00000186094
# GO:1904357 ENSG00000107960/ENSG00000173273/ENSG00000258724
# GO:0051654 ENSG00000131966/ENSG00000186868/ENSG00000186094
# GO:0033044 ENSG00000107960/ENSG00000100811/ENSG00000186868/ENSG00000173273/ENSG00000173473/ENSG00000258724
# GO:0032205 ENSG00000107960/ENSG00000173273/ENSG00000258724
# GO:0018023 ENSG00000181555/ENSG00000145002
# GO:0051646 ENSG00000131966/ENSG00000186868/ENSG00000186094
# GO:0032204 ENSG00000107960/ENSG00000100811/ENSG00000173273/ENSG00000258724
#            Count
# GO:0019896 3
# GO:0034643 3
# GO:0047497 3
# GO:1904357 3
# GO:0051654 3
# GO:0033044 6
# GO:0032205 3
# GO:0018023 2
# GO:0051646 3
# GO:0032204 4

# %%
barplot(AD1_sig_gene_ego, showCategory = 10, title = "GO Enrichment - BP")
# Out:
# plot without title

# %%
AD1_sig_gene_ego_cc <- enrichGO(
  gene          = image_AD1_gene$molecular_id,
  OrgDb         = org.Hs.eg.db,
  keyType       = "ENSEMBL",
  ont           = "CC",
  pAdjustMethod = "BH",
  pvalueCutoff  = 1,
  qvalueCutoff  = 1
)

# %%
head(AD1_sig_gene_ego_cc, n=15)
# Out:
#            ID         Description
# GO:1904115 GO:1904115 axon cytoplasm
# GO:0032838 GO:0032838 plasma membrane bounded cell projection cytoplasm
# GO:0099568 GO:0099568 cytoplasmic region
# GO:0120111 GO:0120111 neuron projection cytoplasm
# GO:0019903 ENSG00000186868/ENSG00000104643/ENSG00000147324/ENSG00000029534
# GO:0051721 ENSG00000186868/ENSG00000147324
# GO:0019902 ENSG00000186868/ENSG00000104643/ENSG00000147324/ENSG00000029534
# GO:0000217 ENSG00000100811/ENSG00000186868
# GO:0008017 ENSG00000138175/ENSG00000066629/ENSG00000186868/ENSG00000047849
# GO:0016279 ENSG00000181555/ENSG00000145002
# GO:0016278 ENSG00000181555/ENSG00000145002
# GO:1901981 ENSG00000186868/ENSG00000170633/ENSG00000123329
# GO:0031625 ENSG00000050130/ENSG00000147324/ENSG00000170633/ENSG00000100567
# GO:0044389 ENSG00000050130/ENSG00000147324/ENSG00000170633/ENSG00000100567
# GO:0042578 ENSG00000073417/ENSG00000141298/ENSG00000164045/ENSG00000136960
# GO:0016671 ENSG00000175806
# GO:0004527 ENSG00000136960/ENSG00000104626
# GO:0008081 ENSG00000073417/ENSG00000136960
#            Count
# GO:0015631 6
# GO:0019903 4
# GO:0051721 2
# GO:0019902 4
# GO:0000217 2
# GO:0008017 4
# GO:0016279 2
# GO:0016278 2
# GO:1901981 3
# GO:0031625 4
# GO:0044389 4
# GO:0042578 4
# GO:0016671 1
# GO:0004527 2
# GO:0008081 2

# %%
barplot(image_AD1_sig_gene_ego_mf, showCategory = 10, title = "GO Enrichment - MF")
# Out:
# plot without title

# %%
entrez_ids <- bitr(image_AD1_gene$molecular_id, fromType = "ENSEMBL", 
                   toType = "ENTREZID", OrgDb = org.Hs.eg.db)

kegg_enrich <- enrichKEGG(gene         = entrez_ids$ENTREZID,
                          organism     = 'hsa',
                          pvalueCutoff = 1,
                         qvalueCutoff = 1)
# Out:
# 'select()' returned 1:1 mapping between keys and columns
#
# Warning message in bitr(image_AD1_gene$molecular_id, fromType = "ENSEMBL", toType = "ENTREZID", :
# “1.49% of input gene IDs are fail to map...”

# %%
kegg_enrich %>% head(n=20)
# Out:
#          category
# hsa04140 Cellular Processes
# hsa03082 Genetic Information Processing
# hsa00230 Metabolism
# hsa00100 Metabolism
# hsa04130 Genetic Information Processing
# hsa04360 Organismal Systems
# hsa03050 Genetic Information Processing
# hsa03272 NA
# hsa00565 Metabolism
# hsa04340 Environmental Information Processing
# hsa05022 Human Diseases
# hsa05132 Human Diseases
# hsa00310 Metabolism
# hsa05217 Human Diseases
# hsa04927 Organismal Systems
# hsa05012 Human Diseases
# hsa04924 Organismal Systems
# hsa00562 Metabolism
# hsa00983 Metabolism
# hsa04612 Organismal Systems
#          subcategory                               ID
# hsa04140 Transport and catabolism                  hsa04140
# hsa03082 Chromosome                                hsa03082
# hsa00230 Nucleotide metabolism                     hsa00230
# hsa00100 Lipid metabolism                          hsa00100
# hsa04130 Folding, sorting and degradation          hsa04130
# hsa04360 Development and regeneration              hsa04360
# hsa03050 Folding, sorting and degradation          hsa03050
# hsa03272 NA                                        hsa03272
# hsa00565 Lipid metabolism                          hsa00565
# hsa04340 Signal transduction                       hsa04340
# hsa05022 Neurodegenerative disease                 hsa05022
