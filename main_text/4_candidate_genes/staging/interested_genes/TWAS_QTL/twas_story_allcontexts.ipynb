# %% [markdown]
# ## image_AD2

# %%
library(tidyverse)
library(data.table)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.2     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose

# %%
AD_top_loci = fread("/home/ubuntu/data/analysis_result/twas/AD/export/summary/FunGen_twas.exported.bed.gz") |> select(-TADB_start,-TADB_end) |> select(`#chr`, molecular_id, start, end, everything()) |> rename(chr = `#chr`)
head(AD_top_loci)
# Out:
#   chr molecular_id    start  end    context         gwas_study      method
# 1 1   ENSG00000187634 923921 923922 AC_DeJager_eQTL Bellenguez_2022 bayes_l
# 2 1   ENSG00000187634 923921 923922 AC_DeJager_eQTL Bellenguez_2022 bayes_r
# 3 1   ENSG00000187634 923921 923922 AC_DeJager_eQTL Bellenguez_2022 enet
# 4 1   ENSG00000187634 923921 923922 AC_DeJager_eQTL Bellenguez_2022 lasso
# 5 1   ENSG00000187634 923921 923922 AC_DeJager_eQTL Bellenguez_2022 mrash
# 6 1   ENSG00000187634 923921 923922 AC_DeJager_eQTL Bellenguez_2022 mrmash
#   is_imputable is_selected_method rsq_cv     pval_cv      twas_z     twas_pval
# 1 TRUE         FALSE              0.06358278 4.713139e-10 -0.5516557 0.5811842
# 2 TRUE          TRUE              0.09006772 8.293727e-14 -0.6079598 0.5432142
# 3 TRUE         FALSE              0.07363354 1.811244e-11 -0.8264034 0.4085753
# 4 TRUE         FALSE              0.07175097 3.341192e-11 -0.7787284 0.4361397
# 5 TRUE         FALSE              0.08157779 1.353045e-12 -0.1803822 0.8568525
# 6 TRUE         FALSE              0.07746210 5.199122e-12 -1.4978502 0.1341722
#   type block
# 1 eQTL chr1_16103_2888443
# 2 eQTL chr1_16103_2888443
# 3 eQTL chr1_16103_2888443
# 4 eQTL chr1_16103_2888443
# 5 eQTL chr1_16103_2888443
# 6 eQTL chr1_16103_2888443

# %%
TL1_top_loci = fread("~/project/image_QTL/twas/TL1_twas_merged.tsv.gz.combined_twas.tsv.gz") 
AD1_top_loci = fread("~/project/image_QTL/twas/image_AD1_twas_merged.tsv.gz.combined_twas.tsv.gz")
AD2_top_loci = fread("~/project/image_QTL/twas/image_AD2_twas_merged.tsv.gz.combined_twas.tsv.gz")
Aging1_top_loci = fread("~/project/image_QTL/twas/image_Aging1_twas_merged.tsv.gz.combined_twas.tsv.gz")
Aging2_top_loci = fread("~/project/image_QTL/twas/image_Aging2_twas_merged.tsv.gz.combined_twas.tsv.gz")
Aging3_top_loci = fread("~/project/image_QTL/twas/image_Aging3_twas_merged.tsv.gz.combined_twas.tsv.gz")
Aging4_top_loci = fread("~/project/image_QTL/twas/image_Aging4_twas_merged.tsv.gz.combined_twas.tsv.gz")
Aging5_top_loci = fread("~/project/image_QTL/twas/image_Aging5_twas_merged.tsv.gz.combined_twas.tsv.gz")

all = rbind(TL1_top_loci, AD1_top_loci, AD2_top_loci, Aging1_top_loci, Aging2_top_loci, Aging3_top_loci, Aging4_top_loci, Aging5_top_loci)

# %%
# TL1_top_loci |> filter(str_detect(molecular_id, "ENSG00000088727"))

# %%
all = all |> select(-TSS, -region,-study_context,-source_file)
all = rbind(all, AD_top_loci) |> unique()

# %%
dim(all)
# Out:
# [1] 19592064       15

# %%
annotated_gene_names = fread("~/DNE_xQTL_paper/main_text/4_candidate_genes/staging/interested_genes/TWAS_QTL/TWAS_QTL_gene_list.tsv")
head(annotated_gene_names)
# Out:
#   #chr  start     end       gene_id         source gene_name event_id
# 1 chr14  99238297 101760000 ENSG00000100811 TWAS   YY1       image_AD1
# 2 chr20  34433347  37080000 ENSG00000125965 TWAS   GDF5      image_AD1
# 3 chr3   46413681  50320000 ENSG00000114650 TWAS   SCAP      image_AD1
# 4 chr8    9840000  12600000 ENSG00000104643 TWAS   MTMR9     image_AD1
# 5 chr10 101673731 103714397 ENSG00000138175 TWAS   ARL3      image_AD1
# 6 chr10 101644478 103680000 ENSG00000171206 TWAS   TRIM8     image_AD1

# %%
# Step 2: Keep only unique gene_id (keep first occurrence)
lookup_table <- annotated_gene_names %>%
  select(gene_id, gene_name) %>%
  distinct(gene_id, .keep_all = TRUE)

# Step 3: Annotate df_c using the lookup table
annotated_all <- all %>%
  left_join(lookup_table, by = c("molecular_id"="gene_id")) %>% select(chr, molecular_id, gene_name, context, gwas_study, twas_z, twas_pval, everything())

# %%
# supp = fread("~/xqtl-analysis/production/image_QTL/interested_genes/TWAS_QTL/manually_annotated_all.tsv")
# annotated_all = bind_rows(annotated_all, supp) |> unique()

# %%
head(annotated_all)
dim(annotated_all)
# Out:
#   chr molecular_id    gene_name context           gwas_study   twas_z
# 1 10  ENSG00000055950 NA        Knight_eQTL_brain Telomere_pc1 -2.903662
# 2 10  ENSG00000055950 NA        Knight_eQTL_brain Telomere_pc1 -2.878534
# 3 10  ENSG00000055950 NA        Knight_eQTL_brain Telomere_pc1 -2.963834
# 4 10  ENSG00000055950 NA        Knight_eQTL_brain Telomere_pc1 -2.919076
# 5 10  ENSG00000059915 NA        Knight_eQTL_brain Telomere_pc1  2.351818
# 6 10  ENSG00000059915 NA        Knight_eQTL_brain Telomere_pc1  2.565091
#   twas_pval   start     end       method is_imputable is_selected_method
# 1 0.003688264  99320000 102120000 enet   TRUE         FALSE
# 2 0.003995280  99320000 102120000 lasso  TRUE         FALSE
# 3 0.003038321  99320000 102120000 mrash  TRUE         FALSE
# 4 0.003510708  99320000 102120000 susie  TRUE          TRUE
# 5 0.018681917 101402617 103680000 enet   TRUE         FALSE
# 6 0.010314876 101402617 103680000 lasso  TRUE         FALSE
#   rsq_cv      pval_cv      type block
# 1 0.098757440 8.923911e-10 eQTL chr10_100331627_104378781
# 2 0.103370596 3.541036e-10 eQTL chr10_100331627_104378781
# 3 0.089177838 6.013310e-09 eQTL chr10_100331627_104378781
# 4 0.121638427 8.766557e-12 eQTL chr10_100331627_104378781
# 5 0.007872702 5.201216e-02 eQTL chr10_100331627_104378781
# 6 0.006195072 7.447581e-02 eQTL chr10_100331627_104378781
# [1] 19592064       16

# %%
# annotated_all |> filter(gene_name %in% c("H2AC11", "H4C13"), twas_pval < 2.5*1e-6)

# %%
AD2_all = annotated_all |>filter(gene_name %in% c("SEZ6L2", "TNIP1", "KANSL1", "NSF", "H2AC11", "H4C13", "DOC2A"))

# %%
AD2_story_genes = annotated_all |>filter(gene_name %in% c("SEZ6L2", "TNIP1", "KANSL1", "NSF", "H2AC11", "H4C13","DOC2A"), is_selected_method, twas_pval < 2.5*1e-6)
dim(AD2_story_genes)
# Out:
# [1] 88 16

# %%
DOC2A_selected = annotated_all |> filter(gene_name == "DOC2A", twas_pval<2.5*1e-6) |> 
  group_by(gwas_study, context) |> 
  slice_min(twas_pval, n = 1, with_ties = FALSE)
DOC2A_selected
# Out:
#    chr molecular_id    gene_name
# 1  16  ENSG00000149927 DOC2A
# 2  16  ENSG00000149927 DOC2A
# 3  16  ENSG00000149927 DOC2A
# 4  16  ENSG00000149927 DOC2A
# 5  16  ENSG00000149927 DOC2A
# 6  16  ENSG00000149927 DOC2A
# 7  16  ENSG00000149927 DOC2A
# 8  16  ENSG00000149927 DOC2A
# 9  16  ENSG00000149927 DOC2A
# 10 16  ENSG00000149927 DOC2A
# 11 16  ENSG00000149927 DOC2A
# 12 16  ENSG00000149927 DOC2A
# 13 16  ENSG00000149927 DOC2A
# 14 16  ENSG00000149927 DOC2A
# 15 16  ENSG00000149927 DOC2A
# 16 16  ENSG00000149927 DOC2A
# 17 16  ENSG00000149927 DOC2A
# 18 16  ENSG00000149927 DOC2A
# 19 16  ENSG00000149927 DOC2A
# 20 16  ENSG00000149927 DOC2A
#    context
# 1  AC_DeJager_eQTL
# 2  BM_10_MSBB_eQTL
# 3  DLPFC_Bennett_pQTL_chr16_Q14183
# 4  Exc_DeJager_eQTL
# 5  Exc_mega_eQTL
# 6  MSBB_BM36_pQTL_chr16_Q14183
# 7  PCC_DeJager_eQTL
# 8  ROSMAP_PCC_sQTL_chr16:30007090:30007172:clu_104500_-:PR:ENSG00000149927
# 9  ROSMAP_PCC_sQTL_chr16:30007090:30007178:clu_104500_-:PR:ENSG00000149927
# 10 AC_DeJager_eQTL
# 11 Exc_mega_eQTL
# 12 AC_DeJager_eQTL
# 13 AC_DeJager_eQTL
# 14 MSBB_BM36_pQTL_chr16_Q14183
# 15 AC_DeJager_eQTL
# 16 DLPFC_Bennett_pQTL_chr16_Q14183
# 17 Exc_DeJager_eQTL
# 18 Exc_mega_eQTL
# 19 MSBB_BM36_pQTL_chr16_Q14183
# 20 PCC_DeJager_eQTL
#    gwas_study                     twas_z    twas_pval    start    end
# 1  Bellenguez_2022                 6.226164 4.779938e-10 30023268 30023269
# 2  Bellenguez_2022                 6.198407 5.703746e-10 30023268 30023269
# 3  Bellenguez_2022                -6.303660 2.906974e-10 30023268 30023269
# 4  Bellenguez_2022                 6.706686 1.990946e-11 30023268 30023269
# 5  Bellenguez_2022                 5.974068 2.314087e-09 30023268 30023269
# 6  Bellenguez_2022                -6.723383 1.775532e-11 30023268 30023269
# 7  Bellenguez_2022                -6.256668 3.932883e-10 30023268 30023269
# 8  Bellenguez_2022                -6.092940 1.108556e-09 30023268 30023269
# 9  Bellenguez_2022                 6.003741 1.928218e-09 30023268 30023269
# 10 Jansen_2021                     4.977360 6.445742e-07 30023268 30023269
# 11 Jansen_2021                     5.053711 4.333066e-07 30023268 30023269
# 12 Wightman_Excluding23andMe_2021  4.883509 1.042146e-06 30023268 30023269
# 13 Wightman_Full_2021              4.780444 1.749082e-06 30023268 30023269
# 14 Wightman_Full_2021             -4.761236 1.924110e-06 30023268 30023269
# 15 image_Aging2                   -5.874356 4.244906e-09 28360000 34000000
# 16 image_Aging2                    6.486572 8.781121e-11 28360000 34000000
# 17 image_Aging2                   -5.898468 3.668914e-09 28360000 34000000
# 18 image_Aging2                   -5.825771 5.684941e-09 28360000 34000000
# 19 image_Aging2                    5.966588 2.422656e-09 28360000 34000000
# 20 image_Aging2                    5.884108 4.002071e-09 28360000 34000000
#    method  is_imputable is_selected_method rsq_cv       pval_cv
# 1  mvsusie TRUE         FALSE              0.0174814955 1.250545e-03
# 2  bayes_l TRUE          TRUE              0.0149392211 4.322408e-02
# 3  mrash   TRUE         FALSE              0.1254711233 9.641842e-14
# 4  lasso   TRUE         FALSE              0.0143437386 1.416518e-02
# 5  susie   TRUE         FALSE              0.0224420810 2.627164e-05
# 6  susie   TRUE         FALSE              0.1694060224 3.875763e-09
# 7  mvsusie TRUE         FALSE              0.0027397208 2.727194e-01
# 8  susie   TRUE          TRUE              0.1274450609 3.669347e-15
# 9  susie   TRUE         FALSE              0.1743403637 1.371768e-20
# 10 mrash   TRUE         FALSE              0.0026456911 2.110292e-01
# 11 mrash   TRUE         FALSE              0.0253708240 8.271714e-06
# 12 lasso   TRUE         FALSE              0.0001644336 7.553305e-01
# 13 enet    TRUE         FALSE              0.0008246655 4.851942e-01
# 14 mrash   TRUE         FALSE              0.1686840717 4.202829e-09
# 15 mvsusie TRUE         FALSE              0.0158190276 1.250545e-03
# 16 enet    TRUE         FALSE              0.1003804882 2.250670e-11
# 17 mvsusie TRUE          TRUE              0.0389821524 2.785749e-05
# 18 susie   TRUE         FALSE              0.0224420810 2.627164e-05
# 19 susie   TRUE         FALSE              0.1694060224 3.875763e-09
# 20 mvsusie TRUE         FALSE              0.0004680573 2.727194e-01
#    type            block
# 1  eQTL            chr16_29685831_46381513
# 2  eQTL            chr16_29685831_46381513
# 3  pQTL            chr16_29685831_46381513
# 4  eQTL            chr16_29685831_46381513
# 5  eQTL            chr16_29685831_46381513
# 6  pQTL            chr16_29685831_46381513
# 7  eQTL            chr16_29685831_46381513
# 8  productive_sQTL chr16_29685831_46381513
# 9  productive_sQTL chr16_29685831_46381513
# 10 eQTL            chr16_29685831_46381513
# 11 eQTL            chr16_29685831_46381513
# 12 eQTL            chr16_29685831_46381513
# 13 eQTL            chr16_29685831_46381513
# 14 pQTL            chr16_29685831_46381513
# 15 eQTL            chr16_29685831_46381513
# 16 pQTL            chr16_29685831_46381513
# 17 eQTL            chr16_29685831_46381513
# 18 eQTL            chr16_29685831_46381513
# 19 pQTL            chr16_29685831_46381513
# 20 eQTL            chr16_29685831_46381513

# %%
TNIP1_selected = annotated_all |> filter(gene_name == "TNIP1", twas_pval<2.5*1e-6) |> 
  group_by(gwas_study, context) |> 
  slice_min(twas_pval, n = 1, with_ties = FALSE)

# TNIP1_selected <- TNIP1_selected[-c(2, 3), ]
TNIP1_selected
# Out:
#   chr molecular_id    gene_name context
# 1 5   ENSG00000145901 TNIP1     Exc_DeJager_eQTL
# 2 5   ENSG00000145901 TNIP1     Exc_DeJager_eQTL
# 3 5   ENSG00000145901 TNIP1     Exc_DeJager_eQTL
# 4 5   ENSG00000145901 TNIP1     Exc_DeJager_eQTL
# 5 5   ENSG00000145901 TNIP1     Exc_DeJager_eQTL
# 6 5   ENSG00000145901 TNIP1     Exc_DeJager_eQTL
#   gwas_study                           twas_z   twas_pval    start
# 1 Bellenguez_2022                      4.797897 1.603403e-06 151093575
# 2 Wightman_Excluding23andMe_2021       6.016836 1.778594e-09 151093575
# 3 Wightman_ExcludingUKBand23andME_2021 4.785963 1.701694e-06 151093575
# 4 Wightman_Full_2021                   6.637223 3.196469e-11 151093575
# 5 image_AD2                            4.932071 8.136249e-07 147240000
# 6 image_Aging2                         5.447872 5.097601e-08 147240000
#   end       method  is_imputable is_selected_method rsq_cv     pval_cv
# 1 151093576 bayes_r TRUE         FALSE              0.02010367 3.633386e-03
# 2 151093576 lasso   TRUE         FALSE              0.03625678 8.784071e-05
# 3 151093576 enet    TRUE         FALSE              0.02524406 1.101203e-03
# 4 151093576 lasso   TRUE         FALSE              0.03625678 8.784071e-05
# 5 154960000 lasso   TRUE         FALSE              0.03394564 8.784071e-05
# 6 154960000 lasso   TRUE         FALSE              0.03394564 8.784071e-05
#   type block
# 1 eQTL chr5_149895776_152257891
# 2 eQTL chr5_149895776_152257891
# 3 eQTL chr5_149895776_152257891
# 4 eQTL chr5_149895776_152257891
# 5 eQTL chr5_149895776_152257891
# 6 eQTL chr5_149895776_152257891

# %%
KANSL1_selected <- AD2_story_genes |> filter(type == "eQTL") |>
  filter(gene_name == "KANSL1") |> 
  group_by(gwas_study, context) |> 
  slice_min(twas_pval, n = 1, with_ties = FALSE)
KANSL1_added = AD2_story_genes |> filter(type == "eQTL") |>
  filter(gene_name == "KANSL1") |>
  # filter(str_detect(context, "Exc")) |>
  group_by(gwas_study) |> 
  slice_min(twas_pval, n = 1, with_ties = FALSE)
KANSL1_selected = KANSL1_selected |> filter(!gwas_study %in% c("Bellenguez_2022"))
  KANSL1_selected = bind_rows(KANSL1_selected, KANSL1_added)
KANSL1_selected
# Out:
#    chr molecular_id    gene_name context              gwas_study
# 1  17  ENSG00000120071 KANSL1    AC_DeJager_eQTL      Bellenguez_GRACE_2022
# 2  17  ENSG00000120071 KANSL1    Ast_DeJager_eQTL     Bellenguez_GRACE_2022
# 3  17  ENSG00000120071 KANSL1    Ast_mega_eQTL        Bellenguez_GRACE_2022
# 4  17  ENSG00000120071 KANSL1    BM_22_MSBB_eQTL      Bellenguez_GRACE_2022
# 5  17  ENSG00000120071 KANSL1    Exc_DeJager_eQTL     Bellenguez_GRACE_2022
# 6  17  ENSG00000120071 KANSL1    Exc_mega_eQTL        Bellenguez_GRACE_2022
# 7  17  ENSG00000120071 KANSL1    Inh_DeJager_eQTL     Bellenguez_GRACE_2022
# 8  17  ENSG00000120071 KANSL1    Inh_mega_eQTL        Bellenguez_GRACE_2022
# 2 17  ENSG00000073969 NSF       DLPFC_DeJager_eQTL   image_AD2        5.330298
# 3 17  ENSG00000073969 NSF       Knight_eQTL_brain    Bellenguez_2022 -5.276245
# 4 17  ENSG00000073969 NSF       monocyte_ROSMAP_eQTL Bellenguez_2022 -6.077064
# 5 17  ENSG00000073969 NSF       Oli_DeJager_eQTL     image_AD2        5.173960
#   twas_pval    start    end      method  is_imputable is_selected_method
# 1 4.488863e-07 42560000 50760000 susie   TRUE          TRUE
# 2 9.805158e-08 42560000 50760000 mrmash  TRUE          TRUE
# 3 1.318575e-07 46590667 46590668 susie   TRUE          TRUE
# 4 1.224027e-09 46590667 46590668 mvsusie TRUE          TRUE
# 5 2.291835e-07 42560000 50760000 mvsusie TRUE         FALSE
#   rsq_cv     pval_cv      type          block
# 1 0.15623647 3.437130e-29 eQTL          chr17_45383525_50162864
# 2 0.02127260 2.450412e-05 eQTL          chr17_45383525_50162864
# 3 0.04310541 4.903448e-05 eQTL          chr17_45383525_50162864
# 4 0.02702615 1.333952e-02 monocyte_eQTL chr17_45383525_50162864
# 5 0.03539570 6.310137e-05 eQTL          chr17_45383525_50162864

# %%
SEZ6L2_selected = AD2_story_genes |> filter(gene_name == "SEZ6L2") #|> slice(-3,-6)
SEZ6L2_selected
# Out:
#   chr molecular_id    gene_name context          gwas_study      twas_z
# 1 16  ENSG00000174938 SEZ6L2    Inh_DeJager_eQTL image_Aging1     5.275650
# 2 16  ENSG00000174938 SEZ6L2    Oli_DeJager_eQTL image_Aging2     5.923020
# 3 16  ENSG00000174938 SEZ6L2    OPC_DeJager_eQTL Bellenguez_2022 -6.920206
# 4 16  ENSG00000174938 SEZ6L2    Oli_DeJager_eQTL Bellenguez_2022 -5.727366
# 5 16  ENSG00000174938 SEZ6L2    Oli_mega_eQTL    Bellenguez_2022 -5.499260
#   twas_pval    start    end      method  is_imputable is_selected_method
# 1 1.322865e-07 28360000 34000000 bayes_l TRUE         TRUE
# 2 3.160821e-09 28360000 34000000 lasso   TRUE         TRUE
# 3 4.509887e-12 29899545 29899546 bayes_l TRUE         TRUE
# 4 1.020019e-08 29899545 29899546 lasso   TRUE         TRUE
# 5 3.813889e-08 29899545 29899546 susie   TRUE         TRUE
#   rsq_cv     pval_cv      type block
# 1 0.01159573 1.552881e-02 eQTL chr16_29685831_46381513
# 2 0.19179170 2.789510e-21 eQTL chr16_29685831_46381513
# 3 0.03240022 2.161435e-04 eQTL chr16_29685831_46381513
# 4 0.19372522 2.789510e-21 eQTL chr16_29685831_46381513
# 5 0.22496308 7.917035e-43 eQTL chr16_29685831_46381513

# %%
-log10(2.5*1e-6)
# Out:
# [1] 5.60206

# %%
AD2_story_genes_selected = bind_rows(TNIP1_selected, KANSL1_selected, NSF_selected, SEZ6L2_selected, DOC2A_selected)
AD2_story_genes_selected = AD2_story_genes_selected |> filter( twas_pval < 2.5*1e-6) |> select(chr, molecular_id, gene_name, context, gwas_study, twas_z, twas_pval, everything())
AD2_story_genes_selected = AD2_story_genes_selected |> mutate(gwas_study = ifelse(grepl("Bellenguez|Wightman|Jansen", gwas_study), "AD", gwas_study)) |> mutate(context = sub("_chr.*", "", context))

# %%
# AD2_story_genes_selected = AD2_story_genes_selected  |>  
#   left_join(context_gene_pair, by = "gene_name") %>% mutate(adjusted_p = (function(p) { o <- order(p); ro <- order(o); pmin(1, cummin(rev(p[o] * context_gene_pair / seq_along(p))))[rev(seq_along(p))][ro] })(twas_pval), bonff_p = pmin(1, twas_pval * context_gene_pair))

# %%
AD2_story_genes_selected = AD2_story_genes_selected|> filter(gwas_study!="image_Aging1")

# %%
plot_data
# Out:
#    chr molecular_id    gene_name context              gwas_study   twas_z
# 1   5  ENSG00000145901 TNIP1     Exc_DeJager_eQTL     AD            4.797897
# 2   5  ENSG00000145901 TNIP1     Exc_DeJager_eQTL     AD            6.016836
# 3   5  ENSG00000145901 TNIP1     Exc_DeJager_eQTL     AD            4.785963
# 4   5  ENSG00000145901 TNIP1     Exc_DeJager_eQTL     AD            6.637223
# 5   5  ENSG00000145901 TNIP1     Exc_DeJager_eQTL     image_AD2     4.932071
# 6   5  ENSG00000145901 TNIP1     Exc_DeJager_eQTL     image_Aging2  5.447872
# 7  17  ENSG00000120071 KANSL1    AC_DeJager_eQTL      AD           -5.201417
# 8  17  ENSG00000120071 KANSL1    Ast_DeJager_eQTL     AD           -5.232810
# 9  17  ENSG00000120071 KANSL1    Ast_mega_eQTL        AD           -5.348022
# 10 17  ENSG00000120071 KANSL1    BM_22_MSBB_eQTL      AD           -5.297593
# 11 17  ENSG00000120071 KANSL1    Exc_DeJager_eQTL     AD           -5.197814
# 12 17  ENSG00000120071 KANSL1    Exc_mega_eQTL        AD           -5.357944
# 13 17  ENSG00000120071 KANSL1    Inh_DeJager_eQTL     AD           -5.220920
# 14 17  ENSG00000120071 KANSL1    Inh_mega_eQTL        AD           -5.408769
# 15 17  ENSG00000120071 KANSL1    Knight_eQTL_brain    AD           -5.248525
# 16 17  ENSG00000120071 KANSL1    Mic_DeJager_eQTL     AD           -4.882819
# 17 17  ENSG00000120071 KANSL1    Mic_mega_eQTL        AD           -5.147555
# 18 17  ENSG00000120071 KANSL1    OPC_DeJager_eQTL     AD           -5.235613
# 19 17  ENSG00000120071 KANSL1    OPC_mega_eQTL        AD           -5.672068
# 20 17  ENSG00000120071 KANSL1    Oli_DeJager_eQTL     AD           -5.375503
# 21 17  ENSG00000120071 KANSL1    Oli_mega_eQTL        AD           -5.365731
# 22 17  ENSG00000120071 KANSL1    PCC_DeJager_eQTL     AD           -5.265577
# 23 17  ENSG00000120071 KANSL1    AC_DeJager_eQTL      image_AD2    -5.805627
# 24 17  ENSG00000120071 KANSL1    Ast_DeJager_eQTL     image_AD2    -5.586704
# 25 17  ENSG00000120071 KANSL1    Ast_mega_eQTL        image_AD2    -5.994898
# 26 17  ENSG00000120071 KANSL1    BM_10_MSBB_eQTL      image_AD2    -5.442602
# 27 17  ENSG00000120071 KANSL1    BM_22_MSBB_eQTL      image_AD2    -5.925283
# 28 17  ENSG00000120071 KANSL1    BM_36_MSBB_eQTL      image_AD2    -5.599905
# 29 17  ENSG00000120071 KANSL1    BM_44_MSBB_eQTL      image_AD2    -5.202655
# 30 17  ENSG00000120071 KANSL1    DLPFC_DeJager_eQTL   image_AD2    -5.893301
# ⋮  ⋮   ⋮               ⋮         ⋮                    ⋮            ⋮
# 45 17  ENSG00000120071 KANSL1    Mic_mega_eQTL        image_AD2    -6.219292
# 46 17  ENSG00000073969 NSF       Oli_mega_eQTL        Telomere_pc1  5.046964
# 47 17  ENSG00000073969 NSF       DLPFC_DeJager_eQTL   image_AD2     5.330298
# 48 17  ENSG00000073969 NSF       Knight_eQTL_brain    AD           -5.276245
# 49 17  ENSG00000073969 NSF       monocyte_ROSMAP_eQTL AD           -6.077064
# 50 17  ENSG00000073969 NSF       Oli_DeJager_eQTL     image_AD2     5.173960
# 51 16  ENSG00000174938 SEZ6L2    Oli_DeJager_eQTL     image_Aging2  5.923020
# 52 16  ENSG00000174938 SEZ6L2    OPC_DeJager_eQTL     AD           -6.920206
# 53 16  ENSG00000174938 SEZ6L2    Oli_DeJager_eQTL     AD           -5.727366
# 54 16  ENSG00000174938 SEZ6L2    Oli_mega_eQTL        AD           -5.499260
# 55 16  ENSG00000149927 DOC2A     AC_DeJager_eQTL      AD            6.226164
# 56 16  ENSG00000149927 DOC2A     BM_10_MSBB_eQTL      AD            6.198407
# 57 16  ENSG00000149927 DOC2A     DLPFC_Bennett_pQTL   AD           -6.303660
# 58 16  ENSG00000149927 DOC2A     Exc_DeJager_eQTL     AD            6.706686
# 59 16  ENSG00000149927 DOC2A     Exc_mega_eQTL        AD            5.974068
# 60 16  ENSG00000149927 DOC2A     MSBB_BM36_pQTL       AD           -6.723383
# 61 16  ENSG00000149927 DOC2A     PCC_DeJager_eQTL     AD           -6.256668
# 62 16  ENSG00000149927 DOC2A     ROSMAP_PCC_sQTL      AD           -6.092940
# 63 16  ENSG00000149927 DOC2A     ROSMAP_PCC_sQTL      AD            6.003741
# 64 16  ENSG00000149927 DOC2A     AC_DeJager_eQTL      Jansen_2021   4.977360
# 65 16  ENSG00000149927 DOC2A     Exc_mega_eQTL        Jansen_2021   5.053711
# 66 16  ENSG00000149927 DOC2A     AC_DeJager_eQTL      AD            4.883509
# 67 16  ENSG00000149927 DOC2A     AC_DeJager_eQTL      AD            4.780444
# 68 16  ENSG00000149927 DOC2A     MSBB_BM36_pQTL       AD           -4.761236
# 69 16  ENSG00000149927 DOC2A     AC_DeJager_eQTL      image_Aging2 -5.874356
# 70 16  ENSG00000149927 DOC2A     DLPFC_Bennett_pQTL   image_Aging2  6.486572
# 71 16  ENSG00000149927 DOC2A     Exc_DeJager_eQTL     image_Aging2 -5.898468
# 72 16  ENSG00000149927 DOC2A     Exc_mega_eQTL        image_Aging2 -5.825771
# 73 16  ENSG00000149927 DOC2A     MSBB_BM36_pQTL       image_Aging2  5.966588
# 74 16  ENSG00000149927 DOC2A     PCC_DeJager_eQTL     image_Aging2  5.884108
#    twas_pval    start     end       method  is_imputable is_selected_method
# 1  1.603403e-06 151093575 151093576 bayes_r TRUE         FALSE
# 2  1.778594e-09 151093575 151093576 lasso   TRUE         FALSE
# 3  1.701694e-06 151093575 151093576 enet    TRUE         FALSE
# 4  3.196469e-11 151093575 151093576 lasso   TRUE         FALSE
# 5  8.136249e-07 147240000 154960000 lasso   TRUE         FALSE
# 6  5.097601e-08 147240000 154960000 lasso   TRUE         FALSE
# 7  1.977744e-07  46225387  46225388 mrash   TRUE          TRUE
# 8  1.669526e-07  46225387  46225388 mvsusie TRUE          TRUE
# 9  8.892076e-08  46225387  46225388 mrash   TRUE          TRUE
# 10 1.173393e-07  46225387  46225388 bayes_r TRUE          TRUE
# 11 2.016456e-07  46225387  46225388 mvsusie TRUE          TRUE
# 12 8.417423e-08  46225387  46225388 lasso   TRUE          TRUE
# 13 1.780361e-07  46225387  46225388 mvsusie TRUE          TRUE
# 14 6.345926e-08  46225387  46225388 lasso   TRUE          TRUE
# 15 1.533218e-07  46225387  46225388 mrash   TRUE          TRUE
# 16 1.045797e-06  46225387  46225388 mvsusie TRUE          TRUE
# 17 2.639043e-07  46225387  46225388 enet    TRUE          TRUE
# 18 1.644386e-07  46225387  46225388 mvsusie TRUE          TRUE
# 19 1.410839e-08  46225387  46225388 enet    TRUE          TRUE
# 20 7.636911e-08  46225387  46225388 bayes_r TRUE          TRUE
# 21 8.062188e-08  46225387  46225388 mrash   TRUE          TRUE
# 22 1.397498e-07  46225387  46225388 mvsusie TRUE          TRUE
# 23 6.412571e-09  42560000  47225389 mrash   TRUE          TRUE
# 24 2.314200e-08  42560000  47225389 mvsusie TRUE          TRUE
# 25 2.036135e-09  42560000  47225389 mrash   TRUE          TRUE
# 26 5.250783e-08  42560000  47225389 mvsusie TRUE          TRUE
# 27 3.117600e-09  42560000  47225389 bayes_r TRUE          TRUE
# 28 2.144693e-08  42560000  47225389 susie   TRUE          TRUE
# 29 1.964616e-07  42560000  47225389 susie   TRUE          TRUE
# 30 3.785549e-09  42560000  47225389 bayes_r TRUE          TRUE
# ⋮  ⋮            ⋮         ⋮         ⋮       ⋮            ⋮
# 45 4.994041e-10 42560000  47225389  enet    TRUE          TRUE
# 46 4.488863e-07 42560000  50760000  susie   TRUE          TRUE
# 47 9.805158e-08 42560000  50760000  mrmash  TRUE          TRUE
# 48 1.318575e-07 46590667  46590668  susie   TRUE          TRUE
# 49 1.224027e-09 46590667  46590668  mvsusie TRUE          TRUE
# 50 2.291835e-07 42560000  50760000  mvsusie TRUE         FALSE
# 51 3.160821e-09 28360000  34000000  lasso   TRUE          TRUE
# 52 4.509887e-12 29899545  29899546  bayes_l TRUE          TRUE
# 53 1.020019e-08 29899545  29899546  lasso   TRUE          TRUE
# 54 3.813889e-08 29899545  29899546  susie   TRUE          TRUE
# 55 4.779938e-10 30023268  30023269  mvsusie TRUE         FALSE
# 56 5.703746e-10 30023268  30023269  bayes_l TRUE          TRUE
# 57 2.906974e-10 30023268  30023269  mrash   TRUE         FALSE
# 58 1.990946e-11 30023268  30023269  lasso   TRUE         FALSE
# 59 2.314087e-09 30023268  30023269  susie   TRUE         FALSE
# 60 1.775532e-11 30023268  30023269  susie   TRUE         FALSE
# 61 3.932883e-10 30023268  30023269  mvsusie TRUE         FALSE
# 62 1.108556e-09 30023268  30023269  susie   TRUE          TRUE
# 63 1.928218e-09 30023268  30023269  susie   TRUE         FALSE
# 64 6.445742e-07 30023268  30023269  mrash   TRUE         FALSE
# 65 4.333066e-07 30023268  30023269  mrash   TRUE         FALSE
# 66 1.042146e-06 30023268  30023269  lasso   TRUE         FALSE
# 67 1.749082e-06 30023268  30023269  enet    TRUE         FALSE
# 64  6.190727         Positive
# 65  6.363205         Positive
# 66  5.982071         Positive
# 67  5.757190         Positive
# 68  5.715770         Negative
# 69  8.372132         Negative
# 70 10.056450         Positive
# 71  8.435462         Negative
# 72  8.245274         Negative
# 73  8.615708         Positive
# 74  8.397715         Positive

# %%
plot_data <- AD2_story_genes_selected %>%
    mutate(
      # Calculate -log10(bonferroni p-value)
      neg_log_twas_pval = -log10(twas_pval),
      # Create color factor based on twas_z sign
      twas_z_sign = ifelse(twas_z < 0, "Negative", "Positive")
    )

# Calculate threshold line for p = 0.05
# threshold_line <- -log10(0.05)

# %%
library(ggplot2)
library(dplyr)
library(ggrepel)

# --- Process data ---
plot_data_processed <- plot_data %>%
  ungroup() %>%
  mutate(
    # Extract cell type
    cell_type = case_when(
      grepl("Exc", context) ~ "Exc",
      grepl("Inh", context) ~ "Inh",
      grepl("Mic", context) ~ "Mic",
      grepl("OPC", context) ~ "OPC",
      grepl("Oli", context) ~ "Oli",
      grepl("monocyte", context) ~ "monocyte",
      TRUE ~ "bulk"
    ),
    # Extract QTL type
    qtl_type = case_when(
      grepl("eQTL", context) ~ "eQTL",
      grepl("pQTL", context) ~ "pQTL",
      TRUE ~ "other"
    ),
    # Extract cohort
    cohort = case_when(
      grepl("PCC", context) ~ "PCC",
      grepl("AC", context) ~ "AC",
      grepl("DLPFC", context) ~ "DLPFC",
      grepl("Knight", context) ~ "Knight",
      grepl("MSBB", context) ~ "MSBB",
      grepl("ROSMAP", context) ~ "ROSMAP",
      grepl("DeJager", context) ~ "DeJager",
      grepl("mega", context) ~ "mega",
      TRUE ~ "Unknown"
    ),
    # Simplify gwas_study names
    gwas_study = case_when(
      startsWith(gwas_study, "image_") ~ paste0("i", substr(gwas_study, 7, nchar(gwas_study))),
      gwas_study == "Telomere_pc1" ~ "Telomere\n length",
      TRUE ~ gwas_study
    ),
    cell_qtl_label = paste0(cell_type, "_", qtl_type)
  )

# Fixed order for x-axis contexts
xqtl_context_order <- plot_data_processed %>%
  select(cell_qtl_label, cell_type, qtl_type) %>%
  distinct() %>%
  arrange(cell_type != "bulk",
          factor(cell_type, levels = c("Exc","Inh","Mic","Oli","OPC","monocyte","bulk")),
          qtl_type) %>%
  pull(cell_qtl_label)

# Define custom GWAS study order
gwas_order <- c("AD", "Telomere\n length", "iAD2", "iAging2")

# Apply factors
plot_data_processed <- plot_data_processed %>%
  mutate(
    cell_qtl_label = factor(cell_qtl_label, levels = xqtl_context_order),
    gwas_study = factor(gwas_study, levels = gwas_order)
  ) 

# KEY FIX: Create unique gene_cell_qtl combinations WITHIN each GWAS study
# This ensures same gene + cell_qtl_label always gets the same x_position
plot_data_processed <- plot_data_processed %>%
  group_by(gwas_study) %>%
  mutate(
    gene_cell_qtl = paste0(gene_name, "_", cell_qtl_label)
  ) %>%
  # Create position mapping based on unique combinations (not on all rows)
  group_by(gwas_study) %>%
  mutate(
    x_position = as.numeric(factor(gene_cell_qtl, 
                                   levels = unique(gene_cell_qtl[order(gene_name, cell_qtl_label)])))
  ) %>%
  ungroup()

# Calculate width metrics for panel sizing
gwas_panel_widths <- plot_data_processed %>%
  group_by(gwas_study) %>%
  summarise(
    n_genes = n_distinct(gene_name),
    n_cell_qtl = n_distinct(cell_qtl_label),
    n_combinations = n_distinct(gene_name, cell_qtl_label),
    .groups = "drop"
  ) %>%
  mutate(
    panel_width = n_combinations * 0.3 + n_genes * 0.6,
    width_ratio = panel_width / sum(panel_width)
  )

# Calculate gene boundaries for rectangles
gene_boundaries <- plot_data_processed %>%
  group_by(gwas_study, gene_name) %>%
  summarise(
    xmin = min(x_position) - 0.5,
    xmax = max(x_position) + 0.5,
    .groups = "drop"
  )

# Compute gene label positions
gene_positions <- plot_data_processed %>%
  group_by(gwas_study, gene_name) %>%
  summarise(
    xpos = mean(x_position),
    .groups = "drop"
  )

# Get max y value for positioning gene labels
max_y <- max(-log10(plot_data_processed$twas_pval), na.rm = TRUE)

# Get unique x positions and labels for axis (one per unique combination per GWAS)
axis_labels <- plot_data_processed %>%
  select(gwas_study, x_position, cell_qtl_label, gene_cell_qtl) %>%
  distinct() %>%
  arrange(gwas_study, x_position)

# ---- Build plot with flexible panel widths ----
p_combined <- ggplot(plot_data_processed,
                     aes(x = x_position, y = neg_log_twas_pval, color = twas_z_sign)) +
  # Add gene grouping rectangles
  geom_rect(
    data = gene_boundaries,
    aes(xmin = xmin, xmax = xmax, ymin = -Inf, ymax = Inf),
    fill = NA, color = "gray30", linewidth = 1,
    inherit.aes = FALSE
  ) +
  geom_point(size = 2.5, alpha = 0.8) +
  # Add cohort labels with repel
  geom_text_repel(
    aes(label = cohort),
    size = 2.5,
    fontface = "bold",
    color = "black",
    box.padding = 0.35,
    point.padding = 0.3,
    segment.color = "grey50",
    segment.size = 0.3,
    max.overlaps = 30,
    min.segment.length = 0,
    direction = "both",
    seed = 123,
    force = 2,
    force_pull = 0.5
  ) +
  geom_hline(yintercept = -log10(2.5e-6), linetype = "dashed", color = "red") +
  facet_grid(. ~ gwas_study, scales = "free_x", space = "free_x") +
  scale_color_manual(values = c("Positive" = "#E74C3C", "Negative" = "#3498DB")) +
  scale_x_continuous(
    breaks = function(limits) {
      # Get x positions within current panel's range
      current_positions <- axis_labels$x_position[
        axis_labels$x_position >= limits[1] & 
        axis_labels$x_position <= limits[2]
      ]
      unique(current_positions)
    },
    labels = function(breaks) {
      # Map breaks to labels
      sapply(breaks, function(b) {
        matched <- axis_labels[axis_labels$x_position == b, ]
        if(nrow(matched) > 0) {
          as.character(matched$cell_qtl_label[1])
        } else {
          ""
        }
      })
    }
  ) +
  theme_bw(base_size = 16) +
  theme(
    strip.background = element_rect(color = "black", fill = "white", linewidth = 1.2),
    strip.text = element_text(face = "bold", size = 14),
    axis.text.x = element_text(angle = 45, hjust = 1, size = 14, face = "bold"),
    axis.title.x = element_blank(),
    panel.grid.major.x = element_blank(),
    panel.spacing.x = unit(0.5, "lines"),
    legend.position = "bottom",
    plot.margin = margin(10, 10, 10, 10)
  ) +
  labs(y = bquote(-log[10]~italic(p)), color = "TWAS Z-score") +
  # Annotate gene names above
  geom_text(
    data = gene_positions,
    aes(x = xpos, y = max_y * 1.25, label = gene_name),
    inherit.aes = FALSE,
    size = 4,
    fontface = "bold.italic",
    vjust = 0
  ) +
  coord_cartesian(clip = "off", ylim = c(5, max_y * 1.35))

print(p_combined)

# Calculate optimal total width based on content
scale_factor <- 1.2
total_width <- max(20, sum(gwas_panel_widths$panel_width) * scale_factor + 1)

ggsave("AD2_gene_plot_by_gwas.png", p_combined,
       width = total_width, height = 9, dpi = 300, bg = "white")

# Print detailed width information
cat("\n=== GWAS Panel Width Information ===\n")
print(gwas_panel_widths %>% select(gwas_study, n_genes, n_cell_qtl, n_combinations, panel_width))
cat("\nTotal plot width:", round(total_width, 1), "inches\n")
cat("\nWidth breakdown:\n")
for(i in 1:nrow(gwas_panel_widths)) {
  cat(sprintf("  %s: %d genes × %d cell_qtl = %d combinations → %.1f inches (%.1f%%)\n", 
              gwas_panel_widths$gwas_study[i],
              gwas_panel_widths$n_genes[i],
              gwas_panel_widths$n_cell_qtl[i],
              gwas_panel_widths$n_combinations[i],
              gwas_panel_widths$panel_width[i],
              gwas_panel_widths$width_ratio[i] * 100))
}
# Out:
# === GWAS Panel Width Information ===
# # A tibble: 4 × 5
#   gwas_study          n_genes n_cell_qtl n_combinations panel_width
#   <fct>                 <int>      <int>          <int>       <dbl>
# 1 "AD"                      5          9             15         7.5
# 2 "Telomere\n length"       1          1              1         0.9
# 3 "iAD2"                    3          7             10         4.8
# 4 "iAging2"                 3          4              5         3.3
#
# Total plot width: 20.8 inches
#
# Width breakdown:
#   AD: 5 genes × 9 cell_qtl = 15 combinations → 7.5 inches (45.5%)
#   Telomere
#  length: 1 genes × 1 cell_qtl = 1 combinations → 0.9 inches (5.5%)
#   iAD2: 3 genes × 7 cell_qtl = 10 combinations → 4.8 inches (29.1%)
#   iAging2: 3 genes × 4 cell_qtl = 5 combinations → 3.3 inches (20.0%)
# plot without title

# %%
plot_data_processed
# Out:
#    chr molecular_id    gene_name context              gwas_study
# 1   5  ENSG00000145901 TNIP1     Exc_DeJager_eQTL     AD
# 2   5  ENSG00000145901 TNIP1     Exc_DeJager_eQTL     AD
# 3   5  ENSG00000145901 TNIP1     Exc_DeJager_eQTL     AD
# 4   5  ENSG00000145901 TNIP1     Exc_DeJager_eQTL     AD
# 5   5  ENSG00000145901 TNIP1     Exc_DeJager_eQTL     iAD2
# 6   5  ENSG00000145901 TNIP1     Exc_DeJager_eQTL     iAging2
# 7  17  ENSG00000120071 KANSL1    AC_DeJager_eQTL      AD
# 8  17  ENSG00000120071 KANSL1    Ast_DeJager_eQTL     AD
# 9  17  ENSG00000120071 KANSL1    Ast_mega_eQTL        AD
# 10 17  ENSG00000120071 KANSL1    BM_22_MSBB_eQTL      AD
# 11 17  ENSG00000120071 KANSL1    Exc_DeJager_eQTL     AD
# 12 17  ENSG00000120071 KANSL1    Exc_mega_eQTL        AD
# 13 17  ENSG00000120071 KANSL1    Inh_DeJager_eQTL     AD
# 14 17  ENSG00000120071 KANSL1    Inh_mega_eQTL        AD
# 15 17  ENSG00000120071 KANSL1    Knight_eQTL_brain    AD
# 16 17  ENSG00000120071 KANSL1    Mic_DeJager_eQTL     AD
# 17 17  ENSG00000120071 KANSL1    Mic_mega_eQTL        AD
# 18 17  ENSG00000120071 KANSL1    OPC_DeJager_eQTL     AD
# 19 17  ENSG00000120071 KANSL1    OPC_mega_eQTL        AD
# 3  DeJager Exc_eQTL       TNIP1_Exc_eQTL    15
# 4  DeJager Exc_eQTL       TNIP1_Exc_eQTL    15
# 5  DeJager Exc_eQTL       TNIP1_Exc_eQTL    10
# 6  DeJager Exc_eQTL       TNIP1_Exc_eQTL     5
# 7  AC      bulk_eQTL      KANSL1_bulk_eQTL   5
# 8  DeJager bulk_eQTL      KANSL1_bulk_eQTL   5
# 9  mega    bulk_eQTL      KANSL1_bulk_eQTL   5
# 10 MSBB    bulk_eQTL      KANSL1_bulk_eQTL   5
# 11 DeJager Exc_eQTL       KANSL1_Exc_eQTL    6
# 12 mega    Exc_eQTL       KANSL1_Exc_eQTL    6
# 13 DeJager Inh_eQTL       KANSL1_Inh_eQTL    7
# 14 mega    Inh_eQTL       KANSL1_Inh_eQTL    7
# 15 Knight  bulk_eQTL      KANSL1_bulk_eQTL   5
# 16 DeJager Mic_eQTL       KANSL1_Mic_eQTL    8
# 17 mega    Mic_eQTL       KANSL1_Mic_eQTL    8
# 18 DeJager OPC_eQTL       KANSL1_OPC_eQTL   10
# 19 mega    OPC_eQTL       KANSL1_OPC_eQTL   10
# 20 DeJager Oli_eQTL       KANSL1_Oli_eQTL    9
# 21 mega    Oli_eQTL       KANSL1_Oli_eQTL    9
# 22 PCC     bulk_eQTL      KANSL1_bulk_eQTL   5
# 23 AC      bulk_eQTL      KANSL1_bulk_eQTL   1
# 24 DeJager bulk_eQTL      KANSL1_bulk_eQTL   1
# 25 mega    bulk_eQTL      KANSL1_bulk_eQTL   1
# 26 MSBB    bulk_eQTL      KANSL1_bulk_eQTL   1
# 27 MSBB    bulk_eQTL      KANSL1_bulk_eQTL   1
# 28 MSBB    bulk_eQTL      KANSL1_bulk_eQTL   1
# 29 MSBB    bulk_eQTL      KANSL1_bulk_eQTL   1
# 30 DLPFC   bulk_eQTL      KANSL1_bulk_eQTL   1
# ⋮  ⋮       ⋮              ⋮                 ⋮
# 45 mega    Mic_eQTL       KANSL1_Mic_eQTL    4
# 46 mega    Oli_eQTL       NSF_Oli_eQTL       1
# 47 DLPFC   bulk_eQTL      NSF_bulk_eQTL      8
# 48 Knight  bulk_eQTL      NSF_bulk_eQTL     11
# 49 ROSMAP  monocyte_eQTL  NSF_monocyte_eQTL 12
# 50 DeJager Oli_eQTL       NSF_Oli_eQTL       9
# 51 DeJager Oli_eQTL       SEZ6L2_Oli_eQTL    4
# 52 DeJager OPC_eQTL       SEZ6L2_OPC_eQTL   14
# 53 DeJager Oli_eQTL       SEZ6L2_Oli_eQTL   13
# 54 mega    Oli_eQTL       SEZ6L2_Oli_eQTL   13
# 55 AC      bulk_eQTL      DOC2A_bulk_eQTL    1
# 56 MSBB    bulk_eQTL      DOC2A_bulk_eQTL    1
# 57 DLPFC   bulk_pQTL      DOC2A_bulk_pQTL    3
# 58 DeJager Exc_eQTL       DOC2A_Exc_eQTL     4
# 59 mega    Exc_eQTL       DOC2A_Exc_eQTL     4
# 60 MSBB    bulk_pQTL      DOC2A_bulk_pQTL    3
# 61 PCC     bulk_eQTL      DOC2A_bulk_eQTL    1
# 62 PCC     bulk_other     DOC2A_bulk_other   2
# 63 PCC     bulk_other     DOC2A_bulk_other   2
# 64 AC      bulk_eQTL      DOC2A_bulk_eQTL    1
# 65 mega    Exc_eQTL       DOC2A_Exc_eQTL     4
# 66 AC      bulk_eQTL      DOC2A_bulk_eQTL    1
# 67 AC      bulk_eQTL      DOC2A_bulk_eQTL    1
# 68 MSBB    bulk_pQTL      DOC2A_bulk_pQTL    3
# 69 AC      bulk_eQTL      DOC2A_bulk_eQTL    1
# 70 DLPFC   bulk_pQTL      DOC2A_bulk_pQTL    2
# 71 DeJager Exc_eQTL       DOC2A_Exc_eQTL     3
# 72 mega    Exc_eQTL       DOC2A_Exc_eQTL     3
# 73 MSBB    bulk_pQTL      DOC2A_bulk_pQTL    2
# 74 PCC     bulk_eQTL      DOC2A_bulk_eQTL    1

# %%
ggsave("twas_AD2.png", plot = p_gene_grouped_AD2, width = 16, height = 10, dpi = 300)

# %% [markdown]
# ## image_AD1

# %%
annotated_all |> filter(gene_name %in% c("MYRF", "TMEM258", "FADS2", "FADS1", "MARK2", "FAM118A")) |> filter(twas_pval < 2.5*1e-6, gwas_study == "image_Aging5")
# Out:
#   chr molecular_id    gene_name context            gwas_study   twas_z
# 1 11  ENSG00000149485 FADS1     DLPFC_DeJager_eQTL image_Aging5 -4.734663
#   twas_pval    start    end      method is_imputable is_selected_method
# 1 2.194198e-06 60799627 64320000 mrash  TRUE         FALSE
#   rsq_cv     pval_cv      type block
# 1 0.08704708 1.973297e-17 eQTL chr11_60339997_63818332

# %%
SREBP2_story_genes = annotated_all |> filter(gene_name %in% c("NBEAL1", "SCAP")) |> filter(is_selected_method, twas_pval < 2.5*1e-6)
dim(SREBP2_story_genes)
SREBP2_story_genes = SREBP2_story_genes |> arrange(gene_name, gwas_study)
# Out:
# [1] 24 16

# %%
SREBP2_story_genes = SREBP2_story_genes |> mutate(gwas_study = ifelse(grepl("Jansen|Bellenguez|Wightman", gwas_study), "AD", gwas_study)) |> mutate(context = ifelse(grepl("MSBB", context), "MSBB_eQTL", context)) |> mutate(context = str_replace(context, 
                               "^(.+?_sQTL)[^:]*:.*:(clu_\\d+_\\+):([A-Z]+):.*$", 
                               "\\1:\\2:\\3"))

# %%
# SREBP1_story_genes

NBEAL1_selected <- annotated_all |> filter(type == "eQTL", twas_pval < 2.5e-6) |>
  filter(gene_name == "NBEAL1") |> 
  mutate(gwas_study = ifelse(grepl("Bellenguez|Wightman|Jansen", gwas_study), "AD", gwas_study)) |> 
  group_by(gwas_study,context) |> 
  slice_min(twas_pval, n = 1, with_ties = FALSE)

# NBEAL1_selected = NBEAL1_selected[-c(5, 6, 9), ]
NBEAL1_selected
# KANSL1_added = AD2_story_genes |> filter(type == "eQTL") |>
#   filter(gene_name == "KANSL1") |>
#   filter(str_detect(context, "Exc")) |>
#   group_by(gwas_study) |> 
#   slice_min(twas_pval, n = 1, with_ties = FALSE)
# KANSL1_selected = KANSL1_selected |> filter(!gwas_study %in% c("Bellenguez_2022"))
#   KANSL1_selected = bind_rows(KANSL1_selected, KANSL1_added)
# KANSL1_selected
# Out:
#    chr molecular_id    gene_name context            gwas_study   twas_z
# 1  2   ENSG00000144426 NBEAL1    AC_DeJager_eQTL    AD           4.771941
# 2  2   ENSG00000144426 NBEAL1    BM_10_MSBB_eQTL    AD           5.058455
# 3  2   ENSG00000144426 NBEAL1    BM_22_MSBB_eQTL    AD           5.032783
# 4  2   ENSG00000144426 NBEAL1    BM_36_MSBB_eQTL    AD           5.053154
# 5  2   ENSG00000144426 NBEAL1    BM_44_MSBB_eQTL    AD           5.032025
# 6  2   ENSG00000144426 NBEAL1    DLPFC_DeJager_eQTL AD           5.120726
# 7  2   ENSG00000144426 NBEAL1    Exc_DeJager_eQTL   AD           5.088813
# 8  2   ENSG00000144426 NBEAL1    Knight_eQTL_brain  AD           5.181194
# 9  2   ENSG00000144426 NBEAL1    PCC_DeJager_eQTL   AD           5.172089
# 10 2   ENSG00000144426 NBEAL1    AC_DeJager_eQTL    image_Aging5 7.579014
# 11 2   ENSG00000144426 NBEAL1    Ast_DeJager_eQTL   image_Aging5 5.044021
# 12 2   ENSG00000144426 NBEAL1    BM_10_MSBB_eQTL    image_Aging5 8.679166
# 13 2   ENSG00000144426 NBEAL1    BM_22_MSBB_eQTL    image_Aging5 8.730277
# 14 2   ENSG00000144426 NBEAL1    BM_36_MSBB_eQTL    image_Aging5 8.683500
# 15 2   ENSG00000144426 NBEAL1    BM_44_MSBB_eQTL    image_Aging5 8.683990
# 16 2   ENSG00000144426 NBEAL1    DLPFC_DeJager_eQTL image_Aging5 7.767398
# 17 2   ENSG00000144426 NBEAL1    Exc_DeJager_eQTL   image_Aging5 8.682402
# 18 2   ENSG00000144426 NBEAL1    Exc_mega_eQTL      image_Aging5 6.326938
# 19 2   ENSG00000144426 NBEAL1    Knight_eQTL_brain  image_Aging5 8.173618
# 20 2   ENSG00000144426 NBEAL1    Oli_mega_eQTL      image_Aging5 5.976667
# 21 2   ENSG00000144426 NBEAL1    PCC_DeJager_eQTL   image_Aging5 8.010097
#    twas_pval    start     end       method  is_imputable is_selected_method
# 1  1.824592e-06 203014877 203014878 mvsusie TRUE          TRUE
# 2  4.226666e-07 203014877 203014878 bayes_r TRUE         FALSE
# 3  4.834103e-07 203014877 203014878 mvsusie TRUE         FALSE
# 4  4.345722e-07 203014877 203014878 enet    TRUE         FALSE
# 5  4.853266e-07 203014877 203014878 mvsusie TRUE          TRUE
# 6  3.043608e-07 203014877 203014878 mvsusie TRUE         FALSE
# 7  3.603123e-07 203014877 203014878 mvsusie TRUE         FALSE
# 8  2.204695e-07 203014877 203014878 susie   TRUE         FALSE
# 9  2.314909e-07 203014877 203014878 mvsusie TRUE         FALSE
# 10 3.481898e-14 202014878 204226378 mrash   TRUE         FALSE
# 11 4.558488e-07 202014878 204226378 mrmash  TRUE         FALSE
# 12 3.986806e-18 202014878 204226378 susie   TRUE          TRUE
# 13 2.540495e-18 202014878 204226378 susie   TRUE         FALSE
# 14 3.837730e-18 202014878 204226378 susie   TRUE         FALSE
# 15 3.821233e-18 202014878 204226378 susie   TRUE         FALSE
# 16 8.011451e-15 202014878 204226378 susie   TRUE         FALSE
# 17 3.874970e-18 202014878 204226378 mvsusie TRUE         FALSE
# 18 2.500744e-10 202014878 204226378 lasso   TRUE         FALSE
# 19 2.992767e-16 202014878 204226378 susie   TRUE         FALSE
# 20 2.277488e-09 202014878 204226378 mrash   TRUE          TRUE
# 21 1.146177e-15 202014878 204226378 lasso   TRUE         FALSE
#    rsq_cv      pval_cv      type block
# 1  0.191059313 4.588913e-29 eQTL chr2_201677542_203951659
# 2  0.122904600 2.416473e-09 eQTL chr2_201677542_203951659
# 3  0.073129188 1.240799e-05 eQTL chr2_201677542_203951659
# 4  0.090230828 3.512882e-06 eQTL chr2_201677542_203951659
# 5  0.167117498 9.854584e-12 eQTL chr2_201677542_203951659
# 6  0.039202483 2.264386e-08 eQTL chr2_201677542_203951659
# 7  0.012442908 2.239293e-02 eQTL chr2_201677542_203951659
# 8  0.046846242 2.375262e-05 eQTL chr2_201677542_203951659
# 9  0.095524902 3.240311e-11 eQTL chr2_201677542_203951659
# 10 0.171226762 3.756277e-26 eQTL chr2_201677542_203951659
# 11 0.039512395 2.468632e-05 eQTL chr2_201677542_203951659
# 12 0.146998425 3.019305e-11 eQTL chr2_201677542_203951659
# 13 0.039630583 8.330485e-04 eQTL chr2_201677542_203951659
# 14 0.138774790 3.322513e-09 eQTL chr2_201677542_203951659
# 15 0.155866052 3.366166e-11 eQTL chr2_201677542_203951659
# 16 0.030438801 5.286804e-07 eQTL chr2_201677542_203951659
# 17 0.010074665 2.239293e-02 eQTL chr2_201677542_203951659
# 18 0.004575484 3.664042e-02 eQTL chr2_201677542_203951659
# 19 0.046846242 2.375262e-05 eQTL chr2_201677542_203951659
# 20 0.012978611 1.134649e-03 eQTL chr2_201677542_203951659
# 21 0.049742281 1.335753e-06 eQTL chr2_201677542_203951659

# %%
SCAP_selected = annotated_all |> filter(type == "eQTL", twas_pval < 2.5e-6) |>
  filter(gene_name == "SCAP") |> 
  group_by(gwas_study,context) |> 
  slice_min(twas_pval, n = 1, with_ties = FALSE)
# SCAP_selected = SCAP_selected[-3,]
SCAP_selected
# Out:
#    chr molecular_id    gene_name context            gwas_study   twas_z
# 1  3   ENSG00000114650 SCAP      Exc_mega_eQTL      Telomere_pc1  6.101586
# 2  3   ENSG00000114650 SCAP      AC_DeJager_eQTL    image_AD1     5.529633
# 3  3   ENSG00000114650 SCAP      BM_10_MSBB_eQTL    image_AD1     5.624211
# 4  3   ENSG00000114650 SCAP      BM_36_MSBB_eQTL    image_AD1     5.472732
# 5  3   ENSG00000114650 SCAP      BM_44_MSBB_eQTL    image_AD1     5.599566
# 6  3   ENSG00000114650 SCAP      DLPFC_DeJager_eQTL image_AD1     5.876836
# 7  3   ENSG00000114650 SCAP      Exc_mega_eQTL      image_AD1    -5.757095
# 8  3   ENSG00000114650 SCAP      Inh_DeJager_eQTL   image_AD1    -6.707012
# 9  3   ENSG00000114650 SCAP      Inh_mega_eQTL      image_AD1    -5.480003
# 10 3   ENSG00000114650 SCAP      Knight_eQTL_brain  image_AD1     5.408284
# 11 3   ENSG00000114650 SCAP      PCC_DeJager_eQTL   image_AD1     5.777695
#    twas_pval    start    end      method is_imputable is_selected_method
# 1  1.050210e-09 46413681 50320000 mrash  TRUE         FALSE
# 2  3.209008e-08 46413681 50320000 mrmash TRUE         FALSE
# 3  1.863574e-08 46413681 50320000 susie  TRUE         FALSE
# 4  4.431504e-08 46413681 50320000 susie  TRUE         FALSE
# 5  2.148896e-08 46413681 50320000 lasso  TRUE         FALSE
# 6  4.181823e-09 46413681 50320000 mrash  TRUE         FALSE
# 7  8.557358e-09 46413681 50320000 enet   TRUE         FALSE
# 8  1.986506e-11 46413681 50320000 mrash  TRUE         FALSE
# 9  4.253188e-08 46413681 50320000 mrash  TRUE         FALSE
# 10 6.363147e-08 46413681 50320000 enet   TRUE          TRUE
# 11 7.573088e-09 46413681 50320000 enet   TRUE         FALSE
#    rsq_cv      pval_cv      type block
# 1  0.023017968 2.092731e-05 eQTL chr3_45108216_47545024
# 2  0.113762848 1.835353e-17 eQTL chr3_45108216_47545024
# 3  0.129403011 5.147137e-10 eQTL chr3_45108216_47545024
# 4  0.108766381 1.841610e-07 eQTL chr3_45108216_47545024
# 5  0.219840235 1.287964e-15 eQTL chr3_45108216_47545024
# 6  0.194088035 8.896897e-39 eQTL chr3_45108216_47545024
# 7  0.018828481 1.098126e-04 eQTL chr3_45108216_47545024
# 8  0.001095196 2.278862e-01 eQTL chr3_45108216_47545024
# 9  0.017202324 2.114666e-04 eQTL chr3_45108216_47545024
# 10 0.201503530 3.567258e-19 eQTL chr3_45108216_47545024
# 11 0.238083228 5.613815e-28 eQTL chr3_45108216_47545024

# %%
NBEAL1_SCAP = bind_rows(NBEAL1_selected, SCAP_selected)

# %%
plot_data <- NBEAL1_SCAP %>%
    mutate(
      # Calculate -log10(bonferroni p-value)
      neg_log_twas_pval = -log10(twas_pval),
      # Create color factor based on twas_z sign
      twas_z_sign = ifelse(twas_z < 0, "Negative", "Positive"),
      # Clean up context names for better display (optional)
      context_clean = gsub("_", " ", context)
    )

# Calculate threshold line for p = 0.05
# threshold_line <- -log10(0.05)

# %%
plot_data = plot_data |> filter(!(context == "ROSMAP_AC_sQTL:clu_18055_+:PR" & twas_z >-6))

# %%
plot_data
# Out:
#    chr molecular_id    gene_name context            gwas_study   twas_z
# 1  2   ENSG00000144426 NBEAL1    AC_DeJager_eQTL    AD            4.771941
# 2  2   ENSG00000144426 NBEAL1    BM_10_MSBB_eQTL    AD            5.058455
# 3  2   ENSG00000144426 NBEAL1    BM_22_MSBB_eQTL    AD            5.032783
# 4  2   ENSG00000144426 NBEAL1    BM_36_MSBB_eQTL    AD            5.053154
# 5  2   ENSG00000144426 NBEAL1    BM_44_MSBB_eQTL    AD            5.032025
# 6  2   ENSG00000144426 NBEAL1    DLPFC_DeJager_eQTL AD            5.120726
# 7  2   ENSG00000144426 NBEAL1    Exc_DeJager_eQTL   AD            5.088813
# 8  2   ENSG00000144426 NBEAL1    Knight_eQTL_brain  AD            5.181194
# 9  2   ENSG00000144426 NBEAL1    PCC_DeJager_eQTL   AD            5.172089
# 10 2   ENSG00000144426 NBEAL1    AC_DeJager_eQTL    image_Aging5  7.579014
# 11 2   ENSG00000144426 NBEAL1    Ast_DeJager_eQTL   image_Aging5  5.044021
# 12 2   ENSG00000144426 NBEAL1    BM_10_MSBB_eQTL    image_Aging5  8.679166
# 13 2   ENSG00000144426 NBEAL1    BM_22_MSBB_eQTL    image_Aging5  8.730277
# 14 2   ENSG00000144426 NBEAL1    BM_36_MSBB_eQTL    image_Aging5  8.683500
# 15 2   ENSG00000144426 NBEAL1    BM_44_MSBB_eQTL    image_Aging5  8.683990
# 16 2   ENSG00000144426 NBEAL1    DLPFC_DeJager_eQTL image_Aging5  7.767398
# 17 2   ENSG00000144426 NBEAL1    Exc_DeJager_eQTL   image_Aging5  8.682402
# 18 2   ENSG00000144426 NBEAL1    Exc_mega_eQTL      image_Aging5  6.326938
# 19 2   ENSG00000144426 NBEAL1    Knight_eQTL_brain  image_Aging5  8.173618
# 20 2   ENSG00000144426 NBEAL1    Oli_mega_eQTL      image_Aging5  5.976667
# 21 2   ENSG00000144426 NBEAL1    PCC_DeJager_eQTL   image_Aging5  8.010097
# 22 3   ENSG00000114650 SCAP      Exc_mega_eQTL      Telomere_pc1  6.101586
# 23 3   ENSG00000114650 SCAP      AC_DeJager_eQTL    image_AD1     5.529633
# 24 3   ENSG00000114650 SCAP      BM_10_MSBB_eQTL    image_AD1     5.624211
# 25 3   ENSG00000114650 SCAP      BM_36_MSBB_eQTL    image_AD1     5.472732
# 26 3   ENSG00000114650 SCAP      BM_44_MSBB_eQTL    image_AD1     5.599566
# 27 3   ENSG00000114650 SCAP      DLPFC_DeJager_eQTL image_AD1     5.876836
# 28 3   ENSG00000114650 SCAP      Exc_mega_eQTL      image_AD1    -5.757095
# 29 3   ENSG00000114650 SCAP      Inh_DeJager_eQTL   image_AD1    -6.707012
# 30 3   ENSG00000114650 SCAP      Inh_mega_eQTL      image_AD1    -5.480003
# 31 3   ENSG00000114650 SCAP      Knight_eQTL_brain  image_AD1     5.408284
# 32 3   ENSG00000114650 SCAP      PCC_DeJager_eQTL   image_AD1     5.777695
#    twas_pval    start     end       method  is_imputable is_selected_method
# 1  1.824592e-06 203014877 203014878 mvsusie TRUE          TRUE
# 2  4.226666e-07 203014877 203014878 bayes_r TRUE         FALSE
# 3  4.834103e-07 203014877 203014878 mvsusie TRUE         FALSE
# 4  4.345722e-07 203014877 203014878 enet    TRUE         FALSE
# 5  4.853266e-07 203014877 203014878 mvsusie TRUE          TRUE
# 6  3.043608e-07 203014877 203014878 mvsusie TRUE         FALSE
# 7  3.603123e-07 203014877 203014878 mvsusie TRUE         FALSE
# 8  2.204695e-07 203014877 203014878 susie   TRUE         FALSE
# 9  2.314909e-07 203014877 203014878 mvsusie TRUE         FALSE
# 10 3.481898e-14 202014878 204226378 mrash   TRUE         FALSE
# 11 4.558488e-07 202014878 204226378 mrmash  TRUE         FALSE
# 21 0.049742281 1.335753e-06 eQTL chr2_201677542_203951659 14.940748
# 22 0.023017968 2.092731e-05 eQTL chr3_45108216_47545024    8.978724
# 23 0.113762848 1.835353e-17 eQTL chr3_45108216_47545024    7.493629
# 24 0.129403011 5.147137e-10 eQTL chr3_45108216_47545024    7.729653
# 25 0.108766381 1.841610e-07 eQTL chr3_45108216_47545024    7.353449
# 26 0.219840235 1.287964e-15 eQTL chr3_45108216_47545024    7.667785
# 27 0.194088035 8.896897e-39 eQTL chr3_45108216_47545024    8.378634
# 28 0.018828481 1.098126e-04 eQTL chr3_45108216_47545024    8.067660
# 29 0.001095196 2.278862e-01 eQTL chr3_45108216_47545024   10.701910
# 30 0.017202324 2.114666e-04 eQTL chr3_45108216_47545024    7.371285
# 31 0.201503530 3.567258e-19 eQTL chr3_45108216_47545024    7.196328
# 32 0.238083228 5.613815e-28 eQTL chr3_45108216_47545024    8.120727
#    twas_z_sign context_clean
# 1  Positive    AC DeJager eQTL
# 2  Positive    BM 10 MSBB eQTL
# 3  Positive    BM 22 MSBB eQTL
# 4  Positive    BM 36 MSBB eQTL
# 5  Positive    BM 44 MSBB eQTL
# 6  Positive    DLPFC DeJager eQTL
# 7  Positive    Exc DeJager eQTL
# 8  Positive    Knight eQTL brain
# 9  Positive    PCC DeJager eQTL
# 10 Positive    AC DeJager eQTL
# 11 Positive    Ast DeJager eQTL
# 12 Positive    BM 10 MSBB eQTL
# 13 Positive    BM 22 MSBB eQTL
# 14 Positive    BM 36 MSBB eQTL
# 15 Positive    BM 44 MSBB eQTL
# 16 Positive    DLPFC DeJager eQTL
# 17 Positive    Exc DeJager eQTL
# 18 Positive    Exc mega eQTL
# 19 Positive    Knight eQTL brain
# 20 Positive    Oli mega eQTL
# 21 Positive    PCC DeJager eQTL
# 22 Positive    Exc mega eQTL
# 23 Positive    AC DeJager eQTL
# 24 Positive    BM 10 MSBB eQTL
# 25 Positive    BM 36 MSBB eQTL
# 26 Positive    BM 44 MSBB eQTL
# 27 Positive    DLPFC DeJager eQTL
# 28 Negative    Exc mega eQTL
# 29 Negative    Inh DeJager eQTL
# 30 Negative    Inh mega eQTL
# 31 Positive    Knight eQTL brain
# 32 Positive    PCC DeJager eQTL

# %%
library(ggplot2)
library(dplyr)
library(ggrepel)

# --- Process data ---
plot_data_processed <- plot_data %>%
  ungroup() %>%
  mutate(
    # Extract cell type
    cell_type = case_when(
      grepl("Exc", context) ~ "Exc",
      grepl("Inh", context) ~ "Inh",
      grepl("Mic", context) ~ "Mic",
      grepl("OPC", context) ~ "OPC",
      grepl("Oli", context) ~ "Oli",
      grepl("monocyte", context) ~ "monocyte",
      TRUE ~ "bulk"
    ),
    # Extract QTL type
    qtl_type = case_when(
      grepl("eQTL", context) ~ "eQTL",
      grepl("pQTL", context) ~ "pQTL",
      TRUE ~ "other"
    ),
    # Extract cohort
    cohort = case_when(
      grepl("PCC", context) ~ "PCC",
      grepl("AC", context) ~ "AC",
      grepl("DLPFC", context) ~ "DLPFC",
      grepl("Knight", context) ~ "Knight",
      grepl("MSBB", context) ~ "MSBB",
      grepl("ROSMAP", context) ~ "ROSMAP",
      grepl("DeJager", context) ~ "DeJager",
      grepl("mega", context) ~ "mega",
      TRUE ~ "Unknown"
    ),
    gwas_study = case_when(
        startsWith(gwas_study, "image_") ~ paste0("i", substr(gwas_study, 7, nchar(gwas_study))),
        gwas_study == "Telomere_pc1" ~ "Telomere length",
        TRUE ~ gwas_study
    ),
    cell_qtl_label = paste0(cell_type, "_", qtl_type)
  )

# Fixed order for x-axis contexts
xqtl_context_order <- plot_data_processed %>%
  select(cell_qtl_label, cell_type, qtl_type) %>%
  distinct() %>%
  arrange(cell_type != "bulk",
          factor(cell_type, levels = c("Exc","Inh","Mic","Oli","OPC","monocyte","bulk")),
          qtl_type) %>%
  pull(cell_qtl_label)

# Define custom GWAS study order
gwas_order <- c("AD", "image_Aging5", "Telomere_pc1", "image_AD1")

# Create gene-specific cell_qtl_label with ordering
plot_data_processed <- plot_data_processed %>%
  mutate(
    gene_cell_qtl = paste0(gene_name, "_", cell_qtl_label),
    cell_qtl_label = factor(cell_qtl_label, levels = xqtl_context_order),
    # Apply fixed order to gwas_study
    gwas_study = factor(gwas_study, levels = gwas_order)
  ) %>%
  group_by(gwas_study, gene_name) %>%
  mutate(gene_order = cur_group_id()) %>%
  ungroup() %>%
  arrange(gwas_study, gene_order, cell_qtl_label) %>%
  mutate(x_position = as.numeric(interaction(gwas_study, gene_name, cell_qtl_label, 
                                              drop = TRUE, lex.order = TRUE)))

# Calculate width metrics for flexible panel sizing
gwas_panel_widths <- plot_data_processed %>%
  group_by(gwas_study) %>%
  summarise(
    n_genes = n_distinct(gene_name),
    n_cell_qtl = n_distinct(cell_qtl_label),
    n_combinations = n_distinct(gene_name, cell_qtl_label),
    .groups = "drop"
  ) %>%
  mutate(
    panel_width = n_combinations * 0.8 + n_genes * 1.0,
    width_ratio = panel_width / sum(panel_width)
  )

# Calculate gene boundaries for rectangles
gene_boundaries <- plot_data_processed %>%
  group_by(gwas_study, gene_name) %>%
  summarise(
    xmin = min(x_position) - 0.5,
    xmax = max(x_position) + 0.5,
    .groups = "drop"
  )

# Compute gene label positions
gene_positions <- plot_data_processed %>%
  group_by(gwas_study, gene_name) %>%
  summarise(
    xpos = mean(x_position),
    .groups = "drop"
  )

# Get max y value for positioning gene labels
max_y <- max(-log10(plot_data_processed$twas_pval), na.rm = TRUE)

# ---- Build dot plot with facets ----
p_combined <- ggplot(plot_data_processed,
                     aes(x = x_position, y = neg_log_twas_pval, color = twas_z_sign)) +
  # Add gene grouping rectangles
  geom_rect(
    data = gene_boundaries,
    aes(xmin = xmin, xmax = xmax, ymin = -Inf, ymax = Inf),
    fill = NA, color = "gray30", linewidth = 1,
    inherit.aes = FALSE
  ) +
  geom_point(size = 2.5, alpha = 0.8) +
  # Add cohort labels with repel to avoid overlap
  geom_text_repel(
    aes(label = cohort),
    size = 2.5,
    fontface = "bold",
    color = "black",
    box.padding = 0.35,
    point.padding = 0.3,
    segment.color = "grey50",
    segment.size = 0.3,
    max.overlaps = 30,
    min.segment.length = 0,
    direction = "both",
    seed = 123,
    force = 2,
    force_pull = 0.5
  ) +
  geom_hline(yintercept = -log10(2.5e-6), linetype = "dashed", color = "red") +
  # Facet with ordered GWAS studies
  facet_wrap(~gwas_study, scales = "free_x", nrow = 1, strip.position = "top") +
  scale_color_manual(values = c("Positive" = "#E74C3C", "Negative" = "#3498DB")) +
  scale_x_continuous(
    breaks = plot_data_processed$x_position,
    labels = plot_data_processed$cell_qtl_label
  ) +
  theme_bw(base_size = 14) +
  theme(
    strip.background = element_rect(color = "black", fill = "white", linewidth = 1.2),
    strip.text = element_text(face = "bold", size = 14),
    axis.text.x = element_text(angle = 45, hjust = 1, size = 10, face = "bold"),
    axis.title.x = element_blank(),
    panel.grid.major.x = element_blank(),
    panel.spacing = unit(0.5, "lines"),
    legend.position = "bottom",
    plot.margin = margin(10, 10, 10, 10)
  ) +
  labs(y = bquote(-log[10]~italic(p)), color = "TWAS Z-score") +
  # Annotate gene names above
  geom_text(
    data = gene_positions,
    aes(x = xpos, y = max_y * 1.25, label = gene_name),
    inherit.aes = FALSE,
    size = 4,
    fontface = "bold.italic",
    vjust = 0
  ) +
  coord_cartesian(clip = "off", ylim = c(0, max_y * 1.35))

print(p_combined)

# Calculate optimal total width based on content
total_width <- max(25, sum(gwas_panel_widths$panel_width) + 3)

ggsave("AD1_gene_plot_by_gwas.png", p_combined,
       width = total_width, height = 9, dpi = 300, bg = "white")

# Print width information
print(gwas_panel_widths)
cat("\nTotal plot width:", total_width, "inches\n")
cat("\nWidth breakdown:\n")
for(i in 1:nrow(gwas_panel_widths)) {
  cat(sprintf("  %s: %.1f inches (%.1f%% of total)\n", 
              gwas_panel_widths$gwas_study[i],
              gwas_panel_widths$panel_width[i],
              gwas_panel_widths$width_ratio[i] * 100))
}
# Out:
# # A tibble: 4 × 6
#   gwas_study   n_genes n_cell_qtl n_combinations panel_width width_ratio
#   <fct>          <int>      <int>          <int>       <dbl>       <dbl>
# 1 AD                 1          2              2         2.6       0.232
# 2 image_Aging5       1          3              3         3.4       0.304
# 3 Telomere_pc1       1          1              1         1.8       0.161
# 4 image_AD1          1          3              3         3.4       0.304
#
# Total plot width: 25 inches
#
# Width breakdown:
#   AD: 2.6 inches (23.2% of total)
#   image_Aging5: 3.4 inches (30.4% of total)
#   Telomere_pc1: 1.8 inches (16.1% of total)
#   image_AD1: 3.4 inches (30.4% of total)
# plot without title

# %%
library(ggplot2)
library(dplyr)
library(ggrepel)

# --- Process data ---
plot_data_processed <- plot_data %>%
  ungroup() %>%
  mutate(
    # Extract cell type
    cell_type = case_when(
      grepl("Exc", context) ~ "Exc",
      grepl("Inh", context) ~ "Inh",
      grepl("Mic", context) ~ "Mic",
      grepl("OPC", context) ~ "OPC",
      grepl("Oli", context) ~ "Oli",
      grepl("monocyte", context) ~ "monocyte",
      TRUE ~ "bulk"
    ),
    # Extract QTL type
    qtl_type = case_when(
      grepl("eQTL", context) ~ "eQTL",
      grepl("pQTL", context) ~ "pQTL",
      TRUE ~ "other"
    ),
    # Extract cohort
    cohort = case_when(
      grepl("PCC", context) ~ "PCC",
      grepl("AC", context) ~ "AC",
      grepl("DLPFC", context) ~ "DLPFC",
      grepl("Knight", context) ~ "Knight",
      grepl("MSBB", context) ~ "MSBB",
      grepl("ROSMAP", context) ~ "ROSMAP",
      grepl("DeJager", context) ~ "DeJager",
      grepl("mega", context) ~ "mega",
      TRUE ~ "Unknown"
    ),
    gwas_study = case_when(
        startsWith(gwas_study, "image_") ~ paste0("i", substr(gwas_study, 7, nchar(gwas_study))),
        gwas_study == "Telomere_pc1" ~ "Telomere length",
        TRUE ~ gwas_study
    ),
    cell_qtl_label = paste0(cell_type, "_", qtl_type)
  )

# Fixed order for x-axis contexts
xqtl_context_order <- plot_data_processed %>%
  select(cell_qtl_label, cell_type, qtl_type) %>%
  distinct() %>%
  arrange(cell_type != "bulk",
          factor(cell_type, levels = c("Exc","Inh","Mic","Oli","OPC","monocyte","bulk")),
          qtl_type) %>%
  pull(cell_qtl_label)

# Create gene-specific cell_qtl_label with ordering
plot_data_processed <- plot_data_processed %>%
  mutate(
    gene_cell_qtl = paste0(gene_name, "_", cell_qtl_label),
    cell_qtl_label = factor(cell_qtl_label, levels = xqtl_context_order)
  ) %>%
  group_by(gwas_study, gene_name) %>%
  mutate(gene_order = cur_group_id()) %>%
  ungroup() %>%
  arrange(gwas_study, gene_order, cell_qtl_label) %>%
  mutate(x_position = as.numeric(interaction(gwas_study, gene_name, cell_qtl_label, 
                                              drop = TRUE, lex.order = TRUE)))

# Calculate width metrics for flexible panel sizing
gwas_panel_widths <- plot_data_processed %>%
  group_by(gwas_study) %>%
  summarise(
    n_genes = n_distinct(gene_name),
    n_cell_qtl = n_distinct(cell_qtl_label),
    n_combinations = n_distinct(gene_name, cell_qtl_label),
    .groups = "drop"
  ) %>%
  mutate(
    panel_width = n_combinations * 0.8 + n_genes * 1.0,
    width_ratio = panel_width / sum(panel_width)
  )

# Calculate gene boundaries for rectangles
gene_boundaries <- plot_data_processed %>%
  group_by(gwas_study, gene_name) %>%
  summarise(
    xmin = min(x_position) - 0.5,
    xmax = max(x_position) + 0.5,
    .groups = "drop"
  )

# Compute gene label positions
gene_positions <- plot_data_processed %>%
  group_by(gwas_study, gene_name) %>%
  summarise(
    xpos = mean(x_position),
    .groups = "drop"
  )

# Get max y value for positioning gene labels
max_y <- max(-log10(plot_data_processed$twas_pval), na.rm = TRUE)

# ---- Build dot plot with facets ----
p_combined <- ggplot(plot_data_processed,
                     aes(x = x_position, y = neg_log_twas_pval, color = twas_z_sign)) +
  # Add gene grouping rectangles
  geom_rect(
    data = gene_boundaries,
    aes(xmin = xmin, xmax = xmax, ymin = -Inf, ymax = Inf),
    fill = NA, color = "gray30", linewidth = 1,
    inherit.aes = FALSE
  ) +
  geom_point(size = 2.5, alpha = 0.8) +
  # Add cohort labels with repel to avoid overlap
  geom_text_repel(
    aes(label = cohort),
    size = 2.5,
    fontface = "bold",
    color = "black",
    box.padding = 0.35,
    point.padding = 0.3,
    segment.color = "grey50",
    segment.size = 0.3,
    max.overlaps = 30,
    min.segment.length = 0,
    direction = "both",
    seed = 123,
    force = 2,
    force_pull = 0.5
  ) +
  geom_hline(yintercept = -log10(2.5e-6), linetype = "dashed", color = "red") +
  # KEPT: facet_wrap with square boxes
  facet_wrap(~gwas_study, scales = "free_x", nrow = 1, strip.position = "top") +
  scale_color_manual(values = c("Positive" = "#E74C3C", "Negative" = "#3498DB")) +
  scale_x_continuous(
    breaks = plot_data_processed$x_position,
    labels = plot_data_processed$cell_qtl_label
  ) +
  theme_bw(base_size = 14) +
  theme(
    # KEPT: square facet boxes
    strip.background = element_rect(color = "black", fill = "white", linewidth = 1.2),
    strip.text = element_text(face = "bold", size = 14),
    axis.text.x = element_text(angle = 45, hjust = 1, size = 10, face = "bold"),
    axis.title.x = element_blank(),
    panel.grid.major.x = element_blank(),
    panel.spacing = unit(0.5, "lines"),  # Space between facets
    legend.position = "bottom",
    plot.margin = margin(10, 10, 10, 10)
  ) +
  labs(y = bquote(-log[10]~italic(p)), color = "TWAS Z-score") +
  # Annotate gene names above
  geom_text(
    data = gene_positions,
    aes(x = xpos, y = max_y * 1.25, label = gene_name),
    inherit.aes = FALSE,
    size = 4,
    fontface = "bold.italic",
    vjust = 0
  ) +
  coord_cartesian(clip = "off", ylim = c(0, max_y * 1.35))

print(p_combined)

# Calculate optimal total width based on content
total_width <- max(25, sum(gwas_panel_widths$panel_width) + 3)

ggsave("gene_plot_by_gwas.png", p_combined,
       width = total_width, height = 9, dpi = 300, bg = "white")

# Print width information
print(gwas_panel_widths)
cat("\nTotal plot width:", total_width, "inches\n")
cat("\nWidth breakdown:\n")
for(i in 1:nrow(gwas_panel_widths)) {
  cat(sprintf("  %s: %.1f inches (%.1f%% of total)\n", 
              gwas_panel_widths$gwas_study[i],
              gwas_panel_widths$panel_width[i],
              gwas_panel_widths$width_ratio[i] * 100))
}
# Out:
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's fill values.”
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's fill values.”
# # A tibble: 2 × 6
#   gene_name n_gwas n_cell_qtl n_combinations panel_width width_ratio
#   <chr>      <int>      <int>          <int>       <dbl>       <dbl>
# 1 NBEAL1         2          3              5         6         0.536
# 2 SCAP           2          3              4         5.2       0.464
#
# Total plot width: 25 inches
#
# Width breakdown:
#   NBEAL1: 6.0 inches (53.6% of total)
#   SCAP: 5.2 inches (46.4% of total)
# plot without title

# %%
ggsave("twas_SREBP2_all_contexts.png", p_gene_grouped, width = 16, height = 8, dpi = 300)

# %% [markdown]
# ## Aging

# %%
annotated_all |> filter(gene_name %in% c("DNAJC5","GGT7", "NCOA6") , twas_pval < 2.5*1e-6) |> arrange(gene_name, gwas_study, context)#, gwas_study == 'TL1'
# annotated_all |> filter(gene_name == "TNF", twas_pval < 2.5*1e-6) #, gwas_study == 'TL1'
# annotated_all |> filter(str_detect(context, "Mic"), gwas_study == 'image_Aging3', twas_pval < 2.5*1e-6) |> pull(gene_name) |> unique()
# annotated_all |> filter(str_detect(context, "Mic"), gwas_study == 'image_AD1', twas_pval < 2.5*1e-6) |> pull(gene_name) |> unique()
# Out:
#    chr molecular_id    gene_name context              gwas_study   twas_z
# 1  20  ENSG00000101152 DNAJC5    BM_36_MSBB_eQTL      Telomere_pc1   8.616714
# 3  3   ENSG00000164077 MON1A     Ast_DeJager_eQTL           Telomere_pc1
# 4  3   ENSG00000164077 MON1A     Ast_DeJager_eQTL           Telomere_pc1
# 5  3   ENSG00000164077 MON1A     DLPFC_DeJager_eQTL         Telomere_pc1
# 6  3   ENSG00000164077 MON1A     PCC_DeJager_eQTL           Telomere_pc1
# 7  3   ENSG00000164077 MON1A     PCC_DeJager_eQTL           Telomere_pc1
# 8  3   ENSG00000164077 MON1A     PCC_DeJager_eQTL           Telomere_pc1
# 9  3   ENSG00000164077 MON1A     PCC_DeJager_eQTL           Telomere_pc1
# 10 3   ENSG00000164077 MON1A     PCC_DeJager_eQTL           Telomere_pc1
# 11 3   ENSG00000164077 MON1A     PCC_DeJager_eQTL           Telomere_pc1
# 12 3   ENSG00000164077 MON1A     PCC_DeJager_eQTL           Telomere_pc1
# 13 3   ENSG00000164077 MON1A     Exc_mega_eQTL              Telomere_pc1
# 14 3   ENSG00000164077 MON1A     Exc_mega_eQTL              Telomere_pc1
# 15 3   ENSG00000164077 MON1A     Exc_mega_eQTL              Telomere_pc1
# 16 3   ENSG00000164077 MON1A     Exc_mega_eQTL              Telomere_pc1
# 17 3   ENSG00000164077 MON1A     DLPFC_DeJager_eQTL         image_AD1
# 18 3   ENSG00000164077 MON1A     DLPFC_DeJager_eQTL         image_AD1
# 19 3   ENSG00000164077 MON1A     DLPFC_DeJager_eQTL         image_AD1
# 20 3   ENSG00000164077 MON1A     DLPFC_DeJager_eQTL         image_AD1
# 21 3   ENSG00000164077 MON1A     DLPFC_DeJager_eQTL         image_AD1
#    twas_z    twas_pval    start    end      method  is_imputable
# 1   5.482784 4.186841e-08 46680000 50930173 mrash   TRUE
# 2  -5.192607 2.073691e-07 46680000 50930173 bayes_l TRUE
# 3  -5.131576 2.873264e-07 46680000 50930173 bayes_r TRUE
# 4  -5.165670 2.395786e-07 46680000 50930173 lasso   TRUE
# 5   5.180704 2.210505e-07 46680000 50930173 lasso   TRUE
# 6   8.313951 9.256700e-17 46680000 50930173 bayes_l TRUE
# 7   8.228121 1.901724e-16 46680000 50930173 bayes_r TRUE
# 8   9.824938 8.792771e-23 46680000 50930173 enet    TRUE
# 9   9.382684 6.431413e-21 46680000 50930173 lasso   TRUE
# 10  8.794505 1.436794e-18 46680000 50930173 mrash   TRUE
# 11  5.347572 8.914207e-08 46680000 50930173 mrmash  TRUE
# 12  9.823034 8.960491e-23 46680000 50930173 susie   TRUE
# 13 -7.325486 2.380351e-13 46680000 50930173 enet    TRUE
# 14 -7.344412 2.066656e-13 46680000 50930173 lasso   TRUE
# 15 -7.127751 1.020222e-12 46680000 50930173 mrash   TRUE
# 16 -7.378189 1.604571e-13 46680000 50930173 susie   TRUE
# 17  5.257465 1.460543e-07 46680000 50930173 bayes_l TRUE
# 18  4.726893 2.279814e-06 46680000 50930173 bayes_r TRUE
# 19  4.766404 1.875431e-06 46680000 50930173 enet    TRUE
# 20  5.093724 3.510971e-07 46680000 50930173 mrash   TRUE
# 21  5.024491 5.047701e-07 46680000 50930173 mrmash  TRUE
#    is_selected_method rsq_cv        pval_cv      type block
# 1  FALSE               0.0396618734 3.878333e-03 pQTL chr3_47545024_52179438
# 2  FALSE              -0.0011279582 4.674169e-01 eQTL chr3_47545024_52179438
# 3  FALSE               0.0001086653 3.071554e-01 eQTL chr3_47545024_52179438
# 4  FALSE              -0.0007003522 4.007712e-01 eQTL chr3_47545024_52179438
# 5  FALSE               0.0113818396 1.613179e-03 eQTL chr3_47545024_52179438
# 6  FALSE               0.0119084484 1.241279e-02 eQTL chr3_47545024_52179438
# 7  FALSE               0.0079644615 3.381308e-02 eQTL chr3_47545024_52179438
# 8  FALSE               0.0107258788 1.671134e-02 eQTL chr3_47545024_52179438
# 9  FALSE               0.0182526594 2.590587e-03 eQTL chr3_47545024_52179438
# 10 FALSE               0.0162064946 4.276518e-03 eQTL chr3_47545024_52179438
# 11 FALSE               0.0143372104 6.780884e-03 eQTL chr3_47545024_52179438
# 12  TRUE               0.0351667970 4.387078e-05 eQTL chr3_47545024_52179438
# 13 FALSE               0.0143721827 6.484021e-04 eQTL chr3_47545024_52179438
# 14 FALSE               0.0170402907 2.234769e-04 eQTL chr3_47545024_52179438
# 15 FALSE               0.0067866871 1.430216e-02 eQTL chr3_47545024_52179438
# 16  TRUE               0.0180531144 1.493944e-04 eQTL chr3_47545024_52179438
# 17 FALSE               0.0221822070 1.673120e-05 eQTL chr3_47545024_52179438
# 18 FALSE               0.0208942113 2.872207e-05 eQTL chr3_47545024_52179438
# 19 FALSE               0.0123236285 1.077463e-03 eQTL chr3_47545024_52179438
# 20  TRUE               0.0236427262 9.072144e-06 eQTL chr3_47545024_52179438
# 21 FALSE               0.0193722676 5.444375e-05 eQTL chr3_47545024_52179438

# %%
Aging_cilia_genes |> filter(gene_name == "PLXNB1")
# Out:
#    chr molecular_id    gene_name context                    gwas_study
# 1  3   ENSG00000164050 PLXNB1    Inh_mega_eQTL              Telomere_pc1
# 2  3   ENSG00000164050 PLXNB1    Inh_mega_eQTL              Telomere_pc1
# 3  3   ENSG00000164050 PLXNB1    Inh_mega_eQTL              Telomere_pc1
# 4  3   ENSG00000164050 PLXNB1    MSBB_BM36_pQTL_chr3_O43157 image_AD1
# 5  3   ENSG00000164050 PLXNB1    monocyte_ROSMAP_eQTL       image_AD1
# 6  3   ENSG00000164050 PLXNB1    monocyte_ROSMAP_eQTL       image_AD1
# 7  3   ENSG00000164050 PLXNB1    monocyte_ROSMAP_eQTL       image_AD1
# 8  3   ENSG00000164050 PLXNB1    monocyte_ROSMAP_eQTL       image_AD1
# 9  3   ENSG00000164050 PLXNB1    monocyte_ROSMAP_eQTL       image_AD1
# 10 3   ENSG00000164050 PLXNB1    monocyte_ROSMAP_eQTL       image_AD1
# 11 3   ENSG00000164050 PLXNB1    monocyte_ROSMAP_eQTL       image_AD1
# 12 3   ENSG00000164050 PLXNB1    monocyte_ROSMAP_eQTL       image_Aging4
# 13 3   ENSG00000164050 PLXNB1    monocyte_ROSMAP_eQTL       image_Aging4
#    twas_z    twas_pval    start    end      method  is_imputable
# 1   6.087669 1.145662e-09 46680000 50320000 enet    TRUE
# 2   6.143722 8.060971e-10 46680000 50320000 lasso   TRUE
# 3   6.325496 2.524206e-10 46680000 50320000 mrash   TRUE
# 4  -5.102090 3.359237e-07 46680000 50320000 susie   TRUE
# 5  -5.927922 3.067915e-09 46680000 50320000 bayes_l TRUE
# 6  -5.398946 6.703362e-08 46680000 50320000 bayes_r TRUE
# 7  -6.072126 1.262278e-09 46680000 50320000 enet    TRUE
# 8  -6.757844 1.400607e-11 46680000 50320000 lasso   TRUE
# 9  -6.692782 2.189673e-11 46680000 50320000 mrash   TRUE
# 10 -5.977414 2.267078e-09 46680000 50320000 mrmash  TRUE
# 11 -5.897565 3.689042e-09 46680000 50320000 susie   TRUE
# 12 -5.486458 4.100739e-08 46680000 50320000 enet    TRUE
# 13 -4.748945 2.044803e-06 46680000 50320000 lasso   TRUE
#    is_selected_method rsq_cv       pval_cv      type block
# 1  FALSE               0.025099622 9.328429e-06 eQTL chr3_47545024_52179438
# 2   TRUE               0.025161733 9.103058e-06 eQTL chr3_47545024_52179438
# 3  FALSE               0.024517769 1.173079e-05 eQTL chr3_47545024_52179438
# 4  FALSE               0.012983987 6.653188e-02 pQTL chr3_47545024_52179438
# 5  FALSE               0.004165362 1.649273e-01 eQTL chr3_47545024_52179438
# 6  FALSE               0.002987016 1.970438e-01 eQTL chr3_47545024_52179438
# 7  FALSE              -0.004459236 9.732592e-01 eQTL chr3_47545024_52179438
# 8  FALSE              -0.003420997 6.298532e-01 eQTL chr3_47545024_52179438
# 9  FALSE               0.000903138 2.738231e-01 eQTL chr3_47545024_52179438
# 10  TRUE               0.031581146 4.263897e-03 eQTL chr3_47545024_52179438
# 11 FALSE              -0.003620109 6.646581e-01 eQTL chr3_47545024_52179438
# 12 FALSE              -0.004459236 9.732592e-01 eQTL chr3_47545024_52179438
# 13 FALSE              -0.003420997 6.298532e-01 eQTL chr3_47545024_52179438

# %%
Aging_cilia_genes |> filter(gene_name == "USP19")
# Out:
#   chr molecular_id    gene_name context                    gwas_study
# 1 3   ENSG00000172046 USP19     BM_44_MSBB_eQTL            Telomere_pc1
# 2 3   ENSG00000172046 USP19     MSBB_BM36_pQTL_chr3_O94966 Telomere_pc1
# 3 3   ENSG00000172046 USP19     MSBB_BM36_pQTL_chr3_O94966 Telomere_pc1
# 4 3   ENSG00000172046 USP19     monocyte_ROSMAP_eQTL       Telomere_pc1
# 5 3   ENSG00000172046 USP19     monocyte_ROSMAP_eQTL       Telomere_pc1
# 6 3   ENSG00000172046 USP19     monocyte_ROSMAP_eQTL       Telomere_pc1
# 7 3   ENSG00000172046 USP19     monocyte_ROSMAP_eQTL       image_AD1
# 8 3   ENSG00000172046 USP19     monocyte_ROSMAP_eQTL       image_AD1
# 9 3   ENSG00000172046 USP19     monocyte_ROSMAP_eQTL       image_AD1
#   twas_z    twas_pval    start    end      method  is_imputable
# 1  4.904352 9.373630e-07 46680000 50320000 enet    TRUE
# 2 -6.694346 2.166386e-11 46680000 50320000 mrash   TRUE
# 3 -8.552964 1.199677e-17 46680000 50320000 susie   TRUE
# 4 -5.800300 6.619619e-09 46680000 50320000 bayes_l TRUE
# 5 -5.124350 2.985652e-07 46680000 50320000 bayes_r TRUE
# 6 -4.812790 1.488378e-06 46680000 50320000 mrash   TRUE
# 7  5.529868 3.204717e-08 46680000 50320000 bayes_l TRUE
# 8  5.722808 1.047774e-08 46680000 50320000 bayes_r TRUE
# 9  4.953944 7.272426e-07 46680000 50320000 mrash   TRUE
#   is_selected_method rsq_cv       pval_cv    type block
# 1 FALSE              -0.001863853 0.46912926 eQTL chr3_47545024_52179438
# 2 FALSE              -0.003422431 0.54060810 pQTL chr3_47545024_52179438
# 3 FALSE              -0.005426760 0.91194525 pQTL chr3_47545024_52179438
# 4 FALSE               0.002320549 0.21840836 eQTL chr3_47545024_52179438
# 5  TRUE               0.014854467 0.03721703 eQTL chr3_47545024_52179438
# 6 FALSE               0.005959492 0.12678056 eQTL chr3_47545024_52179438
# 7 FALSE               0.002320549 0.21840836 eQTL chr3_47545024_52179438
# 8  TRUE               0.014854467 0.03721703 eQTL chr3_47545024_52179438
# 9 FALSE               0.005959492 0.12678056 eQTL chr3_47545024_52179438

# %%
Aging_cilia_genes |> filter(gene_name == "MAP4")
# Out:
#    chr molecular_id    gene_name context          gwas_study   twas_z
# 1  3   ENSG00000047849 MAP4      Oli_DeJager_eQTL Telomere_pc1 -7.285998
# 2  3   ENSG00000047849 MAP4      Oli_DeJager_eQTL Telomere_pc1 -7.336228
# 3  3   ENSG00000047849 MAP4      Oli_DeJager_eQTL Telomere_pc1 -6.146952
# 4  3   ENSG00000047849 MAP4      Oli_DeJager_eQTL Telomere_pc1 -5.065724
# 5  3   ENSG00000047849 MAP4      Oli_DeJager_eQTL Telomere_pc1 -7.658023
# 6  3   ENSG00000047849 MAP4      Oli_DeJager_eQTL Telomere_pc1 -5.619105
# 7  3   ENSG00000047849 MAP4      AC_DeJager_eQTL  image_AD1     4.756407
# 8  3   ENSG00000047849 MAP4      AC_DeJager_eQTL  image_AD1     4.879063
# 9  3   ENSG00000047849 MAP4      Ast_DeJager_eQTL image_AD1     5.621410
# 10 3   ENSG00000047849 MAP4      Inh_DeJager_eQTL image_AD1     4.982378
# 11 3   ENSG00000047849 MAP4      Inh_DeJager_eQTL image_AD1     4.955284
# 12 3   ENSG00000047849 MAP4      Inh_DeJager_eQTL image_AD1     5.089365
# 13 3   ENSG00000047849 MAP4      Inh_DeJager_eQTL image_AD1     4.954516
# 14 3   ENSG00000047849 MAP4      Inh_DeJager_eQTL image_AD1     5.322277
# 15 3   ENSG00000047849 MAP4      Oli_DeJager_eQTL image_AD1     4.850186
# 16 3   ENSG00000047849 MAP4      Oli_DeJager_eQTL image_AD1     5.092336
# 17 3   ENSG00000047849 MAP4      Exc_mega_eQTL    image_AD1     5.452515
# 18 3   ENSG00000047849 MAP4      Exc_mega_eQTL    image_AD1     6.050019
# 19 3   ENSG00000047849 MAP4      Inh_mega_eQTL    image_AD1     4.884397
# 20 3   ENSG00000047849 MAP4      Oli_mega_eQTL    image_AD1     4.840055
# 21 3   ENSG00000047849 MAP4      Oli_mega_eQTL    image_AD1     6.257958
# 22 3   ENSG00000047849 MAP4      Oli_mega_eQTL    image_AD1     5.392334
#    twas_pval    start    end      method  is_imputable is_selected_method
# 1  3.192988e-13 46680000 50320000 bayes_l TRUE         FALSE
# 2  2.196984e-13 46680000 50320000 bayes_r TRUE         FALSE
# 3  7.898584e-10 46680000 50320000 enet    TRUE         FALSE
# 4  4.068502e-07 46680000 50320000 lasso   TRUE         FALSE
# 5  1.888165e-14 46680000 50320000 mrash   TRUE          TRUE
# 6  1.919495e-08 46680000 50320000 susie   TRUE         FALSE
# 7  1.970694e-06 46680000 50320000 bayes_l TRUE         FALSE
# 8  1.065912e-06 46680000 50320000 mrash   TRUE         FALSE
# 9  1.894049e-08 46680000 50320000 mrash   TRUE         FALSE
# 10 6.280766e-07 46680000 50320000 bayes_l TRUE         FALSE
# 11 7.222462e-07 46680000 50320000 bayes_r TRUE         FALSE
# 12 3.592643e-07 46680000 50320000 enet    TRUE         FALSE
# 13 7.251069e-07 46680000 50320000 lasso   TRUE         FALSE
# 14 1.024763e-07 46680000 50320000 mrash   TRUE         FALSE
# 15 1.233456e-06 46680000 50320000 enet    TRUE         FALSE
# 16 3.536795e-07 46680000 50320000 lasso   TRUE         FALSE
# 17 4.966247e-08 46680000 50320000 mrash   TRUE         FALSE
# 18 1.448287e-09 46680000 50320000 susie   TRUE         FALSE
# 19 1.037456e-06 46680000 50320000 mrash   TRUE         FALSE
# 20 1.298034e-06 46680000 50320000 enet    TRUE         FALSE
# 21 3.900511e-10 46680000 50320000 mrash   TRUE          TRUE
# 22 6.954853e-08 46680000 50320000 susie   TRUE         FALSE
#    rsq_cv      pval_cv      type block
# 1  0.028812347 2.838190e-04 eQTL chr3_47545024_52179438
# 2  0.034630252 7.513862e-05 eQTL chr3_47545024_52179438
# 3  0.015255074 6.521214e-03 eQTL chr3_47545024_52179438
# 4  0.021811093 1.417804e-03 eQTL chr3_47545024_52179438
# 5  0.040646419 1.906382e-05 eQTL chr3_47545024_52179438
# 6  0.019468045 2.438679e-03 eQTL chr3_47545024_52179438
# 7  0.027958236 2.528632e-05 eQTL chr3_47545024_52179438
# 8  0.033292653 4.611121e-06 eQTL chr3_47545024_52179438
# 9  0.037883579 3.578416e-05 eQTL chr3_47545024_52179438
# 10 0.032996333 1.090900e-04 eQTL chr3_47545024_52179438
# 11 0.031071813 1.693008e-04 eQTL chr3_47545024_52179438
# 12 0.008152234 3.579311e-02 eQTL chr3_47545024_52179438
# 13 0.018880515 2.795204e-03 eQTL chr3_47545024_52179438
# 14 0.026046995 5.348648e-04 eQTL chr3_47545024_52179438
# 15 0.015255074 6.521214e-03 eQTL chr3_47545024_52179438
# 16 0.021811093 1.417804e-03 eQTL chr3_47545024_52179438
# 17 0.010531850 3.053342e-03 eQTL chr3_47545024_52179438
# 18 0.008060872 8.413149e-03 eQTL chr3_47545024_52179438
# 19 0.019372270 8.943163e-05 eQTL chr3_47545024_52179438
# 20 0.023262074 1.900464e-05 eQTL chr3_47545024_52179438
# 21 0.026141751 6.104250e-06 eQTL chr3_47545024_52179438
# 22 0.021674769 3.557730e-05 eQTL chr3_47545024_52179438

# %%
Aging_cilia_genes |> filter(gene_name == "SBSPON") |> group_by(gwas_study,context) |> 
  slice_min(twas_pval, n = 1, with_ties = FALSE) |> arrange(gwas_study)
# Out:
#   chr molecular_id    gene_name context         gwas_study   twas_z
# 1 8   ENSG00000164764 SBSPON    AC_DeJager_eQTL Telomere_pc1 -5.467477
# 2 8   ENSG00000164764 SBSPON    BM_10_MSBB_eQTL Telomere_pc1 -5.045952
# 3 8   ENSG00000164764 SBSPON    BM_22_MSBB_eQTL Telomere_pc1 -6.238929
# 4 8   ENSG00000164764 SBSPON    BM_36_MSBB_eQTL Telomere_pc1 -5.115528
# 5 8   ENSG00000164764 SBSPON    BM_44_MSBB_eQTL Telomere_pc1 -5.144548
#   twas_pval    start    end      method  is_imputable is_selected_method
# 1 4.564863e-08 72064543 75360000 lasso   TRUE         FALSE
# 2 4.512682e-07 72064543 75360000 mvsusie TRUE          TRUE
# 3 4.405764e-10 72064543 75360000 mrash   TRUE         FALSE
# 4 3.128648e-07 72064543 75360000 mrmash  TRUE         FALSE
# 5 2.681659e-07 72064543 75360000 mrmash  TRUE         FALSE
#   rsq_cv     pval_cv      type block
# 1 0.01692953 8.722582e-04 eQTL chr8_72924454_74340073
# 2 0.03933434 5.639342e-04 eQTL chr8_72924454_74340073
# 3 0.02250114 9.535052e-03 eQTL chr8_72924454_74340073
# 4 0.10937204 1.700039e-07 eQTL chr8_72924454_74340073
# 5 0.04732916 2.672000e-04 eQTL chr8_72924454_74340073

# %%
Aging_cilia_genes |> filter(gene_name == "NBEAL2") |> group_by(gwas_study,context) |> 
  slice_min(twas_pval, n = 1, with_ties = FALSE) |> arrange(gwas_study)
# Out:
#    chr molecular_id    gene_name
# 1  3   ENSG00000160796 NBEAL2
# 2  3   ENSG00000160796 NBEAL2
# 3  3   ENSG00000160796 NBEAL2
# 4  3   ENSG00000160796 NBEAL2
# 5  3   ENSG00000160796 NBEAL2
# 6  3   ENSG00000160796 NBEAL2
# 7  3   ENSG00000160796 NBEAL2
# 8  3   ENSG00000160796 NBEAL2
# 9  3   ENSG00000160796 NBEAL2
# 10 3   ENSG00000160796 NBEAL2
# 11 3   ENSG00000160796 NBEAL2
# 12 3   ENSG00000160796 NBEAL2
# 13 3   ENSG00000160796 NBEAL2
# 14 3   ENSG00000160796 NBEAL2
# 15 3   ENSG00000160796 NBEAL2
# 16 3   ENSG00000160796 NBEAL2
# 17 3   ENSG00000160796 NBEAL2
# 18 3   ENSG00000160796 NBEAL2
# 19 3   ENSG00000160796 NBEAL2
# 20 3   ENSG00000160796 NBEAL2
# 21 3   ENSG00000160796 NBEAL2
# 22 3   ENSG00000160796 NBEAL2
# 23 3   ENSG00000160796 NBEAL2
# 24 3   ENSG00000160796 NBEAL2
#    context
# 1  AC_DeJager_eQTL
# 2  Ast_DeJager_eQTL
# 3  BM_10_MSBB_eQTL
# 4  BM_22_MSBB_eQTL
# 5  BM_36_MSBB_eQTL
# 6  BM_44_MSBB_eQTL
# 7  DLPFC_DeJager_eQTL
# 8  Exc_DeJager_eQTL
# 9  PCC_DeJager_eQTL
# 10 monocyte_ROSMAP_eQTL
# 11 Ast_DeJager_eQTL
# 12 BM_10_MSBB_eQTL
# 13 BM_22_MSBB_eQTL
# 14 BM_36_MSBB_eQTL
# 15 BM_44_MSBB_eQTL
# 16 DLPFC_DeJager_eQTL
# 17 Exc_DeJager_eQTL
# 18 Knight_eQTL_brain
# 19 PCC_DeJager_eQTL
# 20 ROSMAP_AC_sQTL_chr3:46991946:46993936:clu_26458_+:PR:ENSG00000160796
# 21 ROSMAP_AC_sQTL_chr3:46992555:46993936:clu_26458_+:PR:ENSG00000160796
# 22 ROSMAP_PCC_sQTL_chr3:46991946:46992474:clu_24156_+:PR:ENSG00000160796
# 23 ROSMAP_PCC_sQTL_chr3:47001826:47002370:clu_24167_+:PR:ENSG00000160796
# 24 monocyte_ROSMAP_eQTL
#    gwas_study   twas_z    twas_pval    start    end      method  is_imputable
# 1  Telomere_pc1 -5.309631 1.098475e-07 44920000 50320000 mvsusie TRUE
# 2  Telomere_pc1 -5.955138 2.598529e-09 44920000 50320000 mvsusie TRUE
# 3  Telomere_pc1 -6.822076 8.973419e-12 44920000 50320000 bayes_r TRUE
# 4  Telomere_pc1 -8.122384 4.571131e-16 44920000 50320000 mrash   TRUE
# 5  Telomere_pc1 -5.753703 8.730952e-09 44920000 50320000 mrmash  TRUE
# 6  Telomere_pc1 -5.734923 9.755670e-09 44920000 50320000 mrmash  TRUE
# 7  Telomere_pc1 -5.877375 4.168234e-09 44920000 50320000 mvsusie TRUE
# 8  Telomere_pc1 -5.997272 2.006592e-09 44920000 50320000 mvsusie TRUE
# 9  Telomere_pc1 -5.925942 3.105121e-09 44920000 50320000 mvsusie TRUE
# 10 Telomere_pc1 -5.142328 2.713551e-07 44920000 50320000 mvsusie TRUE
# 11 image_AD1     4.910040 9.105798e-07 44920000 50320000 susie   TRUE
# 12 image_AD1     6.012605 1.825657e-09 44920000 50320000 susie   TRUE
# 13 image_AD1     5.591816 2.247070e-08 44920000 50320000 mrmash  TRUE
# 14 image_AD1     5.548720 2.877680e-08 44920000 50320000 mrmash  TRUE
# 15 image_AD1     5.584073 2.349504e-08 44920000 50320000 mrmash  TRUE
# 16 image_AD1     5.213350 1.854605e-07 44920000 50320000 susie   TRUE
# 17 image_AD1     5.130411 2.891098e-07 44920000 50320000 susie   TRUE
# 18 image_AD1     4.727699 2.270783e-06 44920000 50320000 susie   TRUE
# 19 image_AD1     5.060589 4.179640e-07 44920000 50320000 mvsusie TRUE
# 20 image_AD1     4.843384 1.276460e-06 44920000 50320000 susie   TRUE
# 21 image_AD1    -5.518619 3.416740e-08 44920000 50320000 lasso   TRUE
# 22 image_AD1    -4.734795 2.192768e-06 44920000 50320000 lasso   TRUE
# 23 image_AD1    -5.919732 3.224670e-09 44920000 50320000 susie   TRUE
# 24 image_AD1     5.358949 8.370749e-08 44920000 50320000 susie   TRUE
#    is_selected_method rsq_cv        pval_cv      type
# 1  FALSE               0.0431338826 1.998448e-07 eQTL
# 2  FALSE               0.0242582384 8.066948e-04 eQTL
# 3  FALSE               0.0266516394 3.898541e-03 eQTL
# 4  FALSE               0.0164383405 2.305086e-02 eQTL
# 5  FALSE               0.0561199187 1.701171e-04 eQTL
# 6  FALSE               0.0328128441 2.107196e-03 eQTL
# 7  FALSE               0.1062715421 4.360717e-21 eQTL
# 8  FALSE               0.0554986408 6.428909e-07 eQTL
# 9   TRUE               0.1094145490 6.113763e-13 eQTL
# 10  TRUE               0.0237263784 1.165661e-02 eQTL
# 11 FALSE              -0.0006565575 3.947568e-01 eQTL
# 12 FALSE              -0.0006897319 3.683760e-01 eQTL
# 13 FALSE               0.0522796502 1.401072e-04 eQTL
# 14 FALSE               0.0561199187 1.701171e-04 eQTL
# 15 FALSE               0.0328128441 2.107196e-03 eQTL
# 16 FALSE               0.0954231870 5.139071e-19 eQTL
# 17 FALSE               0.0303320662 2.004854e-04 eQTL
# 18 FALSE               0.0082450891 4.807576e-02 eQTL
# 19  TRUE               0.1094145490 6.113763e-13 eQTL
# 20  TRUE               0.0725334195 1.059432e-11 productive_sQTL
# 21 FALSE               0.0181769996 5.280045e-04 productive_sQTL
# 22 FALSE               0.0060548713 5.410396e-02 productive_sQTL
# 23 FALSE               0.0121792922 1.097587e-02 productive_sQTL
# 24 FALSE              -0.0011687937 3.914359e-01 eQTL
#    block
# 1  chr3_45108216_47545024
# 2  chr3_45108216_47545024
# 3  chr3_45108216_47545024
# 4  chr3_45108216_47545024
# 5  chr3_45108216_47545024
# 6  chr3_45108216_47545024
# 7  chr3_45108216_47545024
# 8  chr3_45108216_47545024
# 9  chr3_45108216_47545024
# 10 chr3_45108216_47545024
# 11 chr3_45108216_47545024
# 12 chr3_45108216_47545024
# 13 chr3_45108216_47545024
# 14 chr3_45108216_47545024
# 15 chr3_45108216_47545024
# 16 chr3_45108216_47545024
# 17 chr3_45108216_47545024
# 18 chr3_45108216_47545024
# 19 chr3_45108216_47545024
# 20 chr3_45108216_47545024
# 21 chr3_45108216_47545024
# 22 chr3_45108216_47545024
# 23 chr3_45108216_47545024
# 24 chr3_45108216_47545024

# %%
Aging_cilia_genes_selected = Aging_cilia_genes |> filter(gene_name %in% c("CBY1", "MAP4", "KIF9", "SETD2", "MON1A"))#, "PLXNB1"
   
Aging_cilia_genes_selected = Aging_cilia_genes_selected |> mutate(gwas_study = ifelse(grepl("Bellenguez|Wightman|Jansen", gwas_study), "AD", gwas_study)) |>
  group_by(gwas_study,context) |> 
  slice_min(twas_pval, n = 1, with_ties = FALSE) |> arrange(gene_name, gwas_study, context)

# %%
plot_data <- Aging_cilia_genes_selected %>%
    mutate(
      # Calculate -log10(bonferroni p-value)
      neg_log_twas_pval = -log10(twas_pval),
      # Create color factor based on twas_z sign
      twas_z_sign = ifelse(twas_z < 0, "Negative", "Positive"),
      # Clean up context names for better display (optional)
      context = str_replace(context, 
                               "^(.+?_sQTL)[^:]*:.*:(clu_\\d+_\\+):([A-Z]+):.*$", 
                               "\\1:\\2:\\3"),
      gwas_study = ifelse(grepl("Jansen|Bellenguez|Wightman", gwas_study), "AD", gwas_study))
plot_data = plot_data[-nrow(plot_data),]
plot_data |> arrange(gene_name, gwas_study, context)
# Out:
#    chr molecular_id    gene_name context                    gwas_study
# 1  22  ENSG00000100211 CBY1      DLPFC_DeJager_eQTL         AD
# 2  22  ENSG00000100211 CBY1      Exc_DeJager_eQTL           AD
# 3  22  ENSG00000100211 CBY1      BM_22_MSBB_eQTL            Telomere_pc1
# 4  22  ENSG00000100211 CBY1      BM_44_MSBB_eQTL            Telomere_pc1
# 5  22  ENSG00000100211 CBY1      DLPFC_DeJager_eQTL         Telomere_pc1
# 6  22  ENSG00000100211 CBY1      Inh_DeJager_eQTL           Telomere_pc1
# 7  22  ENSG00000100211 CBY1      Inh_mega_eQTL              Telomere_pc1
# 8  22  ENSG00000100211 CBY1      Oli_mega_eQTL              Telomere_pc1
# 9   3  ENSG00000088727 KIF9      AC_DeJager_eQTL            Telomere_pc1
# 10  3  ENSG00000088727 KIF9      BM_10_MSBB_eQTL            Telomere_pc1
# 11  3  ENSG00000088727 KIF9      Exc_DeJager_eQTL           Telomere_pc1
# 12  3  ENSG00000088727 KIF9      AC_DeJager_eQTL            image_AD1
# 13  3  ENSG00000088727 KIF9      BM_10_MSBB_eQTL            image_AD1
# 14  3  ENSG00000088727 KIF9      PCC_DeJager_eQTL           image_AD1
# 15  3  ENSG00000047849 MAP4      Oli_DeJager_eQTL           Telomere_pc1
# 16  3  ENSG00000047849 MAP4      Ast_DeJager_eQTL           image_AD1
# 17  3  ENSG00000047849 MAP4      Exc_mega_eQTL              image_AD1
# 18  3  ENSG00000047849 MAP4      Inh_DeJager_eQTL           image_AD1
# 19  3  ENSG00000047849 MAP4      Inh_mega_eQTL              image_AD1
# 20  3  ENSG00000047849 MAP4      Oli_DeJager_eQTL           image_AD1
# 21  3  ENSG00000047849 MAP4      Oli_mega_eQTL              image_AD1
# 22  3  ENSG00000164077 MON1A     Ast_DeJager_eQTL           Telomere_pc1
# 23  3  ENSG00000164077 MON1A     Exc_mega_eQTL              Telomere_pc1
# 24  3  ENSG00000164077 MON1A     MSBB_BM36_pQTL_chr3_Q86VX9 Telomere_pc1
# 25  3  ENSG00000164077 MON1A     PCC_DeJager_eQTL           Telomere_pc1
# 26  3  ENSG00000164077 MON1A     DLPFC_DeJager_eQTL         image_AD1
# 27  3  ENSG00000181555 SETD2     MSBB_BM36_pQTL_chr3_Q9BYW2 Telomere_pc1
# 28  3  ENSG00000181555 SETD2     Ast_mega_eQTL              image_AD1
# 29  3  ENSG00000181555 SETD2     Exc_DeJager_eQTL           image_AD1
# 30  3  ENSG00000181555 SETD2     Mic_DeJager_eQTL           image_AD1
#    twas_z    twas_pval    start    end      method  is_imputable
# 1   4.725888 2.291120e-06 38656638 38656639 bayes_l TRUE
# 2   4.996974 5.823702e-07 38656638 38656639 bayes_l TRUE
# 3  -6.118423 9.450584e-10 37520000 41680000 mrmash  TRUE
# 4  -6.028541 1.654467e-09 37520000 41680000 mrmash  TRUE
# 5  -5.584899 2.338354e-08 37520000 41680000 lasso   TRUE
# 6  -5.604643 2.086844e-08 37520000 41680000 enet    TRUE
# 7  -5.995605 2.027294e-09 37520000 41680000 lasso   TRUE
# 8  -4.797165 1.609271e-06 37520000 41680000 susie   TRUE
# 9   4.895271 9.817032e-07 44920000 50320000 mrmash  TRUE
# 21  TRUE               0.026141751 6.104250e-06 eQTL chr3_47545024_52179438
# 22 FALSE              -0.001127958 4.674169e-01 eQTL chr3_47545024_52179438
# 23  TRUE               0.018053114 1.493944e-04 eQTL chr3_47545024_52179438
# 24 FALSE               0.039661873 3.878333e-03 pQTL chr3_47545024_52179438
# 25 FALSE               0.010725879 1.671134e-02 eQTL chr3_47545024_52179438
# 26 FALSE               0.022182207 1.673120e-05 eQTL chr3_47545024_52179438
# 27 FALSE               0.057712720 5.974115e-04 pQTL chr3_45108216_47545024
# 28  TRUE               0.014175862 7.014767e-04 eQTL chr3_45108216_47545024
# 29 FALSE               0.012724253 1.186269e-02 eQTL chr3_45108216_47545024
# 30 FALSE               0.006915071 4.863974e-02 eQTL chr3_45108216_47545024
#    neg_log_twas_pval twas_z_sign
# 1   5.639952         Positive
# 2   6.234801         Positive
# 3   9.024541         Negative
# 4   8.781342         Negative
# 5   7.631090         Negative
# 6   7.680510         Negative
# 7   8.693083         Negative
# 8   5.793371         Negative
# 9   6.008020         Positive
# 10  6.723241         Positive
# 11  9.636608         Positive
# 12  6.547489         Negative
# 13  7.926659         Negative
# 14  7.739633         Negative
# 15 13.723960         Negative
# 16  7.722609         Positive
# 17  8.839145         Positive
# 18  6.989376         Positive
# 19  5.984030         Positive
# 20  6.451390         Positive
# 21  9.408879         Positive
# 22  6.683256         Negative
# 23 12.794641         Negative
# 24  7.378114         Positive
# 25 22.055874         Positive
# 26  6.835486         Positive
# 27  6.243279         Negative
# 28  8.624046         Positive
# 29 11.409393         Positive
# 30 12.549064         Positive

# %%
library(ggplot2)
library(dplyr)
library(ggrepel)

# --- Process data ---
plot_data_processed <- plot_data %>%
  ungroup() %>%
  mutate(
    # Extract cell type from context
    cell_type = case_when(
      grepl("Exc", context) ~ "Exc",
      grepl("Inh", context) ~ "Inh",
      grepl("Mic", context) ~ "Mic",
      grepl("OPC", context) ~ "OPC",
      grepl("Oli", context) ~ "Oli",
      grepl("monocyte", context) ~ "monocyte",
      TRUE ~ "bulk"
    ),
    # Extract QTL type from context
    qtl_type = case_when(
      grepl("eQTL", context) ~ "eQTL",
      grepl("pQTL", context) ~ "pQTL",
      TRUE ~ "other"
    ),
    # Extract cohort from context
    cohort = case_when(
      grepl("PCC", context) ~ "PCC",
      grepl("AC", context) ~ "AC",
      grepl("DLPFC", context) ~ "DLPFC",
      grepl("Knight", context) ~ "Knight",
      grepl("MSBB", context) ~ "MSBB",
      grepl("ROSMAP", context) ~ "ROSMAP",
      grepl("DeJager", context) ~ "DeJager",
      grepl("mega", context) ~ "mega",
      TRUE ~ "Unknown"
    ),
    gwas_study = case_when(
        startsWith(gwas_study, "image_") ~ paste0("i", substr(gwas_study, 7, nchar(gwas_study))),
        gwas_study == "Telomere_pc1" ~ "Telomere length",
        TRUE ~ gwas_study
    ),
    # Create combined label for cell type and QTL
    cell_qtl_label = paste0(cell_type, "_", qtl_type)
  )

# Fixed order for x-axis contexts
xqtl_context_order <- plot_data_processed %>%
  select(cell_qtl_label, cell_type, qtl_type) %>%
  distinct() %>%
  arrange(cell_type != "bulk",
          factor(cell_type, levels = c("Exc","Inh","Mic","Oli","OPC","monocyte","bulk")),
          qtl_type) %>%
  pull(cell_qtl_label)

# Create x-position within each GWAS-gene combination
plot_data_processed <- plot_data_processed %>%
  mutate(
    gene_cell_qtl = paste0(gene_name, "_", cell_qtl_label),
    cell_qtl_label = factor(cell_qtl_label, levels = xqtl_context_order)
  ) %>%
  group_by(gwas_study, gene_name) %>%
  mutate(gene_order = cur_group_id()) %>%
  ungroup() %>%
  arrange(gwas_study, gene_name, cell_qtl_label) %>%
  mutate(x_position = as.numeric(interaction(gwas_study, gene_name, cell_qtl_label, 
                                              drop = TRUE, lex.order = TRUE)))

# Calculate width metrics for flexible panel sizing
gwas_panel_widths <- plot_data_processed %>%
  group_by(gwas_study) %>%
  summarise(
    n_genes = n_distinct(gene_name),
    n_cell_qtl = n_distinct(cell_qtl_label),
    n_combinations = n_distinct(gene_name, cell_qtl_label),
    .groups = "drop"
  ) %>%
  mutate(
    panel_width = n_combinations * 0.8 + n_genes * 1.0,
    width_ratio = panel_width / sum(panel_width)
  )

# Calculate gene boundaries for rectangles within each GWAS study
gene_boundaries <- plot_data_processed %>%
  group_by(gwas_study, gene_name) %>%
  summarise(
    xmin = min(x_position) - 0.5,
    xmax = max(x_position) + 0.5,
    .groups = "drop"
  )

# Compute gene label positions
gene_positions <- plot_data_processed %>%
  group_by(gwas_study, gene_name) %>%
  summarise(
    xpos = mean(x_position),
    .groups = "drop"
  )

# Get max y value for positioning gene labels
max_y <- max(-log10(plot_data_processed$twas_pval), na.rm = TRUE)

# ---- Build dot plot with facets ----
p_combined <- ggplot(plot_data_processed,
                     aes(x = x_position, y = neg_log_twas_pval, color = twas_z_sign)) +
  # Add gene grouping rectangles
  geom_rect(
    data = gene_boundaries,
    aes(xmin = xmin, xmax = xmax, ymin = -Inf, ymax = Inf),
    fill = NA, color = "gray30", linewidth = 1,
    inherit.aes = FALSE
  ) +
  # Main data points
  geom_point(size = 2.5, alpha = 0.8) +
  # Add cohort labels with repel to avoid overlap
  geom_text_repel(
    aes(label = cohort),
    size = 2.5,
    fontface = "bold",
    color = "black",
    box.padding = 0.35,
    point.padding = 0.3,
    segment.color = "grey50",
    segment.size = 0.3,
    max.overlaps = 30,
    min.segment.length = 0,
    direction = "both",
    seed = 123,
    force = 2,
    force_pull = 0.5
  ) +
  # Significance threshold line
  geom_hline(yintercept = -log10(2.5e-6), linetype = "dashed", color = "red", linewidth = 0.8) +
  # Facet by GWAS study with square boxes
  facet_wrap(~gwas_study, scales = "free_x", nrow = 1, strip.position = "top") +
  # Color scheme for Z-score direction
  scale_color_manual(
    values = c("Positive" = "#E74C3C", "Negative" = "#3498DB"),
    name = "TWAS Z-score",
    labels = c("Negative" = "Negative (↓)", "Positive" = "Positive (↑)")
  ) +
  # X-axis with context labels
  scale_x_continuous(
    breaks = plot_data_processed$x_position,
    labels = plot_data_processed$cell_qtl_label
  ) +
  # Styling
  theme_bw(base_size = 14) +
  theme(
    # Square facet boxes
    strip.background = element_rect(color = "black", fill = "white", linewidth = 1.2),
    strip.text = element_text(face = "bold", size = 14),
    axis.text.x = element_text(angle = 45, hjust = 1, size = 10, face = "bold"),
    axis.title.x = element_blank(),
    panel.grid.major.x = element_blank(),
    panel.spacing = unit(0.5, "lines"),
    legend.position = "bottom",
    plot.margin = margin(10, 10, 10, 10),
    plot.title = element_text(size = 16, face = "bold", hjust = 0.5, margin = margin(b = 15))
  ) +
  labs(
    title = "TWAS Results for Genes Involved in Microtubule-Mediated Aging & AD Pathology",
    y = bquote(-log[10]~italic(p)),
    color = "TWAS Z-score"
  ) +
  # Annotate gene names above each group
  geom_text(
    data = gene_positions,
    aes(x = xpos, y = max_y * 1.25, label = gene_name),
    inherit.aes = FALSE,
    size = 4,
    fontface = "bold.italic",
    vjust = 0
  ) +
  coord_cartesian(clip = "off", ylim = c(0, max_y * 1.35))

print(p_combined)

# Calculate optimal total width based on content
total_width <- max(25, sum(gwas_panel_widths$panel_width) + 3)

ggsave("structural_gene_plot_by_gwas_cilia.png", p_combined,
       width = total_width, height = 9, dpi = 300, bg = "white")

# Print width information
print(gwas_panel_widths)
cat("\nTotal plot width:", total_width, "inches\n")
cat("\nWidth breakdown:\n")
for(i in 1:nrow(gwas_panel_widths)) {
  cat(sprintf("  %s: %.1f inches (%.1f%% of total)\n", 
              gwas_panel_widths$gwas_study[i],
              gwas_panel_widths$panel_width[i],
              gwas_panel_widths$width_ratio[i] * 100))
}
# Out:
# # A tibble: 3 × 6
#   gwas_study   n_genes n_cell_qtl n_combinations panel_width width_ratio
#   <chr>          <int>      <int>          <int>       <dbl>       <dbl>
# 1 AD                 1          2              2         2.6      0.0970
# 2 Telomere_pc1       5          5             10        13        0.485
# 3 image_AD1          4          5              9        11.2      0.418
#
# Total plot width: 29.8 inches
#
# Width breakdown:
#   AD: 2.6 inches (9.7% of total)
#   Telomere_pc1: 13.0 inches (48.5% of total)
#   image_AD1: 11.2 inches (41.8% of total)
# plot without title

# %%
ggsave("TL1_AD1_twas_all_contexts.png", p_gene_grouped_cilia, width = 15, height = 8, dpi = 300)

# %%
MON1A = fread("~/twas/PD/twas/PD_ROSMAP_eQTL_pQTL.chr3_47545024_52179438.twas.tsv.gz")
head(MON1A)
# Out:
#   chr molecular_id    TSS      start    end      context          gwas_study
# 1 3   ENSG00000003756 50088918 46680000 51119021 OPC_DeJager_eQTL PD
# 2 3   ENSG00000003756 50088918 46680000 51119021 OPC_DeJager_eQTL PD
# 3 3   ENSG00000003756 50088918 46680000 51119021 OPC_DeJager_eQTL PD
# 4 3   ENSG00000003756 50088918 46680000 51119021 OPC_DeJager_eQTL PD
# 5 3   ENSG00000003756 50088918 46680000 51119021 OPC_DeJager_eQTL PD
# 6 3   ENSG00000003756 50088918 46680000 51119021 OPC_DeJager_eQTL PD
#   method  is_imputable is_selected_method rsq_cv        pval_cv    twas_z
# 1 bayes_l TRUE         FALSE               5.320439e-03 0.07300417 -2.168569
# 2 bayes_r TRUE         FALSE               2.577772e-03 0.15021668 -2.116990
# 3 enet    TRUE         FALSE               2.752461e-03 0.14323778 -2.337244
# 4 lasso   TRUE          TRUE               2.010636e-02 0.00212657        NA
# 5 mrash   TRUE         FALSE              -5.683165e-05 0.32368770 -1.521102
# 6 susie   TRUE         FALSE               8.107353e-04 0.24798886 -1.291580
#   twas_pval  type block
# 1 0.03011539 eQTL chr3_47545024_52179438
# 2 0.03426066 eQTL chr3_47545024_52179438
# 3 0.01942651 eQTL chr3_47545024_52179438
# 4         NA eQTL chr3_47545024_52179438
# 5 0.12823414 eQTL chr3_47545024_52179438
# 6 0.19650259 eQTL chr3_47545024_52179438

# %%
MON1A |> filter(molecular_id == "ENSG00000164077")
# Out:
#    chr molecular_id    TSS      start    end      context            gwas_study
# 1  3   ENSG00000164077 49930172 46680000 50930173 Ast_DeJager_eQTL   PD
# 2  3   ENSG00000164077 49930172 46680000 50930173 Ast_DeJager_eQTL   PD
# 3  3   ENSG00000164077 49930172 46680000 50930173 Ast_DeJager_eQTL   PD
# 4  3   ENSG00000164077 49930172 46680000 50930173 Ast_DeJager_eQTL   PD
# 5  3   ENSG00000164077 49930172 46680000 50930173 Ast_DeJager_eQTL   PD
# 6  3   ENSG00000164077 49930172 46680000 50930173 Ast_DeJager_eQTL   PD
# 7  3   ENSG00000164077 49930172 46680000 50930173 DLPFC_DeJager_eQTL PD
# 8  3   ENSG00000164077 49930172 46680000 50930173 DLPFC_DeJager_eQTL PD
# 9  3   ENSG00000164077 49930172 46680000 50930173 DLPFC_DeJager_eQTL PD
# 10 3   ENSG00000164077 49930172 46680000 50930173 DLPFC_DeJager_eQTL PD
# 11 3   ENSG00000164077 49930172 46680000 50930173 DLPFC_DeJager_eQTL PD
# 12 3   ENSG00000164077 49930172 46680000 50930173 DLPFC_DeJager_eQTL PD
# 13 3   ENSG00000164077 49930172 46680000 50930173 DLPFC_DeJager_eQTL PD
# 14 3   ENSG00000164077 49930172 46680000 50930173 DLPFC_DeJager_eQTL PD
# 15 3   ENSG00000164077 49930172 46680000 50930173 PCC_DeJager_eQTL   PD
# 16 3   ENSG00000164077 49930172 46680000 50930173 PCC_DeJager_eQTL   PD
# 17 3   ENSG00000164077 49930172 46680000 50930173 PCC_DeJager_eQTL   PD
# 18 3   ENSG00000164077 49930172 46680000 50930173 PCC_DeJager_eQTL   PD
# 19 3   ENSG00000164077 49930172 46680000 50930173 PCC_DeJager_eQTL   PD
# 20 3   ENSG00000164077 49930172 46680000 50930173 PCC_DeJager_eQTL   PD
# 21 3   ENSG00000164077 49930172 46680000 50930173 PCC_DeJager_eQTL   PD
# 22 3   ENSG00000164077 49930172 46680000 50930173 PCC_DeJager_eQTL   PD
#    method  is_imputable is_selected_method rsq_cv        pval_cv
# 1  bayes_l TRUE         FALSE              -0.0011279582 4.674169e-01
# 2  bayes_r TRUE         FALSE               0.0001086653 3.071554e-01
# 3  enet    TRUE         FALSE              -0.0019895694 6.803137e-01
# 4  lasso   TRUE         FALSE              -0.0007003522 4.007712e-01
# 5  mrash   TRUE         FALSE               0.0097023998 2.450691e-02
# 6  susie   TRUE          TRUE               0.0106883314 1.930949e-02
# 7  bayes_l TRUE         FALSE               0.0221822070 1.673120e-05
# 8  bayes_r TRUE         FALSE               0.0208942113 2.872207e-05
# 9  enet    TRUE         FALSE               0.0123236285 1.077463e-03
# 10 lasso   TRUE         FALSE               0.0113818396 1.613179e-03
# 11 mrash   TRUE          TRUE               0.0236427262 9.072144e-06
# 12 mrmash  TRUE         FALSE               0.0193722676 5.444375e-05
# 13 mvsusie TRUE         FALSE               0.0180405618 9.537283e-05
# 14 susie   TRUE         FALSE               0.0167923236 1.614811e-04
# 15 bayes_l TRUE         FALSE               0.0119084484 1.241279e-02
# 16 bayes_r TRUE         FALSE               0.0079644615 3.381308e-02
# 17 enet    TRUE         FALSE               0.0107258788 1.671134e-02
# 18 lasso   TRUE         FALSE               0.0182526594 2.590587e-03
# 19 mrash   TRUE         FALSE               0.0162064946 4.276518e-03
# 20 mrmash  TRUE         FALSE               0.0143372104 6.780884e-03
# 21 mvsusie TRUE         FALSE               0.0117927951 1.277784e-02
# 22 susie   TRUE          TRUE               0.0351667970 4.387078e-05
#    twas_z     twas_pval  type block
# 1   2.1792448 0.02931349 eQTL chr3_47545024_52179438
# 2   1.7005227 0.08903265 eQTL chr3_47545024_52179438
# 3   0.2025420 0.83949305 eQTL chr3_47545024_52179438
# 4   0.6469728 0.51764957 eQTL chr3_47545024_52179438
# 5   1.4610728 0.14399546 eQTL chr3_47545024_52179438
# 6          NA         NA eQTL chr3_47545024_52179438
# 7  -1.0993884 0.27159871 eQTL chr3_47545024_52179438
# 8  -1.0752733 0.28225239 eQTL chr3_47545024_52179438
# 9  -1.1941061 0.23243645 eQTL chr3_47545024_52179438
# 10 -1.3829182 0.16668994 eQTL chr3_47545024_52179438
# 11 -1.1235848 0.26118921 eQTL chr3_47545024_52179438
# 12 -0.8176145 0.41357734 eQTL chr3_47545024_52179438
# 13 -0.4603219 0.64528521 eQTL chr3_47545024_52179438
# 14 -0.4695839 0.63865233 eQTL chr3_47545024_52179438
# 15  0.9981821 0.31819106 eQTL chr3_47545024_52179438
# 16  1.1071967 0.26820888 eQTL chr3_47545024_52179438
# 17 -1.1585177 0.24665282 eQTL chr3_47545024_52179438
# 18 -0.7343209 0.46275319 eQTL chr3_47545024_52179438
# 19  0.7185088 0.47244363 eQTL chr3_47545024_52179438
# 20 -0.8113675 0.41715464 eQTL chr3_47545024_52179438
# 21 -0.5436654 0.58667172 eQTL chr3_47545024_52179438
# 22 -1.1147604 0.26495311 eQTL chr3_47545024_52179438

# %%
TL1_Aging3_genes = annotated_all |> filter(gene_name %in% c("DNAJC5", "TRIM26", "USP19", "GGT7"), twas_pval < 2.5* 1e-6)# , is_selected_method

# %%
AD_Aging3_BIN1 = annotated_all |> mutate(gwas_study = ifelse(grepl("Jansen|Bellenguez|Wightman|Kunkle", gwas_study), "AD", gwas_study)) |> filter(gene_name %in% c("BIN1"), twas_pval < 2.5* 1e-6, is_selected_method, type == "eQTL") |>
  group_by(gwas_study, context) |> 
  slice_min(twas_pval, n = 1, with_ties = FALSE)

# %%
AD_Aging3_BIN1
# Out:
#   chr molecular_id    gene_name context            gwas_study   twas_z
# 1 2   ENSG00000136717 BIN1      AC_DeJager_eQTL    AD            6.216229
# 2 2   ENSG00000136717 BIN1      BM_22_MSBB_eQTL    AD            8.440799
# 3 2   ENSG00000136717 BIN1      DLPFC_DeJager_eQTL AD            7.920283
# 4 2   ENSG00000136717 BIN1      Exc_DeJager_eQTL   AD           -8.083012
# 5 2   ENSG00000136717 BIN1      Exc_mega_eQTL      AD           -8.290510
# 6 2   ENSG00000136717 BIN1      Mic_DeJager_eQTL   AD           17.729812
# 7 2   ENSG00000136717 BIN1      Mic_mega_eQTL      AD           18.636256
# 8 2   ENSG00000136717 BIN1      PCC_DeJager_eQTL   AD            6.510411
# 9 2   ENSG00000136717 BIN1      Inh_mega_eQTL      image_Aging3 -5.120803
#   twas_pval    start     end       method  is_imputable is_selected_method
# 1 5.092445e-10 127107286 127107287 mrmash  TRUE         TRUE
# 2 3.151770e-17 127107286 127107287 bayes_r TRUE         TRUE
# 3 2.369711e-15 127107286 127107287 mrmash  TRUE         TRUE
# 4 6.318623e-16 127107286 127107287 susie   TRUE         TRUE
# 5 1.127637e-16 127107286 127107287 susie   TRUE         TRUE
# 6 2.468593e-70 127107286 127107287 enet    TRUE         TRUE
# 7 1.632764e-77 127107286 127107287 lasso   TRUE         TRUE
# 8 7.494538e-11 127107286 127107287 mvsusie TRUE         TRUE
# 9 3.042369e-07 123880000 130720000 susie   TRUE         TRUE
#   rsq_cv     pval_cv      type block
# 1 0.19571938 8.224948e-30 eQTL chr2_125689597_127728648
# 2 0.03588728 2.431204e-03 eQTL chr2_125689597_127728648
# 3 0.01537103 5.026650e-04 eQTL chr2_125689597_127728648
# 4 0.06894663 4.903809e-08 eQTL chr2_125689597_127728648
# 5 0.05747339 2.576670e-11 eQTL chr2_125689597_127728648
# 6 0.12440855 1.016340e-13 eQTL chr2_125689597_127728648
# 7 0.17808999 3.102759e-33 eQTL chr2_125689597_127728648
# 8 0.06020555 1.807796e-07 eQTL chr2_125689597_127728648
# 9 0.01386351 8.011005e-04 eQTL chr2_125689597_127728648

# %%
TL1_Aging3_genes = bind_rows(AD_Aging3_BIN1, TL1_Aging3_genes)
TL1_Aging3_genes|> arrange(gene_name, gwas_study, context)
# Out:
#     chr molecular_id    gene_name context                    gwas_study
# 1    2  ENSG00000136717 BIN1      AC_DeJager_eQTL            AD
# 2    2  ENSG00000136717 BIN1      BM_22_MSBB_eQTL            AD
# 3    2  ENSG00000136717 BIN1      DLPFC_DeJager_eQTL         AD
# 4    2  ENSG00000136717 BIN1      Exc_DeJager_eQTL           AD
# 5    2  ENSG00000136717 BIN1      Exc_mega_eQTL              AD
# 6    2  ENSG00000136717 BIN1      Mic_DeJager_eQTL           AD
# 7    2  ENSG00000136717 BIN1      Mic_mega_eQTL              AD
# 8    2  ENSG00000136717 BIN1      PCC_DeJager_eQTL           AD
# 9    2  ENSG00000136717 BIN1      Inh_mega_eQTL              image_Aging3
# 10  20  ENSG00000101152 DNAJC5    BM_36_MSBB_eQTL            Telomere_pc1
# 11  20  ENSG00000101152 DNAJC5    BM_36_MSBB_eQTL            Telomere_pc1
# 12  20  ENSG00000101152 DNAJC5    BM_36_MSBB_eQTL            Telomere_pc1
# 13  20  ENSG00000101152 DNAJC5    Exc_mega_eQTL              Telomere_pc1
# 14  20  ENSG00000101152 DNAJC5    Exc_mega_eQTL              Telomere_pc1
# 15  20  ENSG00000101152 DNAJC5    Exc_mega_eQTL              Telomere_pc1
# 16  20  ENSG00000101152 DNAJC5    Exc_mega_eQTL              Telomere_pc1
# 17  20  ENSG00000101152 DNAJC5    Knight_eQTL_brain          Telomere_pc1
# 18  20  ENSG00000101152 DNAJC5    Mic_mega_eQTL              Telomere_pc1
# 19  20  ENSG00000101152 DNAJC5    Mic_mega_eQTL              Telomere_pc1
# 20  20  ENSG00000101152 DNAJC5    OPC_mega_eQTL              Telomere_pc1
# 21  20  ENSG00000101152 DNAJC5    Oli_DeJager_eQTL           Telomere_pc1
# 22  20  ENSG00000101152 DNAJC5    Oli_DeJager_eQTL           Telomere_pc1
# 23  20  ENSG00000101152 DNAJC5    Oli_DeJager_eQTL           Telomere_pc1
# 24  20  ENSG00000101152 DNAJC5    Oli_DeJager_eQTL           Telomere_pc1
# 25  20  ENSG00000101152 DNAJC5    Oli_DeJager_eQTL           Telomere_pc1
# 26  20  ENSG00000101152 DNAJC5    Oli_DeJager_eQTL           Telomere_pc1
# 27  20  ENSG00000101152 DNAJC5    Oli_DeJager_eQTL           Telomere_pc1
# 28  20  ENSG00000101152 DNAJC5    Oli_DeJager_eQTL           Telomere_pc1
# 29  20  ENSG00000101152 DNAJC5    Oli_mega_eQTL              Telomere_pc1
# 30  20  ENSG00000101152 DNAJC5    Oli_mega_eQTL              Telomere_pc1
# ⋮   ⋮   ⋮               ⋮         ⋮                          ⋮
# 82  6   ENSG00000234127 TRIM26    Oli_mega_eQTL              Telomere_pc1
# 83  6   ENSG00000234127 TRIM26    Oli_mega_eQTL              Telomere_pc1
# 84  6   ENSG00000234127 TRIM26    AC_DeJager_eQTL            image_AD2
# 85  6   ENSG00000234127 TRIM26    AC_DeJager_eQTL            image_AD2
# 86  6   ENSG00000234127 TRIM26    AC_DeJager_eQTL            image_AD2
# 87  6   ENSG00000234127 TRIM26    AC_DeJager_eQTL            image_AD2
# 88  6   ENSG00000234127 TRIM26    AC_DeJager_eQTL            image_AD2
# 89  6   ENSG00000234127 TRIM26    DLPFC_DeJager_eQTL         image_AD2
# 90  6   ENSG00000234127 TRIM26    DLPFC_DeJager_eQTL         image_AD2
# 91  6   ENSG00000234127 TRIM26    DLPFC_DeJager_eQTL         image_AD2
# 92  6   ENSG00000234127 TRIM26    Knight_eQTL_brain          image_AD2
# 93  6   ENSG00000234127 TRIM26    PCC_DeJager_eQTL           image_AD2
# 94  6   ENSG00000234127 TRIM26    PCC_DeJager_eQTL           image_AD2
# 95  6   ENSG00000234127 TRIM26    Oli_DeJager_eQTL           image_Aging3
# 96  6   ENSG00000234127 TRIM26    Oli_DeJager_eQTL           image_Aging3
# 97  6   ENSG00000234127 TRIM26    Oli_DeJager_eQTL           image_Aging3
# 98  6   ENSG00000234127 TRIM26    AC_DeJager_eQTL            image_Aging5
# 99  6   ENSG00000234127 TRIM26    AC_DeJager_eQTL            image_Aging5
# 100 6   ENSG00000234127 TRIM26    AC_DeJager_eQTL            image_Aging5
# 101 6   ENSG00000234127 TRIM26    DLPFC_DeJager_eQTL         image_Aging5
# 102 6   ENSG00000234127 TRIM26    PCC_DeJager_eQTL           image_Aging5
# 103 3   ENSG00000172046 USP19     BM_44_MSBB_eQTL            Telomere_pc1
# 104 3   ENSG00000172046 USP19     MSBB_BM36_pQTL_chr3_O94966 Telomere_pc1
# 105 3   ENSG00000172046 USP19     MSBB_BM36_pQTL_chr3_O94966 Telomere_pc1
# 106 3   ENSG00000172046 USP19     monocyte_ROSMAP_eQTL       Telomere_pc1
# 107 3   ENSG00000172046 USP19     monocyte_ROSMAP_eQTL       Telomere_pc1
# 108 3   ENSG00000172046 USP19     monocyte_ROSMAP_eQTL       Telomere_pc1
# 109 3   ENSG00000172046 USP19     monocyte_ROSMAP_eQTL       image_AD1
# 110 3   ENSG00000172046 USP19     monocyte_ROSMAP_eQTL       image_AD1
# 111 3   ENSG00000172046 USP19     monocyte_ROSMAP_eQTL       image_AD1
#     twas_z     twas_pval    start     end       method  is_imputable
# 1     6.216229 5.092445e-10 127107286 127107287 mrmash  TRUE
# 2     8.440799 3.151770e-17 127107286 127107287 bayes_r TRUE
# 3     7.920283 2.369711e-15 127107286 127107287 mrmash  TRUE
# 4    -8.083012 6.318623e-16 127107286 127107287 susie   TRUE
# 5    -8.290510 1.127637e-16 127107286 127107287 susie   TRUE
# 6    17.729812 2.468593e-70 127107286 127107287 enet    TRUE
# 7    18.636256 1.632764e-77 127107286 127107287 lasso   TRUE
# 8     6.510411 7.494538e-11 127107286 127107287 mvsusie TRUE
# 9    -5.120803 3.042369e-07 123880000 130720000 susie   TRUE
# 10    8.616714 6.890273e-18  59520000  64444167 bayes_l TRUE
# 11    8.256135 1.504655e-16  59520000  64444167 bayes_r TRUE
# 12    6.593224 4.303762e-11  59520000  64444167 mrash   TRUE
# 13   -8.585080 9.077341e-18  59520000  64444167 enet    TRUE
# 14   -9.603149 7.753826e-22  59520000  64444167 lasso   TRUE
# 15  -10.149955 3.315162e-24  59520000  64444167 mrash   TRUE
# 16   -5.310365 1.094056e-07  59520000  64444167 susie   TRUE
# 17    5.044622 4.544199e-07  59520000  64444167 mrash   TRUE
# 18   -5.713537 1.106519e-08  59520000  64444167 enet    TRUE
# 19   -5.165920 2.392594e-07  59520000  64444167 lasso   TRUE
# 20    9.894008 4.419709e-23  59520000  64444167 lasso   TRUE
# 21   -7.669874 1.721658e-14  59520000  64444167 bayes_l TRUE
# 22  -10.361215 3.722041e-25  59520000  64444167 bayes_r TRUE
# 23  -10.221956 1.581174e-24  59520000  64444167 enet    TRUE
# 24   -8.838855 9.670442e-19  59520000  64444167 lasso   TRUE
# 25  -13.091735 3.671238e-39  59520000  64444167 mrash   TRUE
# 26   -7.485073 7.150734e-14  59520000  64444167 mrmash  TRUE
# 27   -7.395422 1.409603e-13  59520000  64444167 mvsusie TRUE
# 28   -8.145739 3.769716e-16  59520000  64444167 susie   TRUE
# 29   -8.436479 3.270391e-17  59520000  64444167 enet    TRUE
# 30   -8.419436 3.782994e-17  59520000  64444167 lasso   TRUE
# ⋮   ⋮          ⋮            ⋮         ⋮         ⋮       ⋮
# 82   8.542948  1.308399e-17 25960000  33560000  mrash   TRUE
# 83   6.151156  7.692026e-10 25960000  33560000  susie   TRUE
# 84   4.745392  2.081028e-06 25960000  33560000  bayes_l TRUE
# 85   5.410373  6.289371e-08 25960000  33560000  bayes_r TRUE
# 86   4.909717  9.120776e-07 25960000  33560000  enet    TRUE
# 107  TRUE               0.014854467 3.721703e-02 eQTL chr3_47545024_52179438
# 108 FALSE               0.005959492 1.267806e-01 eQTL chr3_47545024_52179438
# 109 FALSE               0.002320549 2.184084e-01 eQTL chr3_47545024_52179438
# 110  TRUE               0.014854467 3.721703e-02 eQTL chr3_47545024_52179438
# 111 FALSE               0.005959492 1.267806e-01 eQTL chr3_47545024_52179438

# %%
# annotated_all |> filter(gene_name %in% c("DNAJC5", "TRIM26", "USP19", "GGT7"), twas_pval < 2.5* 1e-6) |> group_by(gene_name,gwas_study,context) |> 
#   slice_min(twas_pval, n = 1, with_ties = FALSE) |> arrange(gene_name, gwas_study, context)

# %%
plot_data <- TL1_Aging3_genes %>%
    mutate(
      # Calculate -log10(bonferroni p-value)
      neg_log_twas_pval = -log10(twas_pval),
      # Create color factor based on twas_z sign
      twas_z_sign = ifelse(twas_z < 0, "Negative", "Positive"),
      # Clean up context names for better display (optional)
      context = str_replace(context, 
                               "^(.+?_sQTL)[^:]*:.*:(clu_\\d+_\\+):([A-Z]+):.*$", 
                               "\\1:\\2:\\3"),
      gwas_study = ifelse(grepl("Jansen|Bellenguez|Wightman", gwas_study), "AD", gwas_study))
plot_data = plot_data |> filter(gwas_study != "image_Aging5") |> group_by(gene_name,gwas_study,context) |>  slice_min(twas_pval, n = 1, with_ties = FALSE)
plot_data |> arrange(gene_name, gwas_study, context)
# Out:
#    chr molecular_id    gene_name context                    gwas_study
# 1   2  ENSG00000136717 BIN1      AC_DeJager_eQTL            AD
# 2   2  ENSG00000136717 BIN1      BM_22_MSBB_eQTL            AD
# 3   2  ENSG00000136717 BIN1      DLPFC_DeJager_eQTL         AD
# 4   2  ENSG00000136717 BIN1      Exc_DeJager_eQTL           AD
# 5   2  ENSG00000136717 BIN1      Exc_mega_eQTL              AD
# 6   2  ENSG00000136717 BIN1      Mic_DeJager_eQTL           AD
# 7   2  ENSG00000136717 BIN1      Mic_mega_eQTL              AD
# 8   2  ENSG00000136717 BIN1      PCC_DeJager_eQTL           AD
# 9   2  ENSG00000136717 BIN1      Inh_mega_eQTL              image_Aging3
# 10 20  ENSG00000101152 DNAJC5    BM_36_MSBB_eQTL            Telomere_pc1
# 11 20  ENSG00000101152 DNAJC5    Exc_mega_eQTL              Telomere_pc1
# 12 20  ENSG00000101152 DNAJC5    Knight_eQTL_brain          Telomere_pc1
# 13 20  ENSG00000101152 DNAJC5    Mic_mega_eQTL              Telomere_pc1
# 14 20  ENSG00000101152 DNAJC5    OPC_mega_eQTL              Telomere_pc1
# 15 20  ENSG00000101152 DNAJC5    Oli_DeJager_eQTL           Telomere_pc1
# 16 20  ENSG00000101152 DNAJC5    Oli_mega_eQTL              Telomere_pc1
# 17 20  ENSG00000101152 DNAJC5    PCC_DeJager_eQTL           Telomere_pc1
# 18 20  ENSG00000101152 DNAJC5    monocyte_ROSMAP_eQTL       Telomere_pc1
# 19 20  ENSG00000131067 GGT7      Ast_DeJager_eQTL           Telomere_pc1
# 20 20  ENSG00000131067 GGT7      Exc_DeJager_eQTL           Telomere_pc1
# 21 20  ENSG00000131067 GGT7      Exc_mega_eQTL              Telomere_pc1
# 22 20  ENSG00000131067 GGT7      Inh_DeJager_eQTL           Telomere_pc1
# 23 20  ENSG00000131067 GGT7      Inh_mega_eQTL              Telomere_pc1
# 24 20  ENSG00000131067 GGT7      Mic_DeJager_eQTL           Telomere_pc1
# 25 20  ENSG00000131067 GGT7      monocyte_ROSMAP_eQTL       Telomere_pc1
# 26 20  ENSG00000131067 GGT7      Inh_mega_eQTL              image_Aging3
# 27  6  ENSG00000234127 TRIM26    Exc_mega_eQTL              Telomere_pc1
# 28  6  ENSG00000234127 TRIM26    Inh_mega_eQTL              Telomere_pc1
# 29  6  ENSG00000234127 TRIM26    Knight_eQTL_brain          Telomere_pc1
# 30  6  ENSG00000234127 TRIM26    Oli_mega_eQTL              Telomere_pc1
# 31  6  ENSG00000234127 TRIM26    AC_DeJager_eQTL            image_AD2
# 32  6  ENSG00000234127 TRIM26    DLPFC_DeJager_eQTL         image_AD2
# 33  6  ENSG00000234127 TRIM26    Knight_eQTL_brain          image_AD2
# 34  6  ENSG00000234127 TRIM26    PCC_DeJager_eQTL           image_AD2
# 35  6  ENSG00000234127 TRIM26    Oli_DeJager_eQTL           image_Aging3
# 36  3  ENSG00000172046 USP19     BM_44_MSBB_eQTL            Telomere_pc1
# 37  3  ENSG00000172046 USP19     MSBB_BM36_pQTL_chr3_O94966 Telomere_pc1
# 38  3  ENSG00000172046 USP19     monocyte_ROSMAP_eQTL       Telomere_pc1
# 39  3  ENSG00000172046 USP19     monocyte_ROSMAP_eQTL       image_AD1
#    twas_z     twas_pval    start     end       method  is_imputable
# 1    6.216229 5.092445e-10 127107286 127107287 mrmash  TRUE
# 2    8.440799 3.151770e-17 127107286 127107287 bayes_r TRUE
# 3    7.920283 2.369711e-15 127107286 127107287 mrmash  TRUE
# 4   -8.083012 6.318623e-16 127107286 127107287 susie   TRUE
# 5   -8.290510 1.127637e-16 127107286 127107287 susie   TRUE
# 6   17.729812 2.468593e-70 127107286 127107287 enet    TRUE
# 7   18.636256 1.632764e-77 127107286 127107287 lasso   TRUE
# 8    6.510411 7.494538e-11 127107286 127107287 mvsusie TRUE
# 9   -5.120803 3.042369e-07 123880000 130720000 susie   TRUE
# 10   8.616714 6.890273e-18  59520000  64444167 bayes_l TRUE
# 11 -10.149955 3.315162e-24  59520000  64444167 mrash   TRUE
# 12   5.044622 4.544199e-07  59520000  64444167 mrash   TRUE
# 13  -5.713537 1.106519e-08  59520000  64444167 enet    TRUE
# 14   9.894008 4.419709e-23  59520000  64444167 lasso   TRUE
# 15 -13.091735 3.671238e-39  59520000  64444167 mrash   TRUE
# 16  -8.436479 3.270391e-17  59520000  64444167 enet    TRUE
# 17   9.683925 3.528999e-22  59520000  64444167 mrmash  TRUE
# 18   6.306868 2.847391e-10  59520000  64444167 mvsusie TRUE
# 19  -6.601857 4.060392e-11  33844720  37080000 mrmash  TRUE
# 20  -6.857328 7.016063e-12  33844720  37080000 bayes_l TRUE
# 21  -9.247426 2.299636e-20  33844720  37080000 enet    TRUE
# 24 FALSE               0.014936698 7.028437e-03 eQTL chr20_32060775_36429279
# 25 FALSE               0.072676630 2.378177e-05 eQTL chr20_32060775_36429279
# 26 FALSE               0.047698330 1.277462e-09 eQTL chr20_32060775_36429279
# 27  TRUE               0.076042161 1.506477e-14 eQTL chr6_30136357_31604117
# 28 FALSE               0.088590717 9.644534e-17 eQTL chr6_30136357_31604117
# 29 FALSE               0.077685315 5.818688e-08 eQTL chr6_30136357_31604117
# 30 FALSE               0.085089182 3.839107e-16 eQTL chr6_30136357_31604117
# 31 FALSE               0.098112570 3.474733e-15 eQTL chr6_30136357_31604117
# 32 FALSE               0.078114751 9.354456e-16 eQTL chr6_30136357_31604117
# 33 FALSE               0.077685315 5.818688e-08 eQTL chr6_30136357_31604117
# 34 FALSE               0.022029252 1.034056e-03 eQTL chr6_30136357_31604117
# 35 FALSE               0.017435408 3.913485e-03 eQTL chr6_30136357_31604117
# 36 FALSE              -0.001863853 4.691293e-01 eQTL chr3_47545024_52179438
# 37 FALSE              -0.005426760 9.119453e-01 pQTL chr3_47545024_52179438
# 38 FALSE               0.002320549 2.184084e-01 eQTL chr3_47545024_52179438
# 39  TRUE               0.014854467 3.721703e-02 eQTL chr3_47545024_52179438
#    neg_log_twas_pval twas_z_sign
# 1   9.293074         Positive
# 2  16.501446         Positive
# 3  14.625305         Positive
# 4  15.199378         Negative
# 5  15.947831         Negative
# 6  69.607550         Positive
# 7  76.787076         Positive
# 8  10.125255         Positive
# 9   6.516788         Negative
# 10 17.161764         Positive
# 11 23.479495         Negative
# 12  6.342543         Positive
# 13  7.956041         Negative
# 14 22.354606         Positive
# 15 38.435188         Negative
# 16 16.485400         Negative
# 17 21.452348         Positive
# 18  9.545553         Positive
# 19 10.391432         Negative
# 20 11.153907         Negative
# 21 19.638341         Negative
# 22 10.388857         Negative
# 23  9.492920         Negative
# 24 10.395059         Negative
# 25  9.699607         Negative
# 26  6.090070         Positive
# 27 21.688196         Positive
# 28 17.233919         Positive
# 29 11.598609         Negative
# 30 16.883260         Positive
# 31  9.803544         Positive
# 32  6.075408         Positive
# 33  7.654933         Positive
# 34  7.031795         Positive
# 35  6.862387         Negative
# 36  6.028092         Positive
# 37 16.920936         Negative
# 38  8.179167         Negative
# 39  7.979732         Positive

# %%
library(ggplot2)
library(dplyr)
library(ggrepel)

# --- Process data ---
plot_data_processed <- plot_data %>%
  ungroup() %>%
  mutate(
    # Extract cell type from context
    cell_type = case_when(
      grepl("Exc", context) ~ "Exc",
      grepl("Inh", context) ~ "Inh",
      grepl("Mic", context) ~ "Mic",
      grepl("OPC", context) ~ "OPC",
      grepl("Oli", context) ~ "Oli",
      grepl("monocyte", context) ~ "monocyte",
      TRUE ~ "bulk"
    ),
    # Extract QTL type from context
    qtl_type = case_when(
      grepl("eQTL", context) ~ "eQTL",
      grepl("pQTL", context) ~ "pQTL",
      TRUE ~ "other"
    ),
    # Extract cohort from context
    cohort = case_when(
      grepl("PCC", context) ~ "PCC",
      grepl("AC", context) ~ "AC",
      grepl("DLPFC", context) ~ "DLPFC",
      grepl("Knight", context) ~ "Knight",
      grepl("MSBB", context) ~ "MSBB",
      grepl("ROSMAP", context) ~ "ROSMAP",
      grepl("DeJager", context) ~ "DeJager",
      grepl("mega", context) ~ "mega",
      TRUE ~ "Unknown"
    ),
    gwas_study = case_when(
        startsWith(gwas_study, "image_") ~ paste0("i", substr(gwas_study, 7, nchar(gwas_study))),
        gwas_study == "Telomere_pc1" ~ "Telomere length",
        TRUE ~ gwas_study
    ),
    # Create combined label for cell type and QTL
    cell_qtl_label = paste0(cell_type, "_", qtl_type)
  )

# Fixed order for x-axis contexts
xqtl_context_order <- plot_data_processed %>%
  select(cell_qtl_label, cell_type, qtl_type) %>%
  distinct() %>%
  arrange(cell_type != "bulk",
          factor(cell_type, levels = c("Exc","Inh","Mic","Oli","OPC","monocyte","bulk")),
          qtl_type) %>%
  pull(cell_qtl_label)

# Create x-position within each GWAS-gene combination
plot_data_processed <- plot_data_processed %>%
  mutate(
    gene_cell_qtl = paste0(gene_name, "_", cell_qtl_label),
    cell_qtl_label = factor(cell_qtl_label, levels = xqtl_context_order)
  ) %>%
  group_by(gwas_study, gene_name) %>%
  mutate(gene_order = cur_group_id()) %>%
  ungroup() %>%
  arrange(gwas_study, gene_name, cell_qtl_label) %>%
  mutate(x_position = as.numeric(interaction(gwas_study, gene_name, cell_qtl_label, 
                                              drop = TRUE, lex.order = TRUE)))

# Calculate width metrics for flexible panel sizing
gwas_panel_widths <- plot_data_processed %>%
  group_by(gwas_study) %>%
  summarise(
    n_genes = n_distinct(gene_name),
    n_cell_qtl = n_distinct(cell_qtl_label),
    n_combinations = n_distinct(gene_name, cell_qtl_label),
    .groups = "drop"
  ) %>%
  mutate(
    panel_width = n_combinations * 0.8 + n_genes * 1.0,
    width_ratio = panel_width / sum(panel_width)
  )

# Calculate gene boundaries for rectangles within each GWAS study
gene_boundaries <- plot_data_processed %>%
  group_by(gwas_study, gene_name) %>%
  summarise(
    xmin = min(x_position) - 0.5,
    xmax = max(x_position) + 0.5,
    .groups = "drop"
  )

# Compute gene label positions
gene_positions <- plot_data_processed %>%
  group_by(gwas_study, gene_name) %>%
  summarise(
    xpos = mean(x_position),
    .groups = "drop"
  )

# Get max y value for positioning gene labels
max_y <- max(-log10(plot_data_processed$twas_pval), na.rm = TRUE)

# ---- Build dot plot with facets ----
p_combined <- ggplot(plot_data_processed,
                     aes(x = x_position, y = neg_log_twas_pval, color = twas_z_sign)) +
  # Add gene grouping rectangles
  geom_rect(
    data = gene_boundaries,
    aes(xmin = xmin, xmax = xmax, ymin = -Inf, ymax = Inf),
    fill = NA, color = "gray30", linewidth = 1,
    inherit.aes = FALSE
  ) +
  # Main data points
  geom_point(size = 2.5, alpha = 0.8) +
  # Add cohort labels with repel to avoid overlap
  geom_text_repel(
    aes(label = cohort),
    size = 2.5,
    fontface = "bold",
    color = "black",
    box.padding = 0.35,
    point.padding = 0.3,
    segment.color = "grey50",
    segment.size = 0.3,
    max.overlaps = 40,
    min.segment.length = 0,
    direction = "both",
    seed = 123,
    force = 2,
    force_pull = 0.5
  ) +
  # Significance threshold line (p = 2.5e-6)
  geom_hline(yintercept = -log10(2.5e-6), linetype = "dashed", color = "red", linewidth = 0.8) +
  # Facet by GWAS study with square boxes
  facet_wrap(~gwas_study, scales = "free_x", nrow = 1, strip.position = "top") +
  # Color scheme for Z-score direction
  scale_color_manual(
    values = c("Positive" = "#E64B35", "Negative" = "#4DBBD5"),
    name = "TWAS Z-score",
    labels = c("Negative" = "Negative (↓)", "Positive" = "Positive (↑)")
  ) +
  # X-axis with context labels
  scale_x_continuous(
    breaks = plot_data_processed$x_position,
    labels = plot_data_processed$cell_qtl_label
  ) +
  # Styling
  theme_bw(base_size = 14) +
  theme(
    # Square facet boxes
    strip.background = element_rect(color = "black", fill = "white", linewidth = 1.2),
    strip.text = element_text(face = "bold", size = 14),
    axis.text.x = element_text(angle = 45, hjust = 1, size = 10, face = "bold"),
    axis.title.x = element_blank(),
    panel.grid.major.x = element_blank(),
    panel.spacing = unit(0.5, "lines"),
    legend.position = "bottom",
    plot.margin = margin(10, 10, 10, 10),
    plot.title = element_text(size = 16, face = "bold", hjust = 0.5, margin = margin(b = 15))
  ) +
  labs(
    title = "TWAS Results for Genes Involved in EVs-Mediated Aging & AD Pathology",
    y = bquote(-log[10]~italic(p)),
    color = "TWAS Z-score"
  ) +
  # Annotate gene names above each group
  geom_text(
    data = gene_positions,
    aes(x = xpos, y = max_y * 1.25, label = gene_name),
    inherit.aes = FALSE,
    size = 4,
    fontface = "bold.italic",
    vjust = 0
  ) +
  coord_cartesian(clip = "off", ylim = c(0, max_y * 1.35))

print(p_combined)

# Calculate optimal total width based on content
total_width <- max(25, sum(gwas_panel_widths$panel_width) + 3)

ggsave("Functional_gene_plot_by_gwas_EV.png", p_combined,
       width = total_width, height = 9, dpi = 300, bg = "white")

# Print width information
print(gwas_panel_widths)
cat("\nTotal plot width:", total_width, "inches\n")
cat("\nWidth breakdown:\n")
for(i in 1:nrow(gwas_panel_widths)) {
  cat(sprintf("  %s: %.1f inches (%.1f%% of total)\n", 
              gwas_panel_widths$gwas_study[i],
              gwas_panel_widths$panel_width[i],
              gwas_panel_widths$width_ratio[i] * 100))
}
# Out:
# # A tibble: 5 × 6
#   gwas_study   n_genes n_cell_qtl n_combinations panel_width width_ratio
#   <chr>          <int>      <int>          <int>       <dbl>       <dbl>
# 1 AD                 1          3              3         3.4      0.110
# 2 Telomere_pc1       4          8             18        18.4      0.597
# 3 image_AD1          1          1              1         1.8      0.0584
# 4 image_AD2          1          1              1         1.8      0.0584
# 5 image_Aging3       3          2              3         5.4      0.175
#
# Total plot width: 33.8 inches
#
# Width breakdown:
#   AD: 3.4 inches (11.0% of total)
#   Telomere_pc1: 18.4 inches (59.7% of total)
#   image_AD1: 1.8 inches (5.8% of total)
#   image_AD2: 1.8 inches (5.8% of total)
#   image_Aging3: 5.4 inches (17.5% of total)
# plot without title

# %%
ggsave("TL1_Aging3_twas_all_contexts.png", p_gene_EV, width = 20, height = 8, dpi = 300)
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_text()`).”
