# %%
library(tidyverse)
library(data.table)
# Out:
# -- Attaching core tidyverse packages ------------------------ tidyverse 2.0.0 --
# v dplyr     1.1.4     v readr     2.1.5
# v forcats   1.0.0     v stringr   1.5.1
# v ggplot2   3.5.2     v tibble    3.3.0
# v lubridate 1.9.4     v tidyr     1.3.1
# v purrr     1.1.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# i Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: 'data.table'
#
#
# The following objects are masked from 'package:lubridate':
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
#
# The following objects are masked from 'package:dplyr':
#
#     between, first, last
#
#
# The following object is masked from 'package:purrr':
#
#     transpose

# %%
Aging4_mega <- list.files("~/project/image_QTL/twas/output/image_Aging4_ROSMAP_mega_eQTL/twas", pattern = "twas\\.tsv\\.gz$", full.names = TRUE) %>%
  map_dfr(read_tsv)
Aging4_sQTL <- list.files("~/project/image_QTL/twas/output/image_Aging4_ROSMAP_sQTL/twas", pattern = "twas\\.tsv\\.gz$", full.names = TRUE) %>%
  map_dfr(read_tsv)
Aging4_twas = rbind(Aging4_mega,Aging4_sQTL)
# Out:
# Rows: 104 Columns: 16
# -- Column specification --------------------------------------------------------
# Delimiter: "\t"
# chr (6): molecular_id, context, gwas_study, method, type, block
# dbl (8): chr, TSS, start, end, rsq_cv, pval_cv, twas_z, twas_pval
# lgl (2): is_imputable, is_selected_method
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 120 Columns: 16
# -- Column specification --------------------------------------------------------
# Delimiter: "\t"
# chr (6): molecular_id, context, gwas_study, method, type, block
# dbl (8): chr, TSS, start, end, rsq_cv, pval_cv, twas_z, twas_pval
# lgl (2): is_imputable, is_selected_method
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 120 Columns: 16
# ...

# %%
Aging2_mega <- list.files("~/project/image_QTL/twas/output/image_Aging2_ROSMAP_mega_eQTL/twas", pattern = "twas\\.tsv\\.gz$", full.names = TRUE) %>%
  map_dfr(read_tsv)
Aging2_sQTL <- list.files("~/project/image_QTL/twas/output/image_Aging2_ROSMAP_sQTL/twas", pattern = "twas\\.tsv\\.gz$", full.names = TRUE) %>%
  map_dfr(read_tsv)
Aging2_twas = rbind(Aging2_mega,Aging2_sQTL)

# %%
AD2_mega <- list.files("~/project/image_QTL/twas/output/image_AD2_ROSMAP_mega_eQTL/twas", pattern = "twas\\.tsv\\.gz$", full.names = TRUE) %>%
  map_dfr(read_tsv)
AD2_sQTL <- list.files("~/project/image_QTL/twas/output/image_AD2_ROSMAP_sQTL/twas", pattern = "twas\\.tsv\\.gz$", full.names = TRUE) %>%
  map_dfr(read_tsv)
AD2_twas = rbind(AD2_mega,AD2_sQTL)
# Out:
# Rows: 52 Columns: 16
# -- Column specification --------------------------------------------------------
# Delimiter: "\t"
# chr (6): molecular_id, context, gwas_study, method, type, block
# dbl (8): chr, TSS, start, end, rsq_cv, pval_cv, twas_z, twas_pval
# lgl (2): is_imputable, is_selected_method
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 120 Columns: 16
# -- Column specification --------------------------------------------------------
# Delimiter: "\t"
# chr (6): molecular_id, context, gwas_study, method, type, block
# dbl (8): chr, TSS, start, end, rsq_cv, pval_cv, twas_z, twas_pval
# lgl (2): is_imputable, is_selected_method
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 132 Columns: 16
# ...

# %% [markdown]
# ## Aging4

# %%
# ERO1B

# %%
ERO1B = Aging4_twas |> filter(molecular_id == "ENSG00000086619", twas_pval < 6.25*1e-4)
ERO1B
# Out:
#   chr molecular_id    TSS       start     end
# 1 1   ENSG00000086619 236281957 235215101 237720000
# 2 1   ENSG00000086619 236281957 235215101 237720000
# 3 1   ENSG00000086619 236281957 235215101 237720000
#   context
# 1 ROSMAP_PCC_sQTL_chr1:236222010:236225069:clu_11596_-:PR:ENSG00000086619
# 2 ROSMAP_PCC_sQTL_chr1:236222010:236225069:clu_11596_-:PR:ENSG00000086619
# 3 ROSMAP_PCC_sQTL_chr1:236225139:236226268:clu_11596_-:PR:ENSG00000086619
#   gwas_study   method is_imputable is_selected_method rsq_cv      pval_cv
# 1 image_Aging4 mrash  TRUE          TRUE              0.010364879 0.01745691
# 2 image_Aging4 susie  TRUE         FALSE              0.003083837 0.12314729
# 3 image_Aging4 mrash  TRUE         FALSE              0.010811762 0.01556365
#   twas_z    twas_pval    type            block
# 1 -4.591056 4.410094e-06 productive_sQTL chr1_235656952_237008086
# 2 -4.526834 5.987400e-06 productive_sQTL chr1_235656952_237008086
# ...

# %%
# AP3B1

# %%
AP3B1 = Aging4_twas |> filter(molecular_id == "ENSG00000132842", twas_pval < 0.05)
AP3B1
# Out:
#   chr molecular_id    TSS      start    end
# 1 5   ENSG00000132842 78294697 77002326 79520000
# 2 5   ENSG00000132842 78294697 77002326 79520000
# 3 5   ENSG00000132842 78294697 77002326 79520000
# 4 5   ENSG00000132842 78294697 77002326 79520000
#   context
# 1 ROSMAP_DLPFC_sQTL_chr5:78162951:78163178:clu_51854_-:UP:ENSG00000132842
# 2 ROSMAP_DLPFC_sQTL_chr5:78162951:78163178:clu_51854_-:UP:ENSG00000132842
# 3 ROSMAP_PCC_sQTL_chr5:78039274:78089392:clu_40422_-:PR:ENSG00000132842
# 4 ROSMAP_PCC_sQTL_chr5:78039274:78089392:clu_40422_-:PR:ENSG00000132842
#   gwas_study   method is_imputable is_selected_method rsq_cv      pval_cv
# 1 image_Aging4 enet   TRUE         FALSE              0.002607661 0.078448725
# 2 image_Aging4 lasso  TRUE         FALSE              0.002490947 0.083124271
# 3 image_Aging4 mrash  TRUE         FALSE              0.012018663 0.011433783
# 4 image_Aging4 susie  TRUE          TRUE              0.017794068 0.002678642
# ...

# %%
# NABP2

# %%
NABP2 = Aging4_twas |> filter(molecular_id == "ENSG00000139579", twas_pval < 6.25*1e-6)
NABP2
# Out:
#   chr molecular_id    TSS      start    end
# 1 12  ENSG00000139579 56222014 55222014 57960000
# 2 12  ENSG00000139579 56222014 55222014 57960000
#   context
# 1 ROSMAP_AC_sQTL_chr12:56226419:56229013:clu_90187_+:PR:ENSG00000139579
# 2 ROSMAP_AC_sQTL_chr12:56226419:56229013:clu_90187_+:PR:ENSG00000139579
#   gwas_study   method is_imputable is_selected_method rsq_cv     pval_cv
# 1 image_Aging4 enet   TRUE         FALSE              0.01851309 0.0004728843
# 2 image_Aging4 mrash  TRUE         FALSE              0.01629414 0.0009807391
#   twas_z   twas_pval    type            block
# 1 4.612547 3.977648e-06 productive_sQTL chr12_54557704_56408332
# 2 4.764387 1.894289e-06 productive_sQTL chr12_54557704_56408332

# %%
# ANKRD52

# %%
ANKRD52 = Aging4_twas |> filter(molecular_id == "ENSG00000139645", twas_pval < 6.25*1e-2)
ANKRD52
# Out:
#    chr molecular_id    TSS      start    end
# 1  12  ENSG00000139645 56258383 55237807 57960000
# 2  12  ENSG00000139645 56258383 55237807 57960000
# 3  12  ENSG00000139645 56258383 55237807 57960000
# 4  12  ENSG00000139645 56258383 55237807 57960000
# 5  12  ENSG00000139645 56258383 55237807 57960000
# 6  12  ENSG00000139645 56258383 55237807 57960000
# 7  12  ENSG00000139645 56258383 55237807 57960000
# 8  12  ENSG00000139645 56258383 55237807 57960000
# 9  12  ENSG00000139645 56258383 55237807 57960000
# 10 12  ENSG00000139645 56258383 55237807 57960000
# 11 12  ENSG00000139645 56258383 55237807 57960000
# 12 12  ENSG00000139645 56258383 55237807 57960000
# 13 12  ENSG00000139645 56258383 55237807 57960000
# 14 12  ENSG00000139645 56258383 55237807 57960000
# 15 12  ENSG00000139645 56258383 55237807 57960000
#    context
# 1  Exc_mega_eQTL
# 2  Exc_mega_eQTL
# 3  Exc_mega_eQTL
# 4  Exc_mega_eQTL
# 5  Inh_mega_eQTL
# 6  Inh_mega_eQTL
# 7  Inh_mega_eQTL
# ...

# %%
# COQ10A
COQ10A = Aging4_twas |> filter(molecular_id == "ENSG00000135469")
COQ10A
# Out:
#   chr molecular_id    TSS      start    end
# 1 12  ENSG00000135469 56266941 55266941 57960000
# 2 12  ENSG00000135469 56266941 55266941 57960000
# 3 12  ENSG00000135469 56266941 55266941 57960000
# 4 12  ENSG00000135469 56266941 55266941 57960000
#   context
# 1 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
# 2 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
# 3 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
# 4 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
#   gwas_study   method is_imputable is_selected_method rsq_cv
# 1 image_Aging4 enet   TRUE         FALSE              -0.0008640047
# 2 image_Aging4 lasso  TRUE         FALSE              -0.0008896669
# 3 image_Aging4 mrash  TRUE         FALSE               0.0063246561
# 4 image_Aging4 susie  TRUE          TRUE               0.0237575649
#   pval_cv      twas_z      twas_pval type            block
# ...

# %%
# CS
CS = Aging4_twas |> filter(molecular_id == "ENSG00000062485")
CS
# Out:
#    chr molecular_id    TSS      start    end
# 1  12  ENSG00000062485 56300390 55271699 57960000
# 2  12  ENSG00000062485 56300390 55271699 57960000
# 3  12  ENSG00000062485 56300390 55271699 57960000
# 4  12  ENSG00000062485 56300390 55271699 57960000
# 5  12  ENSG00000062485 56300390 55271699 57960000
# 6  12  ENSG00000062485 56300390 55271699 57960000
# 7  12  ENSG00000062485 56300390 55271699 57960000
# 8  12  ENSG00000062485 56300390 55271699 57960000
# 9  12  ENSG00000062485 56300390 55271699 57960000
# 10 12  ENSG00000062485 56300390 55271699 57960000
# 11 12  ENSG00000062485 56300390 55271699 57960000
# 12 12  ENSG00000062485 56300390 55271699 57960000
# 13 12  ENSG00000062485 56300390 55271699 57960000
# 14 12  ENSG00000062485 56300390 55271699 57960000
# 15 12  ENSG00000062485 56300390 55271699 57960000
# 16 12  ENSG00000062485 56300390 55271699 57960000
# 17 12  ENSG00000062485 56300390 55271699 57960000
# 18 12  ENSG00000062485 56300390 55271699 57960000
# ...

# %%
# CNPY2
CNPY2 = Aging4_twas |> filter(molecular_id == "ENSG00000135473")
CNPY2
# Out:
#    chr molecular_id    TSS      start    end
# 1  12  ENSG00000135473 56334052 55316223 57960000
# 2  12  ENSG00000135473 56334052 55316223 57960000
# 3  12  ENSG00000135473 56334052 55316223 57960000
# 4  12  ENSG00000135473 56334052 55316223 57960000
# 5  12  ENSG00000135473 56334052 55316223 57960000
# 6  12  ENSG00000135473 56334052 55316223 57960000
# 7  12  ENSG00000135473 56334052 55316223 57960000
# 8  12  ENSG00000135473 56334052 55316223 57960000
# 9  12  ENSG00000135473 56334052 55316223 57960000
# 10 12  ENSG00000135473 56334052 55316223 57960000
# 11 12  ENSG00000135473 56334052 55316223 57960000
# 12 12  ENSG00000135473 56334052 55316223 57960000
# 13 12  ENSG00000135473 56334052 55316223 57960000
# 14 12  ENSG00000135473 56334052 55316223 57960000
# 15 12  ENSG00000135473 56334052 55316223 57960000
# 16 12  ENSG00000135473 56334052 55316223 57960000
# 17 12  ENSG00000135473 56334052 55316223 57960000
# 18 12  ENSG00000135473 56334052 55316223 57960000
# ...

# %%
# PAN2
PAN2 = Aging4_twas |> filter(molecular_id == "ENSG00000135469")
PAN2
# Out:
#   chr molecular_id    TSS      start    end
# 1 12  ENSG00000135469 56266941 55266941 57960000
# 2 12  ENSG00000135469 56266941 55266941 57960000
# 3 12  ENSG00000135469 56266941 55266941 57960000
# 4 12  ENSG00000135469 56266941 55266941 57960000
#   context
# 1 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
# 2 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
# 3 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
# 4 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
#   gwas_study   method is_imputable is_selected_method rsq_cv
# 1 image_Aging4 enet   TRUE         FALSE              -0.0008640047
# 2 image_Aging4 lasso  TRUE         FALSE              -0.0008896669
# 3 image_Aging4 mrash  TRUE         FALSE               0.0063246561
# 4 image_Aging4 susie  TRUE          TRUE               0.0237575649
#   pval_cv      twas_z      twas_pval type            block
# ...

# %%
# IL23A
IL23A = Aging4_twas |> filter(molecular_id == "ENSG00000110944")
IL23A
# Out:
#      chr molecular_id TSS start end context gwas_study method is_imputable
#      is_selected_method rsq_cv pval_cv twas_z twas_pval type block

# %%
# STAT2
STAT2 = Aging4_twas |> filter(molecular_id == "ENSG00000135469")
STAT2
# Out:
#   chr molecular_id    TSS      start    end
# 1 12  ENSG00000135469 56266941 55266941 57960000
# 2 12  ENSG00000135469 56266941 55266941 57960000
# 3 12  ENSG00000135469 56266941 55266941 57960000
# 4 12  ENSG00000135469 56266941 55266941 57960000
#   context
# 1 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
# 2 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
# 3 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
# 4 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
#   gwas_study   method is_imputable is_selected_method rsq_cv
# 1 image_Aging4 enet   TRUE         FALSE              -0.0008640047
# 2 image_Aging4 lasso  TRUE         FALSE              -0.0008896669
# 3 image_Aging4 mrash  TRUE         FALSE               0.0063246561
# 4 image_Aging4 susie  TRUE          TRUE               0.0237575649
#   pval_cv      twas_z      twas_pval type            block
# ...

# %% [markdown]
# ## Aging2

# %%
# KDM2B
KDM2B = Aging2_twas |> filter(molecular_id == "ENSG00000089094")
KDM2B
# Out:
#    chr molecular_id    TSS       start     end
# 1  12  ENSG00000089094 121581022 120080000 124040000
# 2  12  ENSG00000089094 121581022 120080000 124040000
# 3  12  ENSG00000089094 121581022 120080000 124040000
# 4  12  ENSG00000089094 121581022 120080000 124040000
# 5  12  ENSG00000089094 121581022 120080000 124040000
# 6  12  ENSG00000089094 121581022 120080000 124040000
# 7  12  ENSG00000089094 121581022 120080000 124040000
# 8  12  ENSG00000089094 121581022 120080000 124040000
# 9  12  ENSG00000089094 121581022 120080000 124040000
# 10 12  ENSG00000089094 121581022 120080000 124040000
# 11 12  ENSG00000089094 121581022 120080000 124040000
# 12 12  ENSG00000089094 121581022 120080000 124040000
# 13 12  ENSG00000089094 121581022 120080000 124040000
# 14 12  ENSG00000089094 121581022 120080000 124040000
# 15 12  ENSG00000089094 121581022 120080000 124040000
# 16 12  ENSG00000089094 121581022 120080000 124040000
#    context
# 1  Exc_mega_eQTL
# 2  Exc_mega_eQTL
# 3  Exc_mega_eQTL
# ...

# %%
# ARMH4
ARMH4 = Aging2_twas |> filter(molecular_id == "ENSG00000139971", twas_pval < 6.25*1e-5)
ARMH4
# Out:
#   chr molecular_id    TSS      start    end
# 1 14  ENSG00000139971 58298138 56480000 60600000
# 2 14  ENSG00000139971 58298138 56480000 60600000
# 3 14  ENSG00000139971 58298138 56480000 60600000
# 4 14  ENSG00000139971 58298138 56480000 60600000
# 5 14  ENSG00000139971 58298138 56480000 60600000
#   context
# 1 ROSMAP_DLPFC_sQTL_chr14:58257998:58260947:clu_119034_+:PR:ENSG00000139971
# 2 ROSMAP_DLPFC_sQTL_chr14:58257998:58260947:clu_119034_+:PR:ENSG00000139971
# 3 ROSMAP_PCC_sQTL_chr14:58004804:58005047:clu_93941_-:PR:ENSG00000139971
# 4 ROSMAP_PCC_sQTL_chr14:58004804:58005047:clu_93941_-:PR:ENSG00000139971
# 5 ROSMAP_PCC_sQTL_chr14:58096981:58131511:clu_93943_-:PR:ENSG00000139971
#   gwas_study   method is_imputable is_selected_method rsq_cv      pval_cv
# 1 image_Aging3 mrash  TRUE         FALSE              0.007217633 9.018500e-03
# 2 image_Aging3 susie  TRUE          TRUE              0.010919757 1.725261e-03
# ...

# %%
# PSMA3
PSMA3 = Aging2_twas |> filter(molecular_id == "ENSG00000100567")
PSMA3
# Out:
#      chr molecular_id TSS start end context gwas_study method is_imputable
#      is_selected_method rsq_cv pval_cv twas_z twas_pval type block

# %%
# UGT2B7
UGT2B7 = Aging2_twas |> filter(molecular_id == "ENSG00000171234")
UGT2B7
# Out:
#      chr molecular_id TSS start end context gwas_study method is_imputable
#      is_selected_method rsq_cv pval_cv twas_z twas_pval type block

# %% [markdown]
# ## AD2

# %%
# ERO1B

# %%
ERO1B = AD2_twas |> filter(molecular_id == "ENSG00000086619", twas_pval < 6.25*1e-4)
ERO1B
# Out:
#   chr molecular_id    TSS       start     end
# 1 1   ENSG00000086619 236281957 235215101 237720000
# 2 1   ENSG00000086619 236281957 235215101 237720000
# 3 1   ENSG00000086619 236281957 235215101 237720000
# 4 1   ENSG00000086619 236281957 235215101 237720000
#   context
# 1 Inh_mega_eQTL
# 2 ROSMAP_PCC_sQTL_chr1:236222010:236225069:clu_11596_-:PR:ENSG00000086619
# 3 ROSMAP_PCC_sQTL_chr1:236222010:236225069:clu_11596_-:PR:ENSG00000086619
# 4 ROSMAP_PCC_sQTL_chr1:236225139:236226268:clu_11596_-:PR:ENSG00000086619
#   gwas_study method is_imputable is_selected_method rsq_cv      pval_cv
# 1 image_AD2  susie  TRUE          TRUE              0.102265502 3.506038e-19
# 2 image_AD2  mrash  TRUE          TRUE              0.010364879 1.745691e-02
# 3 image_AD2  susie  TRUE         FALSE              0.003083837 1.231473e-01
# 4 image_AD2  mrash  TRUE         FALSE              0.010811762 1.556365e-02
#   twas_z    twas_pval    type            block
# ...

# %%
# AP3B1

# %%
AP3B1 = AD2_twas |> filter(molecular_id == "ENSG00000132842", twas_pval < 0.05)
AP3B1
# Out:
#    chr molecular_id    TSS      start    end
# 1  5   ENSG00000132842 78294697 77002326 79520000
# 2  5   ENSG00000132842 78294697 77002326 79520000
# 3  5   ENSG00000132842 78294697 77002326 79520000
# 4  5   ENSG00000132842 78294697 77002326 79520000
# 5  5   ENSG00000132842 78294697 77002326 79520000
# 6  5   ENSG00000132842 78294697 77002326 79520000
# 7  5   ENSG00000132842 78294697 77002326 79520000
# 8  5   ENSG00000132842 78294697 77002326 79520000
# 9  5   ENSG00000132842 78294697 77002326 79520000
# 10 5   ENSG00000132842 78294697 77002326 79520000
# 11 5   ENSG00000132842 78294697 77002326 79520000
# 12 5   ENSG00000132842 78294697 77002326 79520000
#    context
# 1  Oli_mega_eQTL
# 2  Oli_mega_eQTL
# 3  Oli_mega_eQTL
# 4  Oli_mega_eQTL
# 5  ROSMAP_DLPFC_sQTL_chr5:78103415:78110206:clu_51846_-:UP:ENSG00000132842
# 6  ROSMAP_DLPFC_sQTL_chr5:78103415:78110206:clu_51846_-:UP:ENSG00000132842
# 7  ROSMAP_DLPFC_sQTL_chr5:78129307:78156257:clu_51852_-:PR:ENSG00000132842
# ...

# %%
# NABP2

# %%
NABP2 = AD2_twas |> filter(molecular_id == "ENSG00000139579")
NABP2
# Out:
#   chr molecular_id    TSS      start    end
# 1 12  ENSG00000139579 56222014 55222014 57960000
# 2 12  ENSG00000139579 56222014 55222014 57960000
# 3 12  ENSG00000139579 56222014 55222014 57960000
# 4 12  ENSG00000139579 56222014 55222014 57960000
# 5 12  ENSG00000139579 56222014 55222014 57960000
# 6 12  ENSG00000139579 56222014 55222014 57960000
# 7 12  ENSG00000139579 56222014 55222014 57960000
# 8 12  ENSG00000139579 56222014 55222014 57960000
#   context
# 1 ROSMAP_AC_sQTL_chr12:56226419:56229013:clu_90187_+:PR:ENSG00000139579
# 2 ROSMAP_AC_sQTL_chr12:56226419:56229013:clu_90187_+:PR:ENSG00000139579
# 3 ROSMAP_AC_sQTL_chr12:56226419:56229013:clu_90187_+:PR:ENSG00000139579
# 4 ROSMAP_AC_sQTL_chr12:56226419:56229013:clu_90187_+:PR:ENSG00000139579
# 5 ROSMAP_AC_sQTL_chr12:56226419:56229438:clu_90187_+:UP:ENSG00000139579
# 6 ROSMAP_AC_sQTL_chr12:56226419:56229438:clu_90187_+:UP:ENSG00000139579
# 7 ROSMAP_AC_sQTL_chr12:56226419:56229438:clu_90187_+:UP:ENSG00000139579
# ...

# %%
# ANKRD52

# %%
ANKRD52 = AD2_twas |> filter(molecular_id == "ENSG00000139645", twas_pval < 6.25*1e-2)
ANKRD52
# Out:
#   chr molecular_id    TSS      start    end
# 1 12  ENSG00000139645 56258383 55237807 57960000
# 2 12  ENSG00000139645 56258383 55237807 57960000
# 3 12  ENSG00000139645 56258383 55237807 57960000
# 4 12  ENSG00000139645 56258383 55237807 57960000
# 5 12  ENSG00000139645 56258383 55237807 57960000
# 6 12  ENSG00000139645 56258383 55237807 57960000
# 7 12  ENSG00000139645 56258383 55237807 57960000
# 8 12  ENSG00000139645 56258383 55237807 57960000
# 9 12  ENSG00000139645 56258383 55237807 57960000
#   context
# 1 ROSMAP_AC_sQTL_chr12:56244435:56244651:clu_93575_-:PR:ENSG00000139645
# 2 ROSMAP_AC_sQTL_chr12:56244435:56244651:clu_93575_-:PR:ENSG00000139645
# 3 ROSMAP_AC_sQTL_chr12:56244435:56244724:clu_93575_-:UP:ENSG00000139645
# 4 ROSMAP_AC_sQTL_chr12:56244435:56244724:clu_93575_-:UP:ENSG00000139645
# 5 ROSMAP_AC_sQTL_chr12:56257361:56257827:clu_93583_-:PR:ENSG00000139645
# 6 ROSMAP_AC_sQTL_chr12:56257361:56257827:clu_93583_-:PR:ENSG00000139645
# ...

# %%
# COQ10A
COQ10A = AD2_twas |> filter(molecular_id == "ENSG00000135469")
COQ10A
# Out:
#   chr molecular_id    TSS      start    end
# 1 12  ENSG00000135469 56266941 55266941 57960000
# 2 12  ENSG00000135469 56266941 55266941 57960000
# 3 12  ENSG00000135469 56266941 55266941 57960000
# 4 12  ENSG00000135469 56266941 55266941 57960000
#   context
# 1 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
# 2 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
# 3 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
# 4 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
#   gwas_study method is_imputable is_selected_method rsq_cv        pval_cv
# 1 image_AD2  enet   TRUE         FALSE              -0.0008640047 5.808707e-01
# 2 image_AD2  lasso  TRUE         FALSE              -0.0008896669 5.939436e-01
# 3 image_AD2  mrash  TRUE         FALSE               0.0063246561 1.354299e-02
# 4 image_AD2  susie  TRUE          TRUE               0.0237575649 6.556686e-06
# ...

# %%
# CS
CS = AD2_twas |> filter(molecular_id == "ENSG00000062485")
CS
# Out:
#    chr molecular_id    TSS      start    end
# 1  12  ENSG00000062485 56300390 55271699 57960000
# 2  12  ENSG00000062485 56300390 55271699 57960000
# 3  12  ENSG00000062485 56300390 55271699 57960000
# 4  12  ENSG00000062485 56300390 55271699 57960000
# 5  12  ENSG00000062485 56300390 55271699 57960000
# 6  12  ENSG00000062485 56300390 55271699 57960000
# 7  12  ENSG00000062485 56300390 55271699 57960000
# 8  12  ENSG00000062485 56300390 55271699 57960000
# 9  12  ENSG00000062485 56300390 55271699 57960000
# 10 12  ENSG00000062485 56300390 55271699 57960000
# 11 12  ENSG00000062485 56300390 55271699 57960000
# 12 12  ENSG00000062485 56300390 55271699 57960000
# 13 12  ENSG00000062485 56300390 55271699 57960000
# 14 12  ENSG00000062485 56300390 55271699 57960000
# 15 12  ENSG00000062485 56300390 55271699 57960000
# 16 12  ENSG00000062485 56300390 55271699 57960000
# 17 12  ENSG00000062485 56300390 55271699 57960000
# 18 12  ENSG00000062485 56300390 55271699 57960000
# ...

# %%
# CNPY2
CNPY2 = AD2_twas |> filter(molecular_id == "ENSG00000135473")
CNPY2
# Out:
#    chr molecular_id    TSS      start    end
# 1  12  ENSG00000135473 56334052 55316223 57960000
# 2  12  ENSG00000135473 56334052 55316223 57960000
# 3  12  ENSG00000135473 56334052 55316223 57960000
# 4  12  ENSG00000135473 56334052 55316223 57960000
# 5  12  ENSG00000135473 56334052 55316223 57960000
# 6  12  ENSG00000135473 56334052 55316223 57960000
# 7  12  ENSG00000135473 56334052 55316223 57960000
# 8  12  ENSG00000135473 56334052 55316223 57960000
# 9  12  ENSG00000135473 56334052 55316223 57960000
# 10 12  ENSG00000135473 56334052 55316223 57960000
# 11 12  ENSG00000135473 56334052 55316223 57960000
# 12 12  ENSG00000135473 56334052 55316223 57960000
# 13 12  ENSG00000135473 56334052 55316223 57960000
# 14 12  ENSG00000135473 56334052 55316223 57960000
# 15 12  ENSG00000135473 56334052 55316223 57960000
# 16 12  ENSG00000135473 56334052 55316223 57960000
# 17 12  ENSG00000135473 56334052 55316223 57960000
# 18 12  ENSG00000135473 56334052 55316223 57960000
# ...

# %%
# PAN2
PAN2 = AD2_twas |> filter(molecular_id == "ENSG00000135469")
PAN2
# Out:
#   chr molecular_id    TSS      start    end
# 1 12  ENSG00000135469 56266941 55266941 57960000
# 2 12  ENSG00000135469 56266941 55266941 57960000
# 3 12  ENSG00000135469 56266941 55266941 57960000
# 4 12  ENSG00000135469 56266941 55266941 57960000
#   context
# 1 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
# 2 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
# 3 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
# 4 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
#   gwas_study method is_imputable is_selected_method rsq_cv        pval_cv
# 1 image_AD2  enet   TRUE         FALSE              -0.0008640047 5.808707e-01
# 2 image_AD2  lasso  TRUE         FALSE              -0.0008896669 5.939436e-01
# 3 image_AD2  mrash  TRUE         FALSE               0.0063246561 1.354299e-02
# 4 image_AD2  susie  TRUE          TRUE               0.0237575649 6.556686e-06
# ...

# %%
# IL23A
IL23A = AD2_twas |> filter(molecular_id == "ENSG00000110944")
IL23A
# Out:
#      chr molecular_id TSS start end context gwas_study method is_imputable
#      is_selected_method rsq_cv pval_cv twas_z twas_pval type block

# %%
# STAT2
STAT2 = AD2_twas |> filter(molecular_id == "ENSG00000135469")
STAT2
# Out:
#   chr molecular_id    TSS      start    end
# 1 12  ENSG00000135469 56266941 55266941 57960000
# 2 12  ENSG00000135469 56266941 55266941 57960000
# 3 12  ENSG00000135469 56266941 55266941 57960000
# 4 12  ENSG00000135469 56266941 55266941 57960000
#   context
# 1 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
# 2 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
# 3 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
# 4 ROSMAP_DLPFC_sQTL_chr12:56267252:56267793:clu_106960_+:PR:ENSG00000135469
#   gwas_study method is_imputable is_selected_method rsq_cv        pval_cv
# 1 image_AD2  enet   TRUE         FALSE              -0.0008640047 5.808707e-01
# 2 image_AD2  lasso  TRUE         FALSE              -0.0008896669 5.939436e-01
# 3 image_AD2  mrash  TRUE         FALSE               0.0063246561 1.354299e-02
# 4 image_AD2  susie  TRUE          TRUE               0.0237575649 6.556686e-06
# ...
