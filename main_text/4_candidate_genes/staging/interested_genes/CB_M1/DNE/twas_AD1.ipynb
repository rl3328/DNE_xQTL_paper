# %%
library(tidyverse)
library(data.table)

# %%
Aging5_mega <- list.files("~/project/image_QTL/twas/output/image_Aging5_ROSMAP_mega_eQTL/twas", pattern = "twas\\.tsv\\.gz$", full.names = TRUE) %>%
  map_dfr(read_tsv)
Aging5_sQTL <- list.files("~/project/image_QTL/twas/output/image_Aging5_ROSMAP_sQTL/twas", pattern = "twas\\.tsv\\.gz$", full.names = TRUE) %>%
  map_dfr(read_tsv)
Aging5_twas = rbind(Aging5_mega,Aging5_sQTL)
# Out:
# Rows: 136 Columns: 16
# -- Column specification --------------------------------------------------------
# Delimiter: "\t"
# chr (6): molecular_id, context, gwas_study, method, type, block
# dbl (8): chr, TSS, start, end, rsq_cv, pval_cv, twas_z, twas_pval
# lgl (2): is_imputable, is_selected_method
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 88 Columns: 16
# -- Column specification --------------------------------------------------------
# Delimiter: "\t"
# chr (6): molecular_id, context, gwas_study, method, type, block
# dbl (8): chr, TSS, start, end, rsq_cv, pval_cv, twas_z, twas_pval
# lgl (2): is_imputable, is_selected_method
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 64 Columns: 16
# ...

# %%
Aging3_mega <- list.files("~/project/image_QTL/twas/output/image_Aging3_ROSMAP_mega_eQTL/twas", pattern = "twas\\.tsv\\.gz$", full.names = TRUE) %>%
  map_dfr(read_tsv)
Aging3_sQTL <- list.files("~/project/image_QTL/twas/output/image_Aging3_ROSMAP_sQTL/twas", pattern = "twas\\.tsv\\.gz$", full.names = TRUE) %>%
  map_dfr(read_tsv)
Aging3_twas = rbind(Aging3_mega,Aging3_sQTL)
# Out:
# Rows: 276 Columns: 16
# -- Column specification --------------------------------------------------------
# Delimiter: "\t"
# chr (6): molecular_id, context, gwas_study, method, type, block
# dbl (8): chr, TSS, start, end, rsq_cv, pval_cv, twas_z, twas_pval
# lgl (2): is_imputable, is_selected_method
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 188 Columns: 16
# -- Column specification --------------------------------------------------------
# Delimiter: "\t"
# chr (6): molecular_id, context, gwas_study, method, type, block
# dbl (8): chr, TSS, start, end, rsq_cv, pval_cv, twas_z, twas_pval
# lgl (2): is_imputable, is_selected_method
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1156 Columns: 16
# ...

# %%
AD1_mega <- list.files("~/project/image_QTL/twas/output/image_AD1_ROSMAP_mega_eQTL/twas", pattern = "twas\\.tsv\\.gz$", full.names = TRUE) %>%
  map_dfr(read_tsv)
AD1_sQTL <- list.files("~/project/image_QTL/twas/output/image_AD1_ROSMAP_sQTL/twas", pattern = "twas\\.tsv\\.gz$", full.names = TRUE) %>%
  map_dfr(read_tsv)
AD1_twas = rbind(AD1_mega,AD1_sQTL)
# Out:
# Rows: 276 Columns: 16
# -- Column specification --------------------------------------------------------
# Delimiter: "\t"
# chr (6): molecular_id, context, gwas_study, method, type, block
# dbl (8): chr, TSS, start, end, rsq_cv, pval_cv, twas_z, twas_pval
# lgl (2): is_imputable, is_selected_method
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 52 Columns: 16
# -- Column specification --------------------------------------------------------
# Delimiter: "\t"
# chr (6): molecular_id, context, gwas_study, method, type, block
# dbl (8): chr, TSS, start, end, rsq_cv, pval_cv, twas_z, twas_pval
# lgl (2): is_imputable, is_selected_method
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 136 Columns: 16
# ...

# %% [markdown]
# ## Aging5

# %%
# AMZ1

# %%
AMZ1 = Aging5_twas |> filter(molecular_id == "ENSG00000174945", twas_pval < 6.25*1e-6)
AMZ1
# Out:
#   chr molecular_id    TSS     start end   context       gwas_study   method
# 1 7   ENSG00000174945 2679521 0     6e+06 Inh_mega_eQTL image_Aging5 enet
# 2 7   ENSG00000174945 2679521 0     6e+06 Inh_mega_eQTL image_Aging5 lasso
# 3 7   ENSG00000174945 2679521 0     6e+06 Inh_mega_eQTL image_Aging5 mrash
# 4 7   ENSG00000174945 2679521 0     6e+06 Inh_mega_eQTL image_Aging5 susie
# 5 7   ENSG00000174945 2679521 0     6e+06 OPC_mega_eQTL image_Aging5 enet
# 6 7   ENSG00000174945 2679521 0     6e+06 OPC_mega_eQTL image_Aging5 lasso
# 7 7   ENSG00000174945 2679521 0     6e+06 OPC_mega_eQTL image_Aging5 mrash
# 8 7   ENSG00000174945 2679521 0     6e+06 OPC_mega_eQTL image_Aging5 susie
#   is_imputable is_selected_method rsq_cv    pval_cv      twas_z   twas_pval
# 1 TRUE          TRUE              0.2519537 1.907347e-48 6.178336 6.478060e-10
# 2 TRUE         FALSE              0.2495352 6.265737e-48 6.178782 6.459817e-10
# ...

# %%
# NBEAL2

# %%
NBEAL2 = Aging5_twas |> filter(molecular_id == "ENSG00000160796", twas_pval < 6.25*1e-5)
NBEAL2
# Out:
#   chr molecular_id    TSS      start    end
# 1 3   ENSG00000160796 46979665 44920000 50320000
#   context
# 1 ROSMAP_PCC_sQTL_chr3:47001826:47002370:clu_24167_+:PR:ENSG00000160796
#   gwas_study   method is_imputable is_selected_method rsq_cv     pval_cv
# 1 image_Aging5 susie  TRUE         FALSE              0.01217929 0.01097587
#   twas_z    twas_pval    type            block
# 1 -4.013339 5.986585e-05 productive_sQTL chr3_45108216_47545024

# %%
# GNA12

# %%
GNA12 = Aging5_twas |> filter(molecular_id == "ENSG00000146535", twas_pval < 6.25*1e-6)
GNA12
# Out:
#    chr molecular_id    TSS     start end   context       gwas_study   method
# 1  7   ENSG00000146535 2844307 0     6e+06 Inh_mega_eQTL image_Aging5 enet
# 2  7   ENSG00000146535 2844307 0     6e+06 Inh_mega_eQTL image_Aging5 lasso
# 3  7   ENSG00000146535 2844307 0     6e+06 Inh_mega_eQTL image_Aging5 mrash
# 4  7   ENSG00000146535 2844307 0     6e+06 Inh_mega_eQTL image_Aging5 susie
# 5  7   ENSG00000146535 2844307 0     6e+06 Mic_mega_eQTL image_Aging5 enet
# 6  7   ENSG00000146535 2844307 0     6e+06 Mic_mega_eQTL image_Aging5 lasso
# 7  7   ENSG00000146535 2844307 0     6e+06 Mic_mega_eQTL image_Aging5 mrash
# 8  7   ENSG00000146535 2844307 0     6e+06 Mic_mega_eQTL image_Aging5 susie
# 9  7   ENSG00000146535 2844307 0     6e+06 OPC_mega_eQTL image_Aging5 enet
# 10 7   ENSG00000146535 2844307 0     6e+06 OPC_mega_eQTL image_Aging5 lasso
# 11 7   ENSG00000146535 2844307 0     6e+06 OPC_mega_eQTL image_Aging5 mrash
# ...

# %%
# SCAP

# %%
SCAP = Aging5_twas |> filter(molecular_id == "ENSG00000114650", twas_pval < 6.25*1e-2)
SCAP
# Out:
#    chr molecular_id    TSS      start    end
# 1  3   ENSG00000114650 47477125 46413681 50320000
# 2  3   ENSG00000114650 47477125 46413681 50320000
# 3  3   ENSG00000114650 47477125 46413681 50320000
# 4  3   ENSG00000114650 47477125 46413681 50320000
# 5  3   ENSG00000114650 47477125 46413681 50320000
# 6  3   ENSG00000114650 47477125 46413681 50320000
# 7  3   ENSG00000114650 47477125 46413681 50320000
# 8  3   ENSG00000114650 47477125 46413681 50320000
# 9  3   ENSG00000114650 47477125 46413681 50320000
# 10 3   ENSG00000114650 47477125 46413681 50320000
# 11 3   ENSG00000114650 47477125 46413681 50320000
# 12 3   ENSG00000114650 47477125 46413681 50320000
# 13 3   ENSG00000114650 47477125 46413681 50320000
# 14 3   ENSG00000114650 47477125 46413681 50320000
#    context
# 1  Exc_mega_eQTL
# 2  Exc_mega_eQTL
# 3  Exc_mega_eQTL
# 4  Exc_mega_eQTL
# 5  Inh_mega_eQTL
# 6  Inh_mega_eQTL
# 7  Inh_mega_eQTL
# 8  Inh_mega_eQTL
# ...

# %%
# CDC12
CDC12 = Aging5_twas |> filter(molecular_id == "ENSG00000160799")
CDC12
# Out:
#   chr molecular_id    TSS      start    end
# 1 3   ENSG00000160799 46982009 44920000 50320000
# 2 3   ENSG00000160799 46982009 44920000 50320000
# 3 3   ENSG00000160799 46982009 44920000 50320000
# 4 3   ENSG00000160799 46982009 44920000 50320000
#   context
# 1 ROSMAP_PCC_sQTL_chr3:46941065:46976636:clu_27386_-:PR:ENSG00000160799
# 2 ROSMAP_PCC_sQTL_chr3:46941065:46976636:clu_27386_-:PR:ENSG00000160799
# 3 ROSMAP_PCC_sQTL_chr3:46941065:46976636:clu_27386_-:PR:ENSG00000160799
# 4 ROSMAP_PCC_sQTL_chr3:46941065:46976636:clu_27386_-:PR:ENSG00000160799
#   gwas_study   method is_imputable is_selected_method rsq_cv      pval_cv
# 1 image_Aging5 enet   TRUE         FALSE              0.010140000 0.018497623
# 2 image_Aging5 lasso  TRUE         FALSE              0.002658053 0.139255311
# 3 image_Aging5 mrash  TRUE          TRUE              0.018159042 0.002446310
# 4 image_Aging5 susie  TRUE         FALSE              0.017563203 0.002837002
# ...

# %%
# ELP6
ELP6 = Aging5_twas |> filter(molecular_id == "ENSG00000163832")
ELP6
# Out:
#    chr molecular_id    TSS      start    end
# 1  3   ENSG00000163832 47513711 46495640 50320000
# 2  3   ENSG00000163832 47513711 46495640 50320000
# 3  3   ENSG00000163832 47513711 46495640 50320000
# 4  3   ENSG00000163832 47513711 46495640 50320000
# 5  3   ENSG00000163832 47513711 46495640 50320000
# 6  3   ENSG00000163832 47513711 46495640 50320000
# 7  3   ENSG00000163832 47513711 46495640 50320000
# 8  3   ENSG00000163832 47513711 46495640 50320000
# 9  3   ENSG00000163832 47513711 46495640 50320000
# 10 3   ENSG00000163832 47513711 46495640 50320000
# 11 3   ENSG00000163832 47513711 46495640 50320000
# 12 3   ENSG00000163832 47513711 46495640 50320000
#    context
# 1  Exc_mega_eQTL
# 2  Exc_mega_eQTL
# 3  Exc_mega_eQTL
# 4  Exc_mega_eQTL
# 5  Oli_mega_eQTL
# 6  Oli_mega_eQTL
# 7  Oli_mega_eQTL
# 8  Oli_mega_eQTL
# 9  ROSMAP_DLPFC_sQTL_chr3:47496197:47501649:clu_35083_-:PR:ENSG00000163832
# 10 ROSMAP_DLPFC_sQTL_chr3:47496197:47501649:clu_35083_-:PR:ENSG00000163832
# ...

# %% [markdown]
# ## Aging3

# %%
# KDM2B
KDM2B = Aging3_twas |> filter(molecular_id == "ENSG00000089094")
KDM2B
# Out:
#    chr molecular_id    TSS       start     end
# 1  12  ENSG00000089094 121581022 120080000 124040000
# 2  12  ENSG00000089094 121581022 120080000 124040000
# 3  12  ENSG00000089094 121581022 120080000 124040000
# 4  12  ENSG00000089094 121581022 120080000 124040000
# 5  12  ENSG00000089094 121581022 120080000 124040000
# 6  12  ENSG00000089094 121581022 120080000 124040000
# 7  12  ENSG00000089094 121581022 120080000 124040000
# 8  12  ENSG00000089094 121581022 120080000 124040000
# 9  12  ENSG00000089094 121581022 120080000 124040000
# 10 12  ENSG00000089094 121581022 120080000 124040000
# 11 12  ENSG00000089094 121581022 120080000 124040000
# 12 12  ENSG00000089094 121581022 120080000 124040000
# 13 12  ENSG00000089094 121581022 120080000 124040000
# 14 12  ENSG00000089094 121581022 120080000 124040000
# 15 12  ENSG00000089094 121581022 120080000 124040000
# 16 12  ENSG00000089094 121581022 120080000 124040000
#    context
# 1  Exc_mega_eQTL
# 2  Exc_mega_eQTL
# 3  Exc_mega_eQTL
# ...

# %%
# ARMH4
ARMH4 = Aging3_twas |> filter(molecular_id == "ENSG00000139971", twas_pval < 6.25*1e-5)
ARMH4
# Out:
#   chr molecular_id    TSS      start    end
# 1 14  ENSG00000139971 58298138 56480000 60600000
# 2 14  ENSG00000139971 58298138 56480000 60600000
# 3 14  ENSG00000139971 58298138 56480000 60600000
# 4 14  ENSG00000139971 58298138 56480000 60600000
# 5 14  ENSG00000139971 58298138 56480000 60600000
#   context
# 1 ROSMAP_DLPFC_sQTL_chr14:58257998:58260947:clu_119034_+:PR:ENSG00000139971
# 2 ROSMAP_DLPFC_sQTL_chr14:58257998:58260947:clu_119034_+:PR:ENSG00000139971
# 3 ROSMAP_PCC_sQTL_chr14:58004804:58005047:clu_93941_-:PR:ENSG00000139971
# 4 ROSMAP_PCC_sQTL_chr14:58004804:58005047:clu_93941_-:PR:ENSG00000139971
# 5 ROSMAP_PCC_sQTL_chr14:58096981:58131511:clu_93943_-:PR:ENSG00000139971
#   gwas_study   method is_imputable is_selected_method rsq_cv      pval_cv
# 1 image_Aging3 mrash  TRUE         FALSE              0.007217633 9.018500e-03
# 2 image_Aging3 susie  TRUE          TRUE              0.010919757 1.725261e-03
# ...

# %%
# PSMA3
PSMA3 = Aging3_twas |> filter(molecular_id == "ENSG00000100567")
PSMA3
# Out:
#      chr molecular_id TSS start end context gwas_study method is_imputable
#      is_selected_method rsq_cv pval_cv twas_z twas_pval type block

# %%
# UGT2B7
UGT2B7 = Aging3_twas |> filter(molecular_id == "ENSG00000171234")
UGT2B7
# Out:
#      chr molecular_id TSS start end context gwas_study method is_imputable
#      is_selected_method rsq_cv pval_cv twas_z twas_pval type block

# %% [markdown]
# ## AD1

# %%
# AMZ1

# %%
AMZ1 = AD1_twas |> filter(molecular_id == "ENSG00000174945", twas_pval < 6.25*1e-4)
AMZ1
# Out:
#   chr molecular_id    TSS     start end   context       gwas_study method
# 1 7   ENSG00000174945 2679521 0     6e+06 OPC_mega_eQTL image_AD1  enet
# 2 7   ENSG00000174945 2679521 0     6e+06 OPC_mega_eQTL image_AD1  lasso
# 3 7   ENSG00000174945 2679521 0     6e+06 OPC_mega_eQTL image_AD1  mrash
# 4 7   ENSG00000174945 2679521 0     6e+06 OPC_mega_eQTL image_AD1  susie
#   is_imputable is_selected_method rsq_cv    pval_cv      twas_z   twas_pval
# 1 TRUE         FALSE              0.2138682 1.918706e-40 3.590554 3.299753e-04
# 2 TRUE         FALSE              0.2110487 7.172641e-40 3.425761 6.130801e-04
# 3 TRUE         FALSE              0.2409880 4.673226e-46 3.761392 1.689704e-04
# 4 TRUE          TRUE              0.2462630 3.588661e-47 4.146954 3.369276e-05
#   type block
# 1 eQTL chr7_2640020_3986377
# 2 eQTL chr7_2640020_3986377
# 3 eQTL chr7_2640020_3986377
# 4 eQTL chr7_2640020_3986377

# %%
# NBEAL2

# %%
NBEAL2 = AD1_twas |> filter(molecular_id == "ENSG00000160796", twas_pval < 6.25*1e-6)
NBEAL2
# Out:
#    chr molecular_id    TSS      start    end
# 1  3   ENSG00000160796 46979665 44920000 50320000
# 2  3   ENSG00000160796 46979665 44920000 50320000
# 3  3   ENSG00000160796 46979665 44920000 50320000
# 4  3   ENSG00000160796 46979665 44920000 50320000
# 5  3   ENSG00000160796 46979665 44920000 50320000
# 6  3   ENSG00000160796 46979665 44920000 50320000
# 7  3   ENSG00000160796 46979665 44920000 50320000
# 8  3   ENSG00000160796 46979665 44920000 50320000
# 9  3   ENSG00000160796 46979665 44920000 50320000
# 10 3   ENSG00000160796 46979665 44920000 50320000
# 11 3   ENSG00000160796 46979665 44920000 50320000
#    context
# 1  ROSMAP_AC_sQTL_chr3:46991946:46993936:clu_26458_+:PR:ENSG00000160796
# 2  ROSMAP_AC_sQTL_chr3:46991946:46993936:clu_26458_+:PR:ENSG00000160796
# 3  ROSMAP_AC_sQTL_chr3:46991946:46993936:clu_26458_+:PR:ENSG00000160796
# 4  ROSMAP_AC_sQTL_chr3:46991946:46993936:clu_26458_+:PR:ENSG00000160796
# ...

# %%
# GNA12

# %%
GNA12 = AD1_twas |> filter(molecular_id == "ENSG00000146535")
GNA12
# Out:
#    chr molecular_id    TSS     start end
# 1  7   ENSG00000146535 2844307 0     6e+06
# 2  7   ENSG00000146535 2844307 0     6e+06
# 3  7   ENSG00000146535 2844307 0     6e+06
# 4  7   ENSG00000146535 2844307 0     6e+06
# 5  7   ENSG00000146535 2844307 0     6e+06
# 6  7   ENSG00000146535 2844307 0     6e+06
# 7  7   ENSG00000146535 2844307 0     6e+06
# 8  7   ENSG00000146535 2844307 0     6e+06
# 9  7   ENSG00000146535 2844307 0     6e+06
# 10 7   ENSG00000146535 2844307 0     6e+06
# 11 7   ENSG00000146535 2844307 0     6e+06
# 12 7   ENSG00000146535 2844307 0     6e+06
# 13 7   ENSG00000146535 2844307 0     6e+06
# 14 7   ENSG00000146535 2844307 0     6e+06
# 15 7   ENSG00000146535 2844307 0     6e+06
# 16 7   ENSG00000146535 2844307 0     6e+06
# 17 7   ENSG00000146535 2844307 0     6e+06
# 18 7   ENSG00000146535 2844307 0     6e+06
# 19 7   ENSG00000146535 2844307 0     6e+06
# 20 7   ENSG00000146535 2844307 0     6e+06
# 21 7   ENSG00000146535 2844307 0     6e+06
# ...

# %%
# SCAP

# %%
SCAP = AD1_twas |> filter(molecular_id == "ENSG00000114650", twas_pval < 6.25*1e-6)
SCAP
# Out:
#   chr molecular_id    TSS      start    end
# 1 3   ENSG00000114650 47477125 46413681 50320000
# 2 3   ENSG00000114650 47477125 46413681 50320000
# 3 3   ENSG00000114650 47477125 46413681 50320000
# 4 3   ENSG00000114650 47477125 46413681 50320000
# 5 3   ENSG00000114650 47477125 46413681 50320000
# 6 3   ENSG00000114650 47477125 46413681 50320000
# 7 3   ENSG00000114650 47477125 46413681 50320000
# 8 3   ENSG00000114650 47477125 46413681 50320000
# 9 3   ENSG00000114650 47477125 46413681 50320000
#   context
# 1 Exc_mega_eQTL
# 2 Exc_mega_eQTL
# 3 Exc_mega_eQTL
# 4 Exc_mega_eQTL
# 5 Inh_mega_eQTL
# 6 Inh_mega_eQTL
# 7 Inh_mega_eQTL
# 8 Inh_mega_eQTL
# 9 ROSMAP_DLPFC_sQTL_chr3:47417207:47418320:clu_35077_-:PR:ENSG00000114650
#   gwas_study method is_imputable is_selected_method rsq_cv     pval_cv
# 1 image_AD1  enet   TRUE         FALSE              0.01882848 1.098126e-04
# 2 image_AD1  lasso  TRUE         FALSE              0.01731153 2.006136e-04
# ...

# %%
# CDC12
CDC12 = AD1_twas |> filter(molecular_id == "ENSG00000160799")
CDC12
# Out:
#   chr molecular_id    TSS      start    end
# 1 3   ENSG00000160799 46982009 44920000 50320000
# 2 3   ENSG00000160799 46982009 44920000 50320000
# 3 3   ENSG00000160799 46982009 44920000 50320000
# 4 3   ENSG00000160799 46982009 44920000 50320000
#   context
# 1 ROSMAP_PCC_sQTL_chr3:46941065:46976636:clu_27386_-:PR:ENSG00000160799
# 2 ROSMAP_PCC_sQTL_chr3:46941065:46976636:clu_27386_-:PR:ENSG00000160799
# 3 ROSMAP_PCC_sQTL_chr3:46941065:46976636:clu_27386_-:PR:ENSG00000160799
# 4 ROSMAP_PCC_sQTL_chr3:46941065:46976636:clu_27386_-:PR:ENSG00000160799
#   gwas_study method is_imputable is_selected_method rsq_cv      pval_cv
# 1 image_AD1  enet   TRUE         FALSE              0.010140000 0.018497623
# 2 image_AD1  lasso  TRUE         FALSE              0.002658053 0.139255311
# 3 image_AD1  mrash  TRUE          TRUE              0.018159042 0.002446310
# 4 image_AD1  susie  TRUE         FALSE              0.017563203 0.002837002
#   twas_z     twas_pval type            block
# ...

# %%
# ELP6
ELP6 = AD1_twas |> filter(molecular_id == "ENSG00000163832")
ELP6
# Out:
#    chr molecular_id    TSS      start    end
# 1  3   ENSG00000163832 47513711 46495640 50320000
# 2  3   ENSG00000163832 47513711 46495640 50320000
# 3  3   ENSG00000163832 47513711 46495640 50320000
# 4  3   ENSG00000163832 47513711 46495640 50320000
# 5  3   ENSG00000163832 47513711 46495640 50320000
# 6  3   ENSG00000163832 47513711 46495640 50320000
# 7  3   ENSG00000163832 47513711 46495640 50320000
# 8  3   ENSG00000163832 47513711 46495640 50320000
# 9  3   ENSG00000163832 47513711 46495640 50320000
# 10 3   ENSG00000163832 47513711 46495640 50320000
# 11 3   ENSG00000163832 47513711 46495640 50320000
# 12 3   ENSG00000163832 47513711 46495640 50320000
#    context
# 1  Exc_mega_eQTL
# 2  Exc_mega_eQTL
# 3  Exc_mega_eQTL
# 4  Exc_mega_eQTL
# 5  Oli_mega_eQTL
# 6  Oli_mega_eQTL
# 7  Oli_mega_eQTL
# 8  Oli_mega_eQTL
# 9  ROSMAP_DLPFC_sQTL_chr3:47496197:47501649:clu_35083_-:PR:ENSG00000163832
# 10 ROSMAP_DLPFC_sQTL_chr3:47496197:47501649:clu_35083_-:PR:ENSG00000163832
# ...

# %%
# KDM2B
KDM2B = AD1_twas |> filter(molecular_id == "ENSG00000089094")
KDM2B
# Out:
#    chr molecular_id    TSS       start     end
# 1  12  ENSG00000089094 121581022 120080000 124040000
# 2  12  ENSG00000089094 121581022 120080000 124040000
# 3  12  ENSG00000089094 121581022 120080000 124040000
# 4  12  ENSG00000089094 121581022 120080000 124040000
# 5  12  ENSG00000089094 121581022 120080000 124040000
# 6  12  ENSG00000089094 121581022 120080000 124040000
# 7  12  ENSG00000089094 121581022 120080000 124040000
# 8  12  ENSG00000089094 121581022 120080000 124040000
# 9  12  ENSG00000089094 121581022 120080000 124040000
# 10 12  ENSG00000089094 121581022 120080000 124040000
# 11 12  ENSG00000089094 121581022 120080000 124040000
# 12 12  ENSG00000089094 121581022 120080000 124040000
# 13 12  ENSG00000089094 121581022 120080000 124040000
# 14 12  ENSG00000089094 121581022 120080000 124040000
# 15 12  ENSG00000089094 121581022 120080000 124040000
# 16 12  ENSG00000089094 121581022 120080000 124040000
#    context
# 1  Exc_mega_eQTL
# 2  Exc_mega_eQTL
# 3  Exc_mega_eQTL
# ...

# %%
# ARMH4
ARMH4 = AD1_twas |> filter(molecular_id == "ENSG00000139971", twas_pval < 6.25*1e-6)
ARMH4
# Out:
#   chr molecular_id    TSS      start    end
# 1 14  ENSG00000139971 58298138 56480000 60600000
# 2 14  ENSG00000139971 58298138 56480000 60600000
# 3 14  ENSG00000139971 58298138 56480000 60600000
# 4 14  ENSG00000139971 58298138 56480000 60600000
#   context
# 1 ROSMAP_DLPFC_sQTL_chr14:58257998:58260947:clu_119034_+:PR:ENSG00000139971
# 2 ROSMAP_PCC_sQTL_chr14:58004804:58005047:clu_93941_-:PR:ENSG00000139971
# 3 ROSMAP_PCC_sQTL_chr14:58004804:58005047:clu_93941_-:PR:ENSG00000139971
# 4 ROSMAP_PCC_sQTL_chr14:58096981:58131511:clu_93943_-:PR:ENSG00000139971
#   gwas_study method is_imputable is_selected_method rsq_cv      pval_cv
# 1 image_AD1  mrash  TRUE         FALSE              0.007217633 9.018500e-03
# 2 image_AD1  mrash  TRUE         FALSE              0.003029548 1.250811e-01
# 3 image_AD1  susie  TRUE          TRUE              0.014577070 5.986542e-03
# 4 image_AD1  mrash  TRUE         FALSE              0.045814041 2.817113e-06
# ...

# %%
# PSMA3
PSMA3 = AD1_twas |> filter(molecular_id == "ENSG00000100567", twas_pval < 6.25*1e-6)
PSMA3
# Out:
#   chr molecular_id    TSS      start    end      context       gwas_study
# 1 14  ENSG00000100567 58244842 56480000 60600000 Exc_mega_eQTL image_AD1
# 2 14  ENSG00000100567 58244842 56480000 60600000 Exc_mega_eQTL image_AD1
# 3 14  ENSG00000100567 58244842 56480000 60600000 Exc_mega_eQTL image_AD1
# 4 14  ENSG00000100567 58244842 56480000 60600000 Exc_mega_eQTL image_AD1
# 5 14  ENSG00000100567 58244842 56480000 60600000 Inh_mega_eQTL image_AD1
# 6 14  ENSG00000100567 58244842 56480000 60600000 Inh_mega_eQTL image_AD1
# 7 14  ENSG00000100567 58244842 56480000 60600000 Inh_mega_eQTL image_AD1
# 8 14  ENSG00000100567 58244842 56480000 60600000 Inh_mega_eQTL image_AD1
#   method is_imputable is_selected_method rsq_cv       pval_cv      twas_z
# 1 enet   TRUE         FALSE              0.0066320705 0.0152606416 -5.667700
# 2 lasso  TRUE         FALSE              0.0061746119 0.0185022789 -5.441194
# 3 mrash  TRUE         FALSE              0.0070688922 0.0127089172 -4.583461
# ...

# %%
# UGT2B7 chr4
UGT2B7 = AD1_twas |> filter(molecular_id == "ENSG00000171234")
UGT2B7
# Out:
#      chr molecular_id TSS start end context gwas_study method is_imputable
#      is_selected_method rsq_cv pval_cv twas_z twas_pval type block
