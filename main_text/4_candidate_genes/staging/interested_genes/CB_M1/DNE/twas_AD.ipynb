# %%
library(tidyverse)
library(data.table)

# %%
AD_twas = fread("/home/ubuntu/data/analysis_result/twas/export/summary/FunGen_twas.exported.bed.gz")

# %% [markdown]
# ## AD_image_Aging5

# %%
ICA1L = AD_twas |> filter(molecular_id == "ENSG00000163596", twas_pval < 6.25*1e-6)
ICA1L
# Out:
#     #chr start     end       molecular_id    TADB_start TADB_end
# 1   2    202871764 202871765 ENSG00000163596 201773150  203960000
# 2   2    202871764 202871765 ENSG00000163596 201773150  203960000
# 3   2    202871764 202871765 ENSG00000163596 201773150  203960000
# 4   2    202871764 202871765 ENSG00000163596 201773150  203960000
# 5   2    202871764 202871765 ENSG00000163596 201773150  203960000
# 6   2    202871764 202871765 ENSG00000163596 201773150  203960000
# 7   2    202871764 202871765 ENSG00000163596 201773150  203960000
# 8   2    202871764 202871765 ENSG00000163596 201773150  203960000
# 9   2    202871764 202871765 ENSG00000163596 201773150  203960000
# 10  2    202871764 202871765 ENSG00000163596 201773150  203960000
# 11  2    202871764 202871765 ENSG00000163596 201773150  203960000
# 12  2    202871764 202871765 ENSG00000163596 201773150  203960000
# 13  2    202871764 202871765 ENSG00000163596 201773150  203960000
# ...

# %%
WDR12 = AD_twas |> filter(molecular_id == "ENSG00000138442", twas_pval < 6.25*1e-6)
WDR12
# Out:
#    #chr start     end       molecular_id    TADB_start TADB_end
# 1  2    203014796 203014797 ENSG00000138442 201874261  204014798
# 2  2    203014796 203014797 ENSG00000138442 201874261  204014798
# 3  2    203014796 203014797 ENSG00000138442 201874261  204014798
# 4  2    203014796 203014797 ENSG00000138442 201874261  204014798
# 5  2    203014796 203014797 ENSG00000138442 201874261  204014798
# 6  2    203014796 203014797 ENSG00000138442 201874261  204014798
# 7  2    203014796 203014797 ENSG00000138442 201874261  204014798
# 8  2    203014796 203014797 ENSG00000138442 201874261  204014798
# 9  2    203014796 203014797 ENSG00000138442 201874261  204014798
# 10 2    203014796 203014797 ENSG00000138442 201874261  204014798
# 11 2    203014796 203014797 ENSG00000138442 201874261  204014798
# 12 2    203014796 203014797 ENSG00000138442 201874261  204014798
#    context
# 1  Exc_DeJager_eQTL
# 2  Exc_DeJager_eQTL
# 3  Exc_mega_eQTL
# 4  PCC_DeJager_eQTL
# 5  PCC_DeJager_eQTL
# ...

# %%
CARF = AD_twas |> filter(molecular_id == "ENSG00000138380", twas_pval < 6.25*1e-6)
CARF
# Out:
#    #chr start     end       molecular_id    TADB_start TADB_end
# 1  2    202912212 202912213 ENSG00000138380 201912213  203988263
# 2  2    202912212 202912213 ENSG00000138380 201912213  203988263
# 3  2    202912212 202912213 ENSG00000138380 201912213  203988263
# 4  2    202912212 202912213 ENSG00000138380 201912213  203988263
# 5  2    202912212 202912213 ENSG00000138380 201912213  203988263
# 6  2    202912212 202912213 ENSG00000138380 201912213  203988263
# 7  2    202912212 202912213 ENSG00000138380 201912213  203988263
# 8  2    202912212 202912213 ENSG00000138380 201912213  203988263
# 9  2    202912212 202912213 ENSG00000138380 201912213  203988263
# 10 2    202912212 202912213 ENSG00000138380 201912213  203988263
# 11 2    202912212 202912213 ENSG00000138380 201912213  203988263
# 12 2    202912212 202912213 ENSG00000138380 201912213  203988263
# 13 2    202912212 202912213 ENSG00000138380 201912213  203988263
# ...

# %%
NBEAL1 = AD_twas |> filter(molecular_id == "ENSG00000144426", twas_pval < 6.25*1e-6)
NBEAL1
# Out:
#    #chr start     end       molecular_id    TADB_start TADB_end
# 1  2    203014877 203014878 ENSG00000144426 202014878  204226378
# 2  2    203014877 203014878 ENSG00000144426 202014878  204226378
# 3  2    203014877 203014878 ENSG00000144426 202014878  204226378
# 4  2    203014877 203014878 ENSG00000144426 202014878  204226378
# 5  2    203014877 203014878 ENSG00000144426 202014878  204226378
# 6  2    203014877 203014878 ENSG00000144426 202014878  204226378
# 7  2    203014877 203014878 ENSG00000144426 202014878  204226378
# 8  2    203014877 203014878 ENSG00000144426 202014878  204226378
# 9  2    203014877 203014878 ENSG00000144426 202014878  204226378
# 10 2    203014877 203014878 ENSG00000144426 202014878  204226378
# 11 2    203014877 203014878 ENSG00000144426 202014878  204226378
# 12 2    203014877 203014878 ENSG00000144426 202014878  204226378
# 13 2    203014877 203014878 ENSG00000144426 202014878  204226378
# ...

# %%
# AMZ1 no sig

# %%
AMZ1 = AD_twas |> filter(molecular_id == "ENSG00000174945", twas_pval < 6.25*1e-4)
AMZ1
# Out:
#   #chr start   end     molecular_id    TADB_start TADB_end
# 1 7    2679520 2679521 ENSG00000174945 0          6000000
# 2 7    2679520 2679521 ENSG00000174945 0          6000000
#   context
# 1 Oli_mega_eQTL
# 2 ROSMAP_AC_sQTL_chr7:2700755:2702721:clu_54405_+:PR:ENSG00000174945
#   gwas_study                           method is_imputable is_selected_method
# 1 Jansen_2021                          mrash  TRUE         TRUE
# 2 Wightman_ExcludingUKBand23andME_2021 mrash  TRUE         TRUE
#   rsq_cv     pval_cv      twas_z    twas_pval    type
# 1 0.32168313 3.528363e-64  3.440443 0.0005807623 eQTL
# 2 0.02383174 8.326753e-05 -3.508767 0.0004501891 productive_sQTL
#   block
# 1 chr7_2640020_3986377
# 2 chr7_2640020_3986377

# %%
# NBEAL2 nosig

# %%
NBEAL2 = AD_twas |> filter(molecular_id == "ENSG00000160796", twas_pval < 6.25*1e-3)
NBEAL2
# Out:
#    #chr start    end      molecular_id    TADB_start TADB_end
# 1  3    46979664 46979665 ENSG00000160796 44920000   50320000
# 2  3    46979664 46979665 ENSG00000160796 44920000   50320000
# 3  3    46979664 46979665 ENSG00000160796 44920000   50320000
# 4  3    46979664 46979665 ENSG00000160796 44920000   50320000
# 5  3    46979664 46979665 ENSG00000160796 44920000   50320000
# 6  3    46979664 46979665 ENSG00000160796 44920000   50320000
# 7  3    46979664 46979665 ENSG00000160796 44920000   50320000
# 8  3    46979664 46979665 ENSG00000160796 44920000   50320000
# 9  3    46979664 46979665 ENSG00000160796 44920000   50320000
# 10 3    46979664 46979665 ENSG00000160796 44920000   50320000
# 11 3    46979664 46979665 ENSG00000160796 44920000   50320000
# 12 3    46979664 46979665 ENSG00000160796 44920000   50320000
# 13 3    46979664 46979665 ENSG00000160796 44920000   50320000
# 14 3    46979664 46979665 ENSG00000160796 44920000   50320000
# ...

# %%
# GNA12 nosig

# %%
GNA12 = AD_twas |> filter(molecular_id == "ENSG00000146535", twas_pval < 6.25*1e-3)
GNA12
# Out:
#    #chr start   end     molecular_id    TADB_start TADB_end
# 1  7    2844306 2844307 ENSG00000146535 0          6000000
# 2  7    2844306 2844307 ENSG00000146535 0          6000000
# 3  7    2844306 2844307 ENSG00000146535 0          6000000
# 4  7    2844306 2844307 ENSG00000146535 0          6000000
# 5  7    2844306 2844307 ENSG00000146535 0          6000000
# 6  7    2844306 2844307 ENSG00000146535 0          6000000
# 7  7    2844306 2844307 ENSG00000146535 0          6000000
# 8  7    2844306 2844307 ENSG00000146535 0          6000000
# 9  7    2844306 2844307 ENSG00000146535 0          6000000
# 10 7    2844306 2844307 ENSG00000146535 0          6000000
# 11 7    2844306 2844307 ENSG00000146535 0          6000000
# 12 7    2844306 2844307 ENSG00000146535 0          6000000
# 13 7    2844306 2844307 ENSG00000146535 0          6000000
# 14 7    2844306 2844307 ENSG00000146535 0          6000000
#    context              gwas_study                     method  is_imputable
# ...

# %%
# SCAP not relevant with image_AD1

# %%
SCAP = AD_twas |> filter(molecular_id == "ENSG00000114650", twas_pval < 6.25*1e-6)
SCAP
# Out:
#   #chr start    end      molecular_id    TADB_start TADB_end
# 1 3    47477124 47477125 ENSG00000114650 46413681   50320000
#   context
# 1 ROSMAP_PCC_sQTL_chr3:47428670:47442871:clu_27408_-:UP:ENSG00000114650
#   gwas_study  method is_imputable is_selected_method rsq_cv     pval_cv
# 1 Jansen_2021 mrash  TRUE         FALSE              0.01003002 0.01902964
#   twas_z    twas_pval    type              block
# 1 -4.717759 2.384566e-06 unproductive_sQTL chr3_45108216_47545024

# %%
# CDC12
CDC12 = AD_twas |> filter(molecular_id == "ENSG00000160799", twas_pval < 6.25*1e-4)
CDC12
# Out:
#      #chr start end molecular_id TADB_start TADB_end context gwas_study method
#      is_imputable is_selected_method rsq_cv pval_cv twas_z twas_pval type block

# %%
# ELP6
ELP6 = AD_twas |> filter(molecular_id == "ENSG00000163832", twas_pval < 6.25*1e-4)
ELP6
# Out:
#      #chr start end molecular_id TADB_start TADB_end context gwas_study method
#      is_imputable is_selected_method rsq_cv pval_cv twas_z twas_pval type block

# %%
# KDM2B NOT RELEVANT
KDM2B = AD_twas |> filter(molecular_id == "ENSG00000089094", twas_pval < 6.25*1e-6)
KDM2B
# Out:
#   #chr start     end       molecular_id    TADB_start TADB_end
# 1 12   121581021 121581022 ENSG00000089094 120080000  124040000
#   context
# 1 ROSMAP_DLPFC_sQTL_chr12:121444536:121445274:clu_112348_-:PR:ENSG00000089094
#   gwas_study                     method is_imputable is_selected_method
# 1 Wightman_Excluding23andMe_2021 lasso  TRUE         FALSE
#   rsq_cv      pval_cv    twas_z   twas_pval    type
# 1 0.003420767 0.05274257 4.596652 4.293341e-06 productive_sQTL
#   block
# 1 chr12_119137214_122044856

# %%
# ARMH4 NOSIG
ARMH4 = AD_twas |> filter(molecular_id == "ENSG00000139971", twas_pval < 6.25*1e-4)
ARMH4
# Out:
#      #chr start end molecular_id TADB_start TADB_end context gwas_study method
#      is_imputable is_selected_method rsq_cv pval_cv twas_z twas_pval type block

# %%
# PSMA3
PSMA3 = AD_twas |> filter(molecular_id == "ENSG00000100567", twas_pval < 6.25*1e-4)
PSMA3
# Out:
#      #chr start end molecular_id TADB_start TADB_end context gwas_study method
#      is_imputable is_selected_method rsq_cv pval_cv twas_z twas_pval type block

# %%
# UGT2B7 chr4
UGT2B7 = AD_twas |> filter(molecular_id == "ENSG00000171234")
UGT2B7
# Out:
#      #chr start end molecular_id TADB_start TADB_end context gwas_study method
#      is_imputable is_selected_method rsq_cv pval_cv twas_z twas_pval type block
