# %%
library(tidyverse)
library(data.table)

# %%
DNE = fread("~/xqtl-analysis/production/image_QTL/analysis/pathway_enrichment_PPI/updated_image_xQTL_gene.tsv")
AD1 = DNE |> filter(str_detect(outcomes, "AD1"))
Aging5 = DNE |> filter(str_detect(outcomes, "Aging5"))
Aging3 = DNE |> filter(str_detect(outcomes, "Aging3"))

# %%
length(unique(DNE$gene_id))
# Out:
# [1] 284

# %%
AD2 = DNE |> filter(str_detect(outcomes, "AD2"))
AD2_gene = AD2 |> pull(unique(gene_name))

# %%
Aging2 = DNE |> filter(str_detect(outcomes, "Aging2"))
Aging2_gene = Aging2 |> pull(unique(gene_name))

# %%
Aging1 = DNE |> filter(str_detect(outcomes, "Aging1"))
Aging1_gene = Aging1 |> pull(unique(gene_name))
Aging4 = DNE |> filter(str_detect(outcomes, "Aging4"))
Aging4_gene = Aging4 |> pull(unique(gene_name))

# %%
AD1_gene = AD1 |> pull(unique(gene_name))

# %%
Aging5_gene = Aging5 |> pull(unique(gene_name))

# %%
Aging3_gene = Aging3 |> pull(unique(gene_name))

# %%
AD1_gene |> unique()
# Out:
#  [1] "THNSL1"   "MFSD13A"  "ACTR1A"   "SUFU"     "TRIM8"    "ARL3"
#  [7] "KDM2B"    "ARMH4"    "PSMA3"    "EEF2"     "PIAS4"    "ARL4C"
# [13] "UQCC1"    "GDF5"     "PI4KA"    "SERPIND1" "SNAP29"   "ADORA2A"
# [19] "CCDC12"   "NBEAL2"   "SCAP"     "ELP6"     "CSPG5"    "SMARCC1"
# [25] "DHX30"    "UGT2B7"   "KIF13A"   "AMZ1"     "GNA12"    "SBSPON"
# [31] "ENPP2"

# %%
AD2_gene |> unique()
# Out:
#  [1] "ERO1B"          "DPCD"           "DGKZ"           "MDK"
#  [5] "ATG13"          "C11orf49"       "PACSIN3"        "NR1H3"
#  [9] "SPI1"           "ZDHHC5"         "TMX2"           "CTNND1"
# [13] "NABP2"          "ANKRD52"        "COQ10A"         "CS"
# [17] "CNPY2"          "PAN2"           "IL23A"          "STAT2"
# [21] "SOHLH2"         "CCDC169-SOHLH2" "CCDC169"        "SPART"
# [25] "CCDC57"         "DIS3L2"         "UQCC1"          "GDF5"
# [29] "MAST4"          "AP3B1"          "VCAN"           "CYSTM1"
# [33] "APBB3"          "TNIP1"          "TMEM170B"       "FILIP1"
# [37] "CCM2"           "TBRG4"

# %%
Aging1_gene |> unique()
# Out:
#  [1] "CD101"     "ENO4"      "SHTN1"     "SAA4"      "SAA2"      "HPS5"
#  [7] "GTF2H1"    "DSCAML1"   "CNTN1"     "EIF2B2"    "MLH3"      "ACYP1"
# [13] "ZC2HC1C"   "NEK9"      "TMED10"    "NPIPA1"    "PDXDC1"    "NPIPA5"
# [19] "SLC5A11"   "NPIPB7"    "SGF29"     "SULT1A2"   "SULT1A1"   "EIF3C"
# [25] "TUFM"      "SH2B1"     "ATP2A1"    "DYNC1LI2"  "TMEM208"   "HELZ"
# [31] "ATP9B"     "BCL2L1"    "SLC2A4RG"  "DNAJC5"    "ZIC4"      "ZIC1"
# [37] "IGFBP7"    "AHRR"      "EXOC3"     "HLA-A"     "CENPW"     "TULP4"
# [43] "TMEM181"   "SOD2"      "WTAP"      "ACAT2"     "TCP1"      "MRPL18"
# [49] "PNLDC1"    "AMZ1"      "GNA12"     "STAG3"     "PILRB"     "PILRA"
# [55] "ZCWPW1"    "MEPCE"     "C7orf61"   "TSC22D4"   "FAM160B2"  "SLC20A2"
# [61] "SMIM19"    "EFCAB1"    "TNFRSF11B"

# %%
Aging2_gene |> unique()
# Out:
#  [1] "WAC"            "EEF1AKMT2"      "SYT10"          "DYRK2"
#  [5] "SOHLH2"         "CCDC169-SOHLH2" "CCDC169"        "SPART"
#  [9] "SEZ6L2"         "ASPHD1"         "KCTD13"         "TMEM219"
# [13] "DOC2A"          "GDPD3"          "MAPK3"          "CORO6"
# [17] "SSH2"           "EFCAB5"         "NSRP1"          "MTMR4"
# [21] "RAD51C"         "PPM1E"          "DOCK10"         "ARL4C"
# [25] "BCL2L1"         "MAST4"          "VCAN"           "TNIP1"
# [29] "TMEM170B"       "CENPW"          "RPA3"           "FAM126A"
# [33] "KLHL7"          "NUP42"          "GPNMB"          "SPDYE3"
# [37] "C7orf33"        "ZNF786"         "ZNF398"         "ZBTB10"
# [41] "GADD45G"

# %%
Aging3_gene |> unique()
# Out:
#  [1] "HSPG2"           "CDC42"           "ENO4"            "SHTN1"
#  [5] "KDM2B"           "IRS2"            "ARMH4"           "PSMA3"
#  [9] "ASPHD1"          "KCTD13"          "TMEM219"         "DOC2A"
# [13] "GDPD3"           "MAPK3"           "PTGES3L-AARSD1"  "ARHGAP27"
# [17] "PLEKHM1"         "LINC02210-CRHR1" "CRHR1"           "SPPL2C"
# [21] "MAPT"            "STH"             "KANSL1"          "ARL17B"
# [25] "LRRC37A"         "LRRC37A2"        "ARL17A"          "NSF"
# [29] "AC005670.2"      "SPTBN1"          "ITCH"            "MAP1LC3A"
# [33] "NCOA6"           "GGT7"            "SLC2A4RG"        "DNAJC5"
# [37] "HSF2BP"          "RRP1B"           "PDXK"            "GTPBP1"
# [41] "UGT2B7"          "CENPW"           "ISCA1"           "TUT7"

# %%
Aging4_gene |> unique()
# Out:
#  [1] "GLRX2"          "CDC73"          "RAB29"          "SLC41A1"
#  [5] "PM20D1"         "SLC26A9"        "RAB7B"          "CTSE"
#  [9] "RHEX"           "ERO1B"          "TCF7L2"         "SLC36A4"
# [13] "NABP2"          "ANKRD52"        "COQ10A"         "CS"
# [17] "CNPY2"          "PAN2"           "IL23A"          "STAT2"
# [21] "BPTF"           "KPNA2"          "TPGS2"          "KIAA1328"
# [25] "COX6B1"         "UPK1A"          "ZBTB32"         "KMT2B"
# [29] "PROSER3"        "COQ8B"          "DPYSL5"         "MAPRE3"
# [33] "TMEM214"        "EMILIN1"        "KHK"            "CGREF1"
# [37] "GFM1"           "AP3B1"          "BMP6"           "TXNDC5"
# [41] "BLOC1S5-TXNDC5" "SUPT3H"         "AMZ1"           "GNA12"
# [45] "SLC20A2"        "SMIM19"         "ENPP2"

# %%
Aging5_gene |> unique()
# Out:
#  [1] "EIF4G3"   "CNTN2"    "TMEM81"   "RBBP5"    "DSTYK"    "TMCC2"
#  [7] "NUAK2"    "SYNPO2L"  "VCL"      "ADK"      "WBP1L"    "AS3MT"
# [13] "CNNM2"    "AKIP1"    "TMEM9B"   "TLCD5"    "ARHGEF12" "RHBDF1"
# [19] "FOXF1"    "VPS9D1"   "EFCAB13"  "LRRC46"   "TTLL6"    "CALCOCO2"
# [25] "ATP5MC1"  "UBE2Z"    "SNF8"     "ABI3"     "SEPTIN9"  "CCDC9"
# [31] "C5AR1"    "RGPD4"    "SULT1C4"  "GCC2"     "LIMS1"    "RANBP2"
# [37] "ICA1L"    "WDR12"    "CARF"     "NBEAL1"   "PLCG1"    "ZHX3"
# [43] "FAM118A"  "RIBC2"    "NUP210"   "NR2C2"    "RARB"     "CCDC12"
# [49] "NBEAL2"   "SCAP"     "ELP6"     "STIMATE"  "EPHA3"    "BTN2A1"
# [55] "ZKSCAN8"  "TRIM31"   "GPANK1"   "VWA7"     "C4A"      "C4B"
# [61] "CYP21A2"  "HLA-DQA1" "HLA-DMB"  "HLA-DMA"  "BRD2"     "FUT9"
# [67] "UFL1"     "FHL5"     "CENPW"    "AMZ1"     "GNA12"    "UMAD1"

# %%
Aging = fread("~/xqtl-analysis/production/image_QTL/interested_genes/CB_M1/Aging_DNE/annotated_aging_new_dne_gene.tsv")
Aging_gene = Aging |> pull(unique(gene_name))

# %%
library(VennDiagram)

# Create the Venn diagram
venn.plot <- venn.diagram(
  x = list(
    AD1 = AD1_gene,
    Aging5 = Aging5_gene,
    Aging = Aging_gene
  ),
  filename = NULL,  # Set to NULL to display in R, or provide filename to save
  category.names = c("AD1 genes", "Aging5 genes", "Aging genes"),
  
  # Customize colors
  fill = c("lightblue", "lightcoral", "lightgreen"),
  alpha = 0.7,
  
  # Customize text
  cex = 1.2,
  fontfamily = "sans",
  
  # Remove log file
  disable.logging = TRUE
)

# Display the plot
grid.draw(venn.plot)
# Out:
# Loading required package: grid
#
# Loading required package: futile.logger
# INFO [2025-07-09 23:22:46] $x
# INFO [2025-07-09 23:22:46] list(AD1 = AD1_gene, Aging5 = Aging5_gene, Aging = Aging_gene)
# INFO [2025-07-09 23:22:46]
# INFO [2025-07-09 23:22:46] $filename
# INFO [2025-07-09 23:22:46] NULL
# INFO [2025-07-09 23:22:46]
# INFO [2025-07-09 23:22:46] $category.names
# INFO [2025-07-09 23:22:46] c("AD1 genes", "Aging5 genes", "Aging genes")
# INFO [2025-07-09 23:22:46]
# INFO [2025-07-09 23:22:46] $fill
# INFO [2025-07-09 23:22:46] c("lightblue", "lightcoral", "lightgreen")
# INFO [2025-07-09 23:22:46]
# INFO [2025-07-09 23:22:46] $alpha
# INFO [2025-07-09 23:22:46] [1] 0.7
# INFO [2025-07-09 23:22:46]
# INFO [2025-07-09 23:22:46] $cex
# INFO [2025-07-09 23:22:46] [1] 1.2
# INFO [2025-07-09 23:22:46]
# INFO [2025-07-09 23:22:46] $fontfamily
# INFO [2025-07-09 23:22:46] [1] "sans"
# INFO [2025-07-09 23:22:46]
# INFO [2025-07-09 23:22:46] $disable.logging
# INFO [2025-07-09 23:22:46] [1] TRUE
# INFO [2025-07-09 23:22:46]
# plot without title

# %%
library(VennDiagram)

# Create the Venn diagram
venn.plot <- venn.diagram(
  x = list(
    AD1 = unique(AD1_gene),
    Aging5 = unique(Aging5_gene),
    Aging3 = unique(Aging3_gene)
  ),
  filename = NULL,  # Set to NULL to display in R, or provide filename to save
  category.names = c("AD1 genes", "Aging5 genes", "Aging3 genes"),
  
  # Customize colors
  fill = c("lightblue", "lightcoral", "lightgreen"),
  alpha = 0.7,
  
  # Customize text
  cex = 1.2,
  fontfamily = "sans",
  
  # Remove log file
  disable.logging = TRUE
)

# Display the plot
grid.draw(venn.plot)
# Out:
# INFO [2025-07-17 20:48:23] $x
# INFO [2025-07-17 20:48:23] list(AD1 = unique(AD1_gene), Aging5 = unique(Aging5_gene), Aging3 = unique(Aging3_gene))
# INFO [2025-07-17 20:48:23]
# INFO [2025-07-17 20:48:23] $filename
# INFO [2025-07-17 20:48:23] NULL
# INFO [2025-07-17 20:48:23]
# INFO [2025-07-17 20:48:23] $category.names
# INFO [2025-07-17 20:48:23] c("AD1 genes", "Aging5 genes", "Aging3 genes")
# INFO [2025-07-17 20:48:23]
# INFO [2025-07-17 20:48:23] $fill
# INFO [2025-07-17 20:48:23] c("lightblue", "lightcoral", "lightgreen")
# INFO [2025-07-17 20:48:23]
# INFO [2025-07-17 20:48:23] $alpha
# INFO [2025-07-17 20:48:23] [1] 0.7
# INFO [2025-07-17 20:48:23]
# INFO [2025-07-17 20:48:23] $cex
# INFO [2025-07-17 20:48:23] [1] 1.2
# INFO [2025-07-17 20:48:23]
# INFO [2025-07-17 20:48:23] $fontfamily
# INFO [2025-07-17 20:48:23] [1] "sans"
# INFO [2025-07-17 20:48:23]
# INFO [2025-07-17 20:48:23] $disable.logging
# INFO [2025-07-17 20:48:23] [1] TRUE
# INFO [2025-07-17 20:48:23]
# plot without title

# %%
library(VennDiagram)

# Create the Venn diagram
venn.plot <- venn.diagram(
  x = list(
    AD2 = unique(AD2_gene),
    Aging1 = unique(Aging1_gene),
    Aging4 = unique(Aging4_gene),
    Aging2 = unique(Aging2_gene)
  ),
  filename = NULL,  # Set to NULL to display in R, or provide filename to save
  category.names = c("AD2 genes", "Aging1 genes", "Aging4 genes", "Aging2 genes"),
  
  # Customize colors
  fill = c("lightblue", "lightcoral", "lightgreen", "lightyellow"),
  alpha = 0.7,
  
  # Customize text
  cex = 1.2,
  fontfamily = "sans",
  
  # Remove log file
  disable.logging = TRUE
)

# Display the plot
grid.draw(venn.plot)
# Out:
# INFO [2025-07-17 20:48:16] $x
# INFO [2025-07-17 20:48:16] list(AD2 = unique(AD2_gene), Aging1 = unique(Aging1_gene), Aging4 = unique(Aging4_gene),
# INFO [2025-07-17 20:48:16]     Aging2 = unique(Aging2_gene))
# INFO [2025-07-17 20:48:16]
# INFO [2025-07-17 20:48:16] $filename
# INFO [2025-07-17 20:48:16] NULL
# INFO [2025-07-17 20:48:16]
# INFO [2025-07-17 20:48:16] $category.names
# INFO [2025-07-17 20:48:16] c("AD2 genes", "Aging1 genes", "Aging4 genes", "Aging2 genes")
# INFO [2025-07-17 20:48:16]
# INFO [2025-07-17 20:48:16] $fill
# INFO [2025-07-17 20:48:16] c("lightblue", "lightcoral", "lightgreen", "lightyellow")
# INFO [2025-07-17 20:48:16]
# INFO [2025-07-17 20:48:16] $alpha
# INFO [2025-07-17 20:48:16] [1] 0.7
# INFO [2025-07-17 20:48:16]
# INFO [2025-07-17 20:48:16] $cex
# INFO [2025-07-17 20:48:16] [1] 1.2
# INFO [2025-07-17 20:48:16]
# INFO [2025-07-17 20:48:16] $fontfamily
# INFO [2025-07-17 20:48:16] [1] "sans"
# INFO [2025-07-17 20:48:16]
# INFO [2025-07-17 20:48:16] $disable.logging
# INFO [2025-07-17 20:48:16] [1] TRUE
# INFO [2025-07-17 20:48:16]
# plot without title

# %%
intersect(AD1_gene, Aging1_gene)
# Out:
# [1] "AMZ1"  "GNA12"

# %%
intersect(AD1_gene, Aging2_gene)
# Out:
# [1] "ARL4C"

# %%
intersect(AD1_gene, Aging3_gene)
# Out:
# [1] "KDM2B"  "ARMH4"  "PSMA3"  "UGT2B7"

# %%
intersect(AD1_gene, Aging4_gene)
# Out:
# [1] "AMZ1"  "GNA12" "ENPP2"

# %%
intersect(AD1_gene, Aging5_gene)
# Out:
# [1] "CCDC12" "NBEAL2" "SCAP"   "ELP6"   "AMZ1"   "GNA12"

# %%
intersect(Aging3_gene, Aging5_gene)
# Out:
# [1] "CENPW"

# %% [markdown]
# CENPV is deubiquitylated by CYLD and localizes in interphase to primary cilia where it increases the ciliary levels of acetylated α-tubulin.
# Cenpj, a protein that is required for centriole biogenesis, plays a role in regulating cilium disassembly in vivo..
# CENPW's role in cillia is less direct and well-characterized.

# %%
intersect(AD1_gene, AD2_gene)
# Out:
# [1] "UQCC1" "GDF5"

# %%
intersect(Aging1_gene, AD2_gene)
# Out:
# character(0)

# %%
intersect(Aging2_gene, AD2_gene)
# Out:
# [1] "SOHLH2"         "CCDC169-SOHLH2" "CCDC169"        "SPART"
# [5] "MAST4"          "VCAN"           "TNIP1"          "TMEM170B"

# %% [markdown]
# Loss-of-function mutations in the SPART gene cause Troyer syndrome, a recessive form of spastic paraplegia resulting in muscle weakness, short stature, and cognitive defects. SPART encodes for Spartin, a protein linked to endosomal trafficking and mitochondrial membrane potential maintenance. Here, we identified with whole exome sequencing (WES) a novel frameshift mutation in the SPART gene in 2 brothers presenting an uncharacterized developmental delay and short stature. Functional characterization in an SH-SY5Y cell model shows that this mutation is associated with increased neurite outgrowth. These cells also show a marked decrease in mitochondrial complex I (NADH dehydrogenase) activity, coupled to decreased ATP synthesis and defective mitochondrial membrane potential. The cells also presented an increase in reactive oxygen species, extracellular pyruvate, and NADH levels, consistent with impaired complex I activity. In concordance with a severe mitochondrial failure, Spartin loss also led to an altered intracellular Ca2+ homeostasis that was restored after transient expression of wild-type Spartin.

# %%
intersect(Aging3_gene, AD2_gene)
# Out:
# character(0)

# %%
intersect(Aging4_gene, AD2_gene)
# Out:
#  [1] "ERO1B"   "NABP2"   "ANKRD52" "COQ10A"  "CS"      "CNPY2"   "PAN2"
#  [8] "IL23A"   "STAT2"   "AP3B1"

# %%
intersect(Aging5_gene, AD2_gene)
# Out:
# character(0)

# %%
gene_sets
# Out:
# $AD1
#  [1] "THNSL1"   "MFSD13A"  "ACTR1A"   "SUFU"     "TRIM8"    "ARL3"
#  [7] "KDM2B"    "ARMH4"    "PSMA3"    "EEF2"     "PIAS4"    "ARL4C"
# [13] "UQCC1"    "GDF5"     "PI4KA"    "SERPIND1" "SNAP29"   "ADORA2A"
# [19] "CCDC12"   "NBEAL2"   "SCAP"     "ELP6"     "CSPG5"    "SMARCC1"
# [25] "DHX30"    "UGT2B7"   "KIF13A"   "AMZ1"     "GNA12"    "SBSPON"
# [31] "ENPP2"
#
# $AD2
#  [1] "ERO1B"          "DPCD"           "DGKZ"           "MDK"
#  [5] "ATG13"          "C11orf49"       "PACSIN3"        "NR1H3"
#  [9] "SPI1"           "ZDHHC5"         "TMX2"           "CTNND1"
# [13] "NABP2"          "ANKRD52"        "COQ10A"         "CS"
# [17] "CNPY2"          "PAN2"           "IL23A"          "STAT2"
# [21] "SOHLH2"         "CCDC169-SOHLH2" "CCDC169"        "SPART"
# [25] "CCDC57"         "DIS3L2"         "UQCC1"          "GDF5"
# [29] "MAST4"          "AP3B1"          "VCAN"           "CYSTM1"
# [33] "APBB3"          "TNIP1"          "TMEM170B"       "FILIP1"
# [37] "CCM2"           "TBRG4"
#
# $Aging1
#  [1] "CD101"     "ENO4"      "SHTN1"     "SAA4"      "SAA2"      "HPS5"
#  [7] "GTF2H1"    "DSCAML1"   "CNTN1"     "EIF2B2"    "MLH3"      "ACYP1"
# [13] "ZC2HC1C"   "NEK9"      "TMED10"    "NPIPA1"    "PDXDC1"    "NPIPA5"
# [19] "SLC5A11"   "NPIPB7"    "SGF29"     "SULT1A2"   "SULT1A1"   "EIF3C"
# [25] "TUFM"      "SH2B1"     "ATP2A1"    "DYNC1LI2"  "TMEM208"   "HELZ"
# [31] "ATP9B"     "BCL2L1"    "SLC2A4RG"  "DNAJC5"    "ZIC4"      "ZIC1"
# [37] "IGFBP7"    "AHRR"      "EXOC3"     "HLA-A"     "CENPW"     "TULP4"
# [43] "TMEM181"   "SOD2"      "WTAP"      "ACAT2"     "TCP1"      "MRPL18"
# [49] "PNLDC1"    "AMZ1"      "GNA12"     "STAG3"     "PILRB"     "PILRA"
# [55] "ZCWPW1"    "MEPCE"     "C7orf61"   "TSC22D4"   "FAM160B2"  "SLC20A2"
# [61] "SMIM19"    "EFCAB1"    "TNFRSF11B"
#
# $Aging2
#  [1] "WAC"            "EEF1AKMT2"      "SYT10"          "DYRK2"
#  [5] "SOHLH2"         "CCDC169-SOHLH2" "CCDC169"        "SPART"
#  [9] "SEZ6L2"         "ASPHD1"         "KCTD13"         "TMEM219"
# [13] "DOC2A"          "GDPD3"          "MAPK3"          "CORO6"
# [17] "SSH2"           "EFCAB5"         "NSRP1"          "MTMR4"
# [21] "RAD51C"         "PPM1E"          "DOCK10"         "ARL4C"
# [25] "BCL2L1"         "MAST4"          "VCAN"           "TNIP1"
# [29] "TMEM170B"       "CENPW"          "RPA3"           "FAM126A"
# [33] "KLHL7"          "NUP42"          "GPNMB"          "SPDYE3"
# [37] "C7orf33"        "ZNF786"         "ZNF398"         "ZBTB10"
# [41] "GADD45G"
#
# $Aging3
#  [1] "HSPG2"           "CDC42"           "ENO4"            "SHTN1"
#  [5] "KDM2B"           "IRS2"            "ARMH4"           "PSMA3"
#  [9] "ASPHD1"          "KCTD13"          "TMEM219"         "DOC2A"
# [13] "GDPD3"           "MAPK3"           "PTGES3L-AARSD1"  "ARHGAP27"
# [17] "PLEKHM1"         "LINC02210-CRHR1" "CRHR1"           "SPPL2C"
# [21] "MAPT"            "STH"             "KANSL1"          "ARL17B"
# [25] "LRRC37A"         "LRRC37A2"        "ARL17A"          "NSF"
# [29] "AC005670.2"      "SPTBN1"          "ITCH"            "MAP1LC3A"
# [33] "NCOA6"           "GGT7"            "SLC2A4RG"        "DNAJC5"
# [37] "HSF2BP"          "RRP1B"           "PDXK"            "GTPBP1"
# [41] "UGT2B7"          "CENPW"           "ISCA1"           "TUT7"
#
# $Aging4
#  [1] "GLRX2"          "CDC73"          "RAB29"          "SLC41A1"
#  [5] "PM20D1"         "SLC26A9"        "RAB7B"          "CTSE"
#  [9] "RHEX"           "ERO1B"          "TCF7L2"         "SLC36A4"
# [13] "NABP2"          "ANKRD52"        "COQ10A"         "CS"
# [17] "CNPY2"          "PAN2"           "IL23A"          "STAT2"
# [21] "BPTF"           "KPNA2"          "TPGS2"          "KIAA1328"
# [25] "COX6B1"         "UPK1A"          "ZBTB32"         "KMT2B"
# [29] "PROSER3"        "COQ8B"          "DPYSL5"         "MAPRE3"
# [33] "TMEM214"        "EMILIN1"        "KHK"            "CGREF1"
# [37] "GFM1"           "AP3B1"          "BMP6"           "TXNDC5"
# [41] "BLOC1S5-TXNDC5" "SUPT3H"         "AMZ1"           "GNA12"
# [45] "SLC20A2"        "SMIM19"         "ENPP2"
#
# $Aging5
#  [1] "EIF4G3"   "CNTN2"    "TMEM81"   "RBBP5"    "DSTYK"    "TMCC2"
#  [7] "NUAK2"    "SYNPO2L"  "VCL"      "ADK"      "WBP1L"    "AS3MT"
# [13] "CNNM2"    "AKIP1"    "TMEM9B"   "TLCD5"    "ARHGEF12" "RHBDF1"
# [19] "FOXF1"    "VPS9D1"   "EFCAB13"  "LRRC46"   "TTLL6"    "CALCOCO2"
# [25] "ATP5MC1"  "UBE2Z"    "SNF8"     "ABI3"     "SEPTIN9"  "CCDC9"
# [31] "C5AR1"    "RGPD4"    "SULT1C4"  "GCC2"     "LIMS1"    "RANBP2"
# [37] "ICA1L"    "WDR12"    "CARF"     "NBEAL1"   "PLCG1"    "ZHX3"
# [43] "FAM118A"  "RIBC2"    "NUP210"   "NR2C2"    "RARB"     "CCDC12"
# [49] "NBEAL2"   "SCAP"     "ELP6"     "STIMATE"  "EPHA3"    "BTN2A1"
# [55] "ZKSCAN8"  "TRIM31"   "GPANK1"   "VWA7"     "C4A"      "C4B"
# [61] "CYP21A2"  "HLA-DQA1" "HLA-DMB"  "HLA-DMA"  "BRD2"     "FUT9"
# [67] "UFL1"     "FHL5"     "CENPW"    "AMZ1"     "GNA12"    "UMAD1"

# %%
library(UpSetR)
# Create named list of gene sets
gene_sets <- list(
  "AD1" = unique(AD1_gene),
  "AD2" = unique(AD2_gene), 
  "Aging1" = unique(Aging1_gene),
  "Aging2" = unique(Aging2_gene),
  "Aging3" = unique(Aging3_gene),
  "Aging4" = unique(Aging4_gene),
  "Aging5" = unique(Aging5_gene)
)

# Remove any NA values
gene_sets <- lapply(gene_sets, function(x) x[!is.na(x)])
# Convert to binary matrix for UpSet plot
all_genes <- unique(unlist(gene_sets))
upset_data <- data.frame(gene = all_genes)

for(set_name in names(gene_sets)) {
  upset_data[[set_name]] <- upset_data$gene %in% gene_sets[[set_name]]
}

# Convert to proper format for UpSetR
upset_r_data <- upset_data
# Remove the 'gene' column and convert to 0/1 instead of TRUE/FALSE
upset_r_data <- upset_r_data[, -1]  # Remove gene column
upset_r_data <- as.data.frame(lapply(upset_r_data, as.numeric))

# Add row names if needed
rownames(upset_r_data) <- upset_data$gene

# Create UpSetR plot with proper error handling
tryCatch({
  upset_r_plot <- upset(upset_r_data, 
                       sets = names(gene_sets),
                       order.by = "freq",
                       decreasing = TRUE,
                       mb.ratio = c(0.6, 0.4),
                       number.angles = 0,
                       text.scale = 1.2,
                       point.size = 3,
                       line.size = 1.5,
                       mainbar.y.label = "Intersection Size",
                       sets.x.label = "Gene Set Size",
                       sets.bar.color = "steelblue",
                       main.bar.color = "darkblue")
  
  cat("UpSetR plot created successfully\n")
}, error = function(e) {
  cat("UpSetR failed, using alternative method\n")
  
  # Alternative: Create a simple intersection matrix
  intersection_matrix <- matrix(0, nrow = length(unique(DNE$gene_name)), ncol = length(gene_sets))
  rownames(intersection_matrix) <- unique(DNE$gene_name)
  colnames(intersection_matrix) <- names(gene_sets)
  
  for(i in 1:length(gene_sets)) {
    intersection_matrix[unique(DNE$gene_name) %in% gene_sets[[i]], i] <- 1
  }
  
  print(head(intersection_matrix))
})
# Out:
# UpSetR plot created successfully

# %%
png("~/xqtl-analysis/production/image_QTL/analysis/pathway_enrichment_PPI/DNE_gene_overlap_upset_plot.png", width = 12, height = 8, units = "in", res = 300)
print(upset_r_plot)
dev.off()
# Out:
# agg_record_1423354144
#                     2
